# %% [markdown]
# # Installing necessary packages
# ### This block installs system libraries and Python packages necessary for image processing, document handling, and deep learning tasks.

# %%
# !sudo apt-get install -y libjpeg-dev zlib1g-dev graphviz
# %pip install scikit-image python-docx pymupdf opencv-python torch torchvision tensorflow

# %% [markdown]
# # Importing required modules
# ### This section imports all the necessary Python libraries for data preprocessing, handling, visualization, and model building.

# %%
# Data Pre-processing
import fitz
import cv2
import csv
import os
from docx import Document
import string
import requests
import pandas as pd
import numpy as np
from PIL import Image, ImageOps
from IPython.display import clear_output as cls

# Data
from glob import glob
from tqdm import tqdm
import tensorflow.data as tfd

# Data Visualization
import matplotlib.pyplot as plt

# Model
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, callbacks
from tensorflow.keras.utils import plot_model

# %% [markdown]
# # Downloading the dataset

# %%
# Downloading the Dataset on collab/local notebook

# Virtuosa ( Dataset 1)
# !gdown 'http://drive.google.com/uc?id=10NX_UbV2HMbPEO2fvKYAIXOOOec0g38g'  # Downloading link for Ancient Text

# Perfecto ( Dataset 2)
# !gdown 'http://drive.google.com/uc?id=1x6FS3z4WhsHS7s38a2oSH8JnLQ_u_f21'  # Downloading link for Ancient Text

# !gdown 'http://drive.google.com/uc?id=1r7TjJ9RjNZHxAzKhd4uOaRWanrQXIqw8'  # Downloading utils.py from cloud
# Out:
# Downloading...
# From: http://drive.google.com/uc?id=10NX_UbV2HMbPEO2fvKYAIXOOOec0g38g
# To: /home/psyduck/GSOC/Padilla - Nobleza virtuosa_testExtract.pdf
# 100%|██████████████████████████████████████| 2.58M/2.58M [00:00<00:00, 6.83MB/s]
# Downloading...
# From: http://drive.google.com/uc?id=1x6FS3z4WhsHS7s38a2oSH8JnLQ_u_f21
# To: /home/psyduck/GSOC/Padilla - 2 Noble perfecto_Extract.pdf
# 100%|██████████████████████████████████████| 3.95M/3.95M [00:00<00:00, 9.31MB/s]
# Downloading...
# From (original): http://drive.google.com/uc?id=1r7TjJ9RjNZHxAzKhd4uOaRWanrQXIqw8
# From (redirected): https://drive.google.com/uc?id=1r7TjJ9RjNZHxAzKhd4uOaRWanrQXIqw8&confirm=t&uuid=1b2efab9-888e-4329-8c6a-a2fa2fc2bc7f
# To: /home/psyduck/GSOC/utils.py
# 100%|██████████████████████████████████████| 17.0k/17.0k [00:00<00:00, 3.03MB/s]

# %%
# !ls
# Out:
# 'Model(1)(1).ipynb'
# 'Padilla - 2 Noble perfecto_Extract.pdf'
# 'Padilla - Nobleza virtuosa_testExtract.pdf'
#  utils.py

# %% [markdown]
# # Pre-processing the dataset

# %% [markdown]
# ### Converting PDF to images

# %%
from utils import pdf_to_images

pdf_path1 = "./Padilla - Nobleza virtuosa_testExtract.pdf"  # Path to the PDF file
unproc_images_folder_1 = "./preprocessing/imgsUnProcessed1"  # Output folder to save the images
if not os.path.exists(unproc_images_folder_1):
    os.makedirs(unproc_images_folder_1)
pdf_to_images(pdf_path1, unproc_images_folder_1)


pdf_path2 = "./Padilla - 2 Noble perfecto_Extract.pdf"  # Path to the PDF file
unproc_images_folder_2 = "./preprocessing/imgsUnProcessed2"  # Output folder to save the images
if not os.path.exists(unproc_images_folder_2):
    os.makedirs(unproc_images_folder_2)
pdf_to_images(pdf_path2, unproc_images_folder_2)

# %% [markdown]
# ### Splitting two sided scanned images into individual pages.

# %%
#Segregating 2-sided pages into individual pages
from utils import process_images

unproc_images_folder_1 = "./preprocessing/imgsUnProcessed1"
proc_images_folder_1 = "./preprocessing/imgsForAllPages1"
if not os.path.exists(proc_images_folder_1):
    os.makedirs(proc_images_folder_1)
process_images(unproc_images_folder_1, proc_images_folder_1)


unproc_images_folder_2 = "./preprocessing/imgsUnProcessed2"
proc_images_folder_2 = "./preprocessing/imgsForAllPages2"
if not os.path.exists(proc_images_folder_2):
    os.makedirs(proc_images_folder_2)
process_images(unproc_images_folder_2, proc_images_folder_2)

print("Image processing complete!")
# Out:
# Image processing complete!

# %% [markdown]
# ### Downloading the CRAFT model

# %%
# Check if the folder already exists
if not os.path.exists('CRAFT_Model'):
    # If it doesn't exist, clone the repository
    # !git clone 'https://github.com/lochan13/CRAFT.git'
else:
    print(f"The repository already exists.")
# Out:
# Cloning into 'CRAFT'...
# remote: Enumerating objects: 38, done.
# remote: Total 38 (delta 0), reused 0 (delta 0), pack-reused 38 (from 1)
# Receiving objects: 100% (38/38), 73.63 MiB | 17.94 MiB/s, done.
# Resolving deltas: 100% (13/13), done.

# %% [markdown]
# # Text Detection
# ### Extracting words from a scanned text page image we are using the [CRAFT Model](https://github.com/clovaai/CRAFT-pytorch) for the same.

# %%
# !python3 CRAFT/test.py --result_folder='./preprocessing/BoundBoxApplied1/' --test_folder="./preprocessing/imgsForAllPages1" --trained_model='CRAFT/weights/craft_mlt_25k.pth'
# Out:
# Loading weights from checkpoint (CRAFT/weights/craft_mlt_25k.pth)
# elapsed time : 37.26823854446411s/imgsForAllPages1/image_31.png

# %%
# !python3 CRAFT/test.py --result_folder='./preprocessing/BoundBoxApplied2/' --test_folder="./preprocessing/imgsForAllPages2" --trained_model='CRAFT/weights/craft_mlt_25k.pth'
# Out:
# Loading weights from checkpoint (CRAFT/weights/craft_mlt_25k.pth)
# elapsed time : 38.846946001052856simgsForAllPages2/image_31.png

# %% [markdown]
# ### The output of this model provides coordinates of the polygon enclosing the word. Using these coordinates one can draw a bounding box and crop word images.

# %%
#Sorting the BB based on the Spanish writing style
from utils import sort_bounding_boxes

bound_box_applied1 = './preprocessing/BoundBoxApplied1/'
bound_box_sorted1 = "./preprocessing/BoundBoxSorted1"
if not os.path.exists(bound_box_sorted1):
    os.makedirs(bound_box_sorted1)
sort_bounding_boxes(bound_box_applied1, bound_box_sorted1)

bound_box_applied2 = './preprocessing/BoundBoxApplied2/'
bound_box_sorted2 = "./preprocessing/BoundBoxSorted2"
if not os.path.exists(bound_box_sorted2):
    os.makedirs(bound_box_sorted2)
sort_bounding_boxes(bound_box_applied2, bound_box_sorted2)

# %% [markdown]
# # Generating Test Data

# %% [markdown]
# ### This code is preparing test data by extracting individual words from scanned document pages, using pre-computed bounding box information. The extracted words are saved as separate image files, which can then be used for testing an OCR (Optical Character Recognition) model.

# %%
from utils import count_files_in_folder, extract_bounding_boxes

def apply_extraction_to_folder_for_test(image_folder, bounding_box_folder, output_folder, word, TRAIN_PAGES):
    image_count = count_files_in_folder(image_folder, ['.png', '.jpeg', '.jpg'])
    
    for image in range(TRAIN_PAGES, image_count):
        image_filename = f'image_{image+1}.png'
        image_base_name = f'image_{image+1}'
        bounding_box_filename = f"res_{image_base_name}_sorted.txt"
        bounding_box_path = os.path.join(bounding_box_folder, bounding_box_filename)
        
        if os.path.exists(bounding_box_path):
            image_path = os.path.join(image_folder, image_filename)
            word = extract_bounding_boxes(image_path, bounding_box_path, output_folder, word)
            print(image_base_name)
        else:
            print(f'Bounding box file for {image_filename} does not exist.')
    
    return word

# For testing_data1
proc_images_folder_1 = './preprocessing/imgsForAllPages1'
bound_box_sorted1 = './preprocessing/BoundBoxSorted1'
testing_data1 = './testing_data1'
word = apply_extraction_to_folder_for_test(proc_images_folder_1, bound_box_sorted1, testing_data1, 0, 25)

# For testing_data2
proc_images_folder_2 = './preprocessing/imgsForAllPages2'
bound_box_sorted2 = './preprocessing/BoundBoxSorted2'
testing_data2 = './testing_data2'
apply_extraction_to_folder_for_test(proc_images_folder_2, bound_box_sorted2, testing_data2, word, 0)
# Out:
# image_26
# image_27
# image_28
# image_29
# image_30
# image_31
# image_1
# image_2
# image_3
# image_4
# image_5
# image_6
# image_7
# image_8
# image_9
# image_10
# image_11
# image_12
# image_13
# image_14
# image_15
# image_16
# image_17
# image_18
# image_19
# image_20
# image_21
# image_22
# image_23
# image_24
# image_25
# image_26
# image_27
# image_28
# image_29
# image_30
# image_31
# 5268

# %%
from utils import pad_and_resize_images

testing_data1 = './testing_data1'
pad_and_resize_images(testing_data1)

testing_data2= './testing_data2'
pad_and_resize_images(testing_data2)
# Out:
# Processed and replaced: ./testing_data1/0;0.png
# Processed and replaced: ./testing_data1/1;0.png
# Processed and replaced: ./testing_data1/2;0.png
# Processed and replaced: ./testing_data1/3;0.png
# Processed and replaced: ./testing_data1/4;0.png
# Processed and replaced: ./testing_data1/5;0.png
# Processed and replaced: ./testing_data1/6;1.png
# Processed and replaced: ./testing_data1/7;1.png
# Processed and replaced: ./testing_data1/8;1.png
# Processed and replaced: ./testing_data1/9;1.png
# Processed and replaced: ./testing_data1/10;1.png
# Processed and replaced: ./testing_data1/11;1.png
# Processed and replaced: ./testing_data1/12;1.png
# Processed and replaced: ./testing_data1/13;2.png
# Processed and replaced: ./testing_data1/14;2.png
# Processed and replaced: ./testing_data1/15;2.png
# Processed and replaced: ./testing_data1/16;2.png
# Processed and replaced: ./testing_data1/17;2.png
# Processed and replaced: ./testing_data1/18;2.png
# Processed and replaced: ./testing_data1/19;3.png
# Processed and replaced: ./testing_data1/20;3.png
# Processed and replaced: ./testing_data1/21;3.png
# Processed and replaced: ./testing_data1/22;3.png
# Processed and replaced: ./testing_data1/23;3.png
# Processed and replaced: ./testing_data1/24;4.png
# Processed and replaced: ./testing_data1/25;4.png
# Processed and replaced: ./testing_data1/26;4.png
# Processed and replaced: ./testing_data1/27;4.png
# Processed and replaced: ./testing_data1/28;4.png
# Processed and replaced: ./testing_data1/29;4.png
# Processed and replaced: ./testing_data1/30;4.png
# Processed and replaced: ./testing_data1/31;5.png
# Processed and replaced: ./testing_data1/32;5.png
# Processed and replaced: ./testing_data1/33;5.png
# Processed and replaced: ./testing_data1/34;5.png
# Processed and replaced: ./testing_data1/35;6.png
# Processed and replaced: ./testing_data1/36;6.png
# Processed and replaced: ./testing_data1/37;6.png
# Processed and replaced: ./testing_data1/38;6.png
# Processed and replaced: ./testing_data1/39;7.png
# Processed and replaced: ./testing_data1/40;7.png
# Processed and replaced: ./testing_data1/41;7.png
# Processed and replaced: ./testing_data1/42;7.png
# Processed and replaced: ./testing_data1/43;7.png
# Processed and replaced: ./testing_data1/44;8.png
# Processed and replaced: ./testing_data1/45;8.png
# Processed and replaced: ./testing_data1/46;9.png
# Processed and replaced: ./testing_data1/47;9.png
# Processed and replaced: ./testing_data1/48;9.png
# Processed and replaced: ./testing_data1/49;9.png
# Processed and replaced: ./testing_data1/50;9.png
# Processed and replaced: ./testing_data1/51;9.png
# Processed and replaced: ./testing_data1/52;9.png
# Processed and replaced: ./testing_data1/53;9.png
# Processed and replaced: ./testing_data1/54;9.png
# Processed and replaced: ./testing_data1/55;10.png
# Processed and replaced: ./testing_data1/56;10.png
# Processed and replaced: ./testing_data1/57;10.png
# Processed and replaced: ./testing_data1/58;10.png
# Processed and replaced: ./testing_data1/59;10.png
# Processed and replaced: ./testing_data1/60;11.png
# Processed and replaced: ./testing_data1/61;11.png
# Processed and replaced: ./testing_data1/62;11.png
# Processed and replaced: ./testing_data1/63;11.png
# Processed and replaced: ./testing_data1/64;12.png
# Processed and replaced: ./testing_data1/65;12.png
# Processed and replaced: ./testing_data1/66;12.png
# Processed and replaced: ./testing_data1/67;12.png
# Processed and replaced: ./testing_data1/68;12.png
# Processed and replaced: ./testing_data1/69;12.png
# Processed and replaced: ./testing_data1/70;12.png
# Processed and replaced: ./testing_data1/71;13.png
# Processed and replaced: ./testing_data1/72;13.png
# Processed and replaced: ./testing_data1/73;13.png
# Processed and replaced: ./testing_data1/74;13.png
# Processed and replaced: ./testing_data1/75;13.png
# Processed and replaced: ./testing_data1/76;13.png
# Processed and replaced: ./testing_data1/77;14.png
# Processed and replaced: ./testing_data1/78;14.png
# Processed and replaced: ./testing_data1/79;14.png
# Processed and replaced: ./testing_data1/80;14.png
# Processed and replaced: ./testing_data1/81;14.png
# Processed and replaced: ./testing_data1/82;14.png
# Processed and replaced: ./testing_data1/83;14.png
# Processed and replaced: ./testing_data1/84;14.png
# Processed and replaced: ./testing_data1/85;15.png
# Processed and replaced: ./testing_data1/86;15.png
# Processed and replaced: ./testing_data1/87;15.png
# Processed and replaced: ./testing_data1/88;15.png
# Processed and replaced: ./testing_data1/89;15.png
# Processed and replaced: ./testing_data1/90;16.png
# Processed and replaced: ./testing_data1/91;16.png
# Processed and replaced: ./testing_data1/92;16.png
# Processed and replaced: ./testing_data1/93;16.png
# Processed and replaced: ./testing_data1/94;16.png
# Processed and replaced: ./testing_data1/95;16.png
# Processed and replaced: ./testing_data1/96;17.png
# Processed and replaced: ./testing_data1/97;17.png
# Processed and replaced: ./testing_data1/98;17.png
# Processed and replaced: ./testing_data1/99;17.png
# Processed and replaced: ./testing_data1/100;17.png
# Processed and replaced: ./testing_data1/101;17.png
# Processed and replaced: ./testing_data1/102;18.png
# Processed and replaced: ./testing_data1/103;18.png
# Processed and replaced: ./testing_data1/104;18.png
# Processed and replaced: ./testing_data1/105;18.png
# Processed and replaced: ./testing_data1/106;19.png
# Processed and replaced: ./testing_data1/107;19.png
# Processed and replaced: ./testing_data1/108;19.png
# Processed and replaced: ./testing_data1/109;19.png
# Processed and replaced: ./testing_data1/110;19.png
# Processed and replaced: ./testing_data1/111;19.png
# Processed and replaced: ./testing_data1/112;20.png
# Processed and replaced: ./testing_data1/113;20.png
# Processed and replaced: ./testing_data1/114;20.png
# Processed and replaced: ./testing_data1/115;20.png
# Processed and replaced: ./testing_data1/116;20.png
# Processed and replaced: ./testing_data1/117;20.png
# Processed and replaced: ./testing_data1/118;20.png
# Processed and replaced: ./testing_data1/119;20.png
# Processed and replaced: ./testing_data1/120;20.png
# Processed and replaced: ./testing_data1/121;21.png
# Processed and replaced: ./testing_data1/122;21.png
# Processed and replaced: ./testing_data1/123;21.png
# Processed and replaced: ./testing_data1/124;21.png
# Processed and replaced: ./testing_data1/125;21.png
# Processed and replaced: ./testing_data1/126;21.png
# Processed and replaced: ./testing_data1/127;21.png
# Processed and replaced: ./testing_data1/128;22.png
# Processed and replaced: ./testing_data1/129;22.png
# Processed and replaced: ./testing_data1/130;22.png
# Processed and replaced: ./testing_data1/131;22.png
# Processed and replaced: ./testing_data1/132;22.png
# Processed and replaced: ./testing_data1/133;22.png
# Processed and replaced: ./testing_data1/134;22.png
# Processed and replaced: ./testing_data1/135;22.png
# Processed and replaced: ./testing_data1/136;22.png
# Processed and replaced: ./testing_data1/137;23.png
# Processed and replaced: ./testing_data1/138;23.png
# Processed and replaced: ./testing_data1/139;23.png
# Processed and replaced: ./testing_data1/140;23.png
# Processed and replaced: ./testing_data1/141;23.png
# Processed and replaced: ./testing_data1/142;23.png
# Processed and replaced: ./testing_data1/143;23.png
# Processed and replaced: ./testing_data1/144;23.png
# Processed and replaced: ./testing_data1/145;24.png
# Processed and replaced: ./testing_data1/146;0.png
# Processed and replaced: ./testing_data1/147;0.png
# Processed and replaced: ./testing_data1/148;0.png
# Processed and replaced: ./testing_data1/149;0.png
# Processed and replaced: ./testing_data1/150;1.png
# Processed and replaced: ./testing_data1/151;1.png
# Processed and replaced: ./testing_data1/152;1.png
# Processed and replaced: ./testing_data1/153;1.png
# Processed and replaced: ./testing_data1/154;1.png
# Processed and replaced: ./testing_data1/155;1.png
# Processed and replaced: ./testing_data1/156;1.png
# Processed and replaced: ./testing_data1/157;1.png
# Processed and replaced: ./testing_data1/158;2.png
# Processed and replaced: ./testing_data1/159;2.png
# Processed and replaced: ./testing_data1/160;2.png
# Processed and replaced: ./testing_data1/161;2.png
# Processed and replaced: ./testing_data1/162;2.png
# Processed and replaced: ./testing_data1/163;2.png
# Processed and replaced: ./testing_data1/164;3.png
# Processed and replaced: ./testing_data1/165;3.png
# Processed and replaced: ./testing_data1/166;3.png
# Processed and replaced: ./testing_data1/167;3.png
# Processed and replaced: ./testing_data1/168;3.png
# Processed and replaced: ./testing_data1/169;3.png
# Processed and replaced: ./testing_data1/170;4.png
# Processed and replaced: ./testing_data1/171;4.png
# Processed and replaced: ./testing_data1/172;4.png
# Processed and replaced: ./testing_data1/173;4.png
# Processed and replaced: ./testing_data1/174;4.png
# Processed and replaced: ./testing_data1/175;4.png
# Processed and replaced: ./testing_data1/176;4.png
# Processed and replaced: ./testing_data1/177;5.png
# Processed and replaced: ./testing_data1/178;5.png
# Processed and replaced: ./testing_data1/179;5.png
# Processed and replaced: ./testing_data1/180;5.png
# Processed and replaced: ./testing_data1/181;5.png
# Processed and replaced: ./testing_data1/182;5.png
# Processed and replaced: ./testing_data1/183;6.png
# Processed and replaced: ./testing_data1/184;6.png
# Processed and replaced: ./testing_data1/185;6.png
# Processed and replaced: ./testing_data1/186;6.png
# Processed and replaced: ./testing_data1/187;6.png
# Processed and replaced: ./testing_data1/188;6.png
# Processed and replaced: ./testing_data1/189;6.png
# Processed and replaced: ./testing_data1/190;7.png
# Processed and replaced: ./testing_data1/191;7.png
# Processed and replaced: ./testing_data1/192;7.png
# Processed and replaced: ./testing_data1/193;7.png
# Processed and replaced: ./testing_data1/194;7.png
# Processed and replaced: ./testing_data1/195;7.png
# Processed and replaced: ./testing_data1/196;7.png
# Processed and replaced: ./testing_data1/197;8.png
# Processed and replaced: ./testing_data1/198;8.png
# Processed and replaced: ./testing_data1/199;8.png
# Processed and replaced: ./testing_data1/200;8.png
# Processed and replaced: ./testing_data1/201;8.png
# Processed and replaced: ./testing_data1/202;8.png
# Processed and replaced: ./testing_data1/203;9.png
# Processed and replaced: ./testing_data1/204;9.png
# Processed and replaced: ./testing_data1/205;9.png
# Processed and replaced: ./testing_data1/206;10.png
# Processed and replaced: ./testing_data1/207;10.png
# Processed and replaced: ./testing_data1/208;10.png
# Processed and replaced: ./testing_data1/209;10.png
# Processed and replaced: ./testing_data1/210;10.png
# Processed and replaced: ./testing_data1/211;10.png
# Processed and replaced: ./testing_data1/212;10.png
# Processed and replaced: ./testing_data1/213;11.png
# Processed and replaced: ./testing_data1/214;11.png
# Processed and replaced: ./testing_data1/215;11.png
# Processed and replaced: ./testing_data1/216;11.png
# Processed and replaced: ./testing_data1/217;11.png
# Processed and replaced: ./testing_data1/218;11.png
# Processed and replaced: ./testing_data1/219;12.png
# Processed and replaced: ./testing_data1/220;12.png
# Processed and replaced: ./testing_data1/221;12.png
# Processed and replaced: ./testing_data1/222;12.png
# Processed and replaced: ./testing_data1/223;12.png
# Processed and replaced: ./testing_data1/224;12.png
# Processed and replaced: ./testing_data1/225;13.png
# Processed and replaced: ./testing_data1/226;13.png
# Processed and replaced: ./testing_data1/227;13.png
# Processed and replaced: ./testing_data1/228;13.png
# Processed and replaced: ./testing_data1/229;13.png
# Processed and replaced: ./testing_data1/230;13.png
# Processed and replaced: ./testing_data1/231;14.png
# Processed and replaced: ./testing_data1/232;14.png
# Processed and replaced: ./testing_data1/233;14.png
# Processed and replaced: ./testing_data1/234;14.png
# Processed and replaced: ./testing_data1/235;14.png
# Processed and replaced: ./testing_data1/236;14.png
# Processed and replaced: ./testing_data1/237;14.png
# Processed and replaced: ./testing_data1/238;14.png
# Processed and replaced: ./testing_data1/239;14.png
# Processed and replaced: ./testing_data1/240;15.png
# Processed and replaced: ./testing_data1/241;15.png
# Processed and replaced: ./testing_data1/242;15.png
# Processed and replaced: ./testing_data1/243;15.png
# Processed and replaced: ./testing_data1/244;15.png
# Processed and replaced: ./testing_data1/245;15.png
# Processed and replaced: ./testing_data1/246;15.png
# Processed and replaced: ./testing_data1/247;15.png
# Processed and replaced: ./testing_data1/248;16.png
# Processed and replaced: ./testing_data1/249;16.png
# Processed and replaced: ./testing_data1/250;16.png
# Processed and replaced: ./testing_data1/251;16.png
# Processed and replaced: ./testing_data1/252;16.png
# Processed and replaced: ./testing_data1/253;16.png
# Processed and replaced: ./testing_data1/254;16.png
# Processed and replaced: ./testing_data1/255;17.png
# Processed and replaced: ./testing_data1/256;17.png
# Processed and replaced: ./testing_data1/257;17.png
# Processed and replaced: ./testing_data1/258;17.png
# Processed and replaced: ./testing_data1/259;17.png
# Processed and replaced: ./testing_data1/260;17.png
# Processed and replaced: ./testing_data1/261;18.png
# Processed and replaced: ./testing_data1/262;18.png
# Processed and replaced: ./testing_data1/263;18.png
# Processed and replaced: ./testing_data1/264;18.png
# Processed and replaced: ./testing_data1/265;18.png
# Processed and replaced: ./testing_data1/266;18.png
# Processed and replaced: ./testing_data1/267;19.png
# Processed and replaced: ./testing_data1/268;20.png
# Processed and replaced: ./testing_data1/269;20.png
# Processed and replaced: ./testing_data1/270;20.png
# Processed and replaced: ./testing_data1/271;20.png
# Processed and replaced: ./testing_data1/272;20.png
# Processed and replaced: ./testing_data1/273;20.png
# Processed and replaced: ./testing_data1/274;21.png
# Processed and replaced: ./testing_data1/275;21.png
# Processed and replaced: ./testing_data1/276;21.png
# Processed and replaced: ./testing_data1/277;21.png
# Processed and replaced: ./testing_data1/278;21.png
# Processed and replaced: ./testing_data1/279;21.png
# Processed and replaced: ./testing_data1/280;21.png
# Processed and replaced: ./testing_data1/281;21.png
# Processed and replaced: ./testing_data1/282;22.png
# Processed and replaced: ./testing_data1/283;22.png
# Processed and replaced: ./testing_data1/284;22.png
# Processed and replaced: ./testing_data1/285;22.png
# Processed and replaced: ./testing_data1/286;22.png
# Processed and replaced: ./testing_data1/287;23.png
# Processed and replaced: ./testing_data1/288;23.png
# Processed and replaced: ./testing_data1/289;23.png
# Processed and replaced: ./testing_data1/290;23.png
# Processed and replaced: ./testing_data1/291;23.png
# Processed and replaced: ./testing_data1/292;24.png
# Processed and replaced: ./testing_data1/293;0.png
# Processed and replaced: ./testing_data1/294;0.png
# Processed and replaced: ./testing_data1/295;0.png
# Processed and replaced: ./testing_data1/296;0.png
# Processed and replaced: ./testing_data1/297;0.png
# Processed and replaced: ./testing_data1/298;0.png
# Processed and replaced: ./testing_data1/299;1.png
# Processed and replaced: ./testing_data1/300;1.png
# Processed and replaced: ./testing_data1/301;1.png
# Processed and replaced: ./testing_data1/302;1.png
# Processed and replaced: ./testing_data1/303;1.png
# Processed and replaced: ./testing_data1/304;1.png
# Processed and replaced: ./testing_data1/305;2.png
# Processed and replaced: ./testing_data1/306;2.png
# Processed and replaced: ./testing_data1/307;2.png
# Processed and replaced: ./testing_data1/308;2.png
# Processed and replaced: ./testing_data1/309;3.png
# Processed and replaced: ./testing_data1/310;3.png
# Processed and replaced: ./testing_data1/311;3.png
# Processed and replaced: ./testing_data1/312;3.png
# Processed and replaced: ./testing_data1/313;3.png
# Processed and replaced: ./testing_data1/314;3.png
# Processed and replaced: ./testing_data1/315;4.png
# Processed and replaced: ./testing_data1/316;4.png
# Processed and replaced: ./testing_data1/317;4.png
# Processed and replaced: ./testing_data1/318;5.png
# Processed and replaced: ./testing_data1/319;5.png
# Processed and replaced: ./testing_data1/320;5.png
# Processed and replaced: ./testing_data1/321;5.png
# Processed and replaced: ./testing_data1/322;6.png
# Processed and replaced: ./testing_data1/323;6.png
# Processed and replaced: ./testing_data1/324;6.png
# Processed and replaced: ./testing_data1/325;6.png
# Processed and replaced: ./testing_data1/326;6.png
# Processed and replaced: ./testing_data1/327;6.png
# Processed and replaced: ./testing_data1/328;7.png
# Processed and replaced: ./testing_data1/329;7.png
# Processed and replaced: ./testing_data1/330;7.png
# Processed and replaced: ./testing_data1/331;7.png
# Processed and replaced: ./testing_data1/332;7.png
# Processed and replaced: ./testing_data1/333;8.png
# Processed and replaced: ./testing_data1/334;8.png
# Processed and replaced: ./testing_data1/335;8.png
# Processed and replaced: ./testing_data1/336;8.png
# Processed and replaced: ./testing_data1/337;8.png
# Processed and replaced: ./testing_data1/338;8.png
# Processed and replaced: ./testing_data1/339;9.png
# Processed and replaced: ./testing_data1/340;9.png
# Processed and replaced: ./testing_data1/341;9.png
# Processed and replaced: ./testing_data1/342;9.png
# Processed and replaced: ./testing_data1/343;9.png
# Processed and replaced: ./testing_data1/344;10.png
# Processed and replaced: ./testing_data1/345;10.png
# Processed and replaced: ./testing_data1/346;10.png
# Processed and replaced: ./testing_data1/347;10.png
# Processed and replaced: ./testing_data1/348;10.png
# Processed and replaced: ./testing_data1/349;10.png
# Processed and replaced: ./testing_data1/350;10.png
# Processed and replaced: ./testing_data1/351;11.png
# Processed and replaced: ./testing_data1/352;11.png
# Processed and replaced: ./testing_data1/353;11.png
# Processed and replaced: ./testing_data1/354;11.png
# Processed and replaced: ./testing_data1/355;11.png
# Processed and replaced: ./testing_data1/356;12.png
# Processed and replaced: ./testing_data1/357;12.png
# Processed and replaced: ./testing_data1/358;12.png
# Processed and replaced: ./testing_data1/359;12.png
# Processed and replaced: ./testing_data1/360;12.png
# Processed and replaced: ./testing_data1/361;12.png
# Processed and replaced: ./testing_data1/362;13.png
# Processed and replaced: ./testing_data1/363;13.png
# Processed and replaced: ./testing_data1/364;13.png
# Processed and replaced: ./testing_data1/365;13.png
# Processed and replaced: ./testing_data1/366;13.png
# Processed and replaced: ./testing_data1/367;13.png
# Processed and replaced: ./testing_data1/368;13.png
# Processed and replaced: ./testing_data1/369;14.png
# Processed and replaced: ./testing_data1/370;14.png
# Processed and replaced: ./testing_data1/371;14.png
# Processed and replaced: ./testing_data1/372;14.png
# Processed and replaced: ./testing_data1/373;14.png
# Processed and replaced: ./testing_data1/374;14.png
# Processed and replaced: ./testing_data1/375;14.png
# Processed and replaced: ./testing_data1/376;15.png
# Processed and replaced: ./testing_data1/377;15.png
# Processed and replaced: ./testing_data1/378;15.png
# Processed and replaced: ./testing_data1/379;15.png
# Processed and replaced: ./testing_data1/380;15.png
# Processed and replaced: ./testing_data1/381;15.png
# Processed and replaced: ./testing_data1/382;15.png
# Processed and replaced: ./testing_data1/383;16.png
# Processed and replaced: ./testing_data1/384;16.png
# Processed and replaced: ./testing_data1/385;16.png
# Processed and replaced: ./testing_data1/386;16.png
# Processed and replaced: ./testing_data1/387;16.png
# Processed and replaced: ./testing_data1/388;16.png
# Processed and replaced: ./testing_data1/389;16.png
# Processed and replaced: ./testing_data1/390;17.png
# Processed and replaced: ./testing_data1/391;17.png
# Processed and replaced: ./testing_data1/392;17.png
# Processed and replaced: ./testing_data1/393;17.png
# Processed and replaced: ./testing_data1/394;17.png
# Processed and replaced: ./testing_data1/395;18.png
# Processed and replaced: ./testing_data1/396;18.png
# Processed and replaced: ./testing_data1/397;18.png
# Processed and replaced: ./testing_data1/398;18.png
# Processed and replaced: ./testing_data1/399;18.png
# Processed and replaced: ./testing_data1/400;18.png
# Processed and replaced: ./testing_data1/401;18.png
# Processed and replaced: ./testing_data1/402;18.png
# Processed and replaced: ./testing_data1/403;19.png
# Processed and replaced: ./testing_data1/404;19.png
# Processed and replaced: ./testing_data1/405;19.png
# Processed and replaced: ./testing_data1/406;19.png
# Processed and replaced: ./testing_data1/407;19.png
# Processed and replaced: ./testing_data1/408;19.png
# Processed and replaced: ./testing_data1/409;20.png
# Processed and replaced: ./testing_data1/410;20.png
# Processed and replaced: ./testing_data1/411;20.png
# Processed and replaced: ./testing_data1/412;20.png
# Processed and replaced: ./testing_data1/413;20.png
# Processed and replaced: ./testing_data1/414;20.png
# Processed and replaced: ./testing_data1/415;21.png
# Processed and replaced: ./testing_data1/416;21.png
# Processed and replaced: ./testing_data1/417;21.png
# Processed and replaced: ./testing_data1/418;21.png
# Processed and replaced: ./testing_data1/419;21.png
# Processed and replaced: ./testing_data1/420;21.png
# Processed and replaced: ./testing_data1/421;22.png
# Processed and replaced: ./testing_data1/422;22.png
# Processed and replaced: ./testing_data1/423;22.png
# Processed and replaced: ./testing_data1/424;22.png
# Processed and replaced: ./testing_data1/425;22.png
# Processed and replaced: ./testing_data1/426;22.png
# Processed and replaced: ./testing_data1/427;23.png
# Processed and replaced: ./testing_data1/428;23.png
# Processed and replaced: ./testing_data1/429;23.png
# Processed and replaced: ./testing_data1/430;23.png
# Processed and replaced: ./testing_data1/431;23.png
# Processed and replaced: ./testing_data1/432;24.png
# Processed and replaced: ./testing_data1/433;0.png
# Processed and replaced: ./testing_data1/434;0.png
# Processed and replaced: ./testing_data1/435;0.png
# Processed and replaced: ./testing_data1/436;0.png
# Processed and replaced: ./testing_data1/437;0.png
# Processed and replaced: ./testing_data1/438;0.png
# Processed and replaced: ./testing_data1/439;0.png
# Processed and replaced: ./testing_data1/440;1.png
# Processed and replaced: ./testing_data1/441;1.png
# Processed and replaced: ./testing_data1/442;1.png
# Processed and replaced: ./testing_data1/443;1.png
# Processed and replaced: ./testing_data1/444;2.png
# Processed and replaced: ./testing_data1/445;2.png
# Processed and replaced: ./testing_data1/446;2.png
# Processed and replaced: ./testing_data1/447;2.png
# Processed and replaced: ./testing_data1/448;2.png
# Processed and replaced: ./testing_data1/449;2.png
# Processed and replaced: ./testing_data1/450;3.png
# Processed and replaced: ./testing_data1/451;3.png
# Processed and replaced: ./testing_data1/452;3.png
# Processed and replaced: ./testing_data1/453;3.png
# Processed and replaced: ./testing_data1/454;3.png
# Processed and replaced: ./testing_data1/455;3.png
# Processed and replaced: ./testing_data1/456;4.png
# Processed and replaced: ./testing_data1/457;4.png
# Processed and replaced: ./testing_data1/458;4.png
# Processed and replaced: ./testing_data1/459;4.png
# Processed and replaced: ./testing_data1/460;5.png
# Processed and replaced: ./testing_data1/461;5.png
# Processed and replaced: ./testing_data1/462;5.png
# Processed and replaced: ./testing_data1/463;5.png
# Processed and replaced: ./testing_data1/464;5.png
# Processed and replaced: ./testing_data1/465;5.png
# Processed and replaced: ./testing_data1/466;5.png
# Processed and replaced: ./testing_data1/467;6.png
# Processed and replaced: ./testing_data1/468;6.png
# Processed and replaced: ./testing_data1/469;6.png
# Processed and replaced: ./testing_data1/470;6.png
# Processed and replaced: ./testing_data1/471;6.png
# Processed and replaced: ./testing_data1/472;6.png
# Processed and replaced: ./testing_data1/473;6.png
# Processed and replaced: ./testing_data1/474;6.png
# Processed and replaced: ./testing_data1/475;6.png
# Processed and replaced: ./testing_data1/476;6.png
# Processed and replaced: ./testing_data1/477;7.png
# Processed and replaced: ./testing_data1/478;7.png
# Processed and replaced: ./testing_data1/479;7.png
# Processed and replaced: ./testing_data1/480;7.png
# Processed and replaced: ./testing_data1/481;7.png
# Processed and replaced: ./testing_data1/482;8.png
# Processed and replaced: ./testing_data1/483;8.png
# Processed and replaced: ./testing_data1/484;8.png
# Processed and replaced: ./testing_data1/485;8.png
# Processed and replaced: ./testing_data1/486;8.png
# Processed and replaced: ./testing_data1/487;8.png
# Processed and replaced: ./testing_data1/488;8.png
# Processed and replaced: ./testing_data1/489;9.png
# Processed and replaced: ./testing_data1/490;9.png
# Processed and replaced: ./testing_data1/491;9.png
# Processed and replaced: ./testing_data1/492;9.png
# Processed and replaced: ./testing_data1/493;9.png
# Processed and replaced: ./testing_data1/494;9.png
# Processed and replaced: ./testing_data1/495;10.png
# Processed and replaced: ./testing_data1/496;10.png
# Processed and replaced: ./testing_data1/497;10.png
# Processed and replaced: ./testing_data1/498;10.png
# Processed and replaced: ./testing_data1/499;11.png
# Processed and replaced: ./testing_data1/500;11.png
# Processed and replaced: ./testing_data1/501;11.png
# Processed and replaced: ./testing_data1/502;11.png
# Processed and replaced: ./testing_data1/503;11.png
# Processed and replaced: ./testing_data1/504;11.png
# Processed and replaced: ./testing_data1/505;12.png
# Processed and replaced: ./testing_data1/506;12.png
# Processed and replaced: ./testing_data1/507;12.png
# Processed and replaced: ./testing_data1/508;12.png
# Processed and replaced: ./testing_data1/509;12.png
# Processed and replaced: ./testing_data1/510;12.png
# Processed and replaced: ./testing_data1/511;12.png
# Processed and replaced: ./testing_data1/512;13.png
# Processed and replaced: ./testing_data1/513;13.png
# Processed and replaced: ./testing_data1/514;13.png
# Processed and replaced: ./testing_data1/515;13.png
# Processed and replaced: ./testing_data1/516;14.png
# Processed and replaced: ./testing_data1/517;14.png
# Processed and replaced: ./testing_data1/518;14.png
# Processed and replaced: ./testing_data1/519;15.png
# Processed and replaced: ./testing_data1/520;15.png
# Processed and replaced: ./testing_data1/521;15.png
# Processed and replaced: ./testing_data1/522;15.png
# Processed and replaced: ./testing_data1/523;15.png
# Processed and replaced: ./testing_data1/524;15.png
# Processed and replaced: ./testing_data1/525;15.png
# Processed and replaced: ./testing_data1/526;16.png
# Processed and replaced: ./testing_data1/527;16.png
# Processed and replaced: ./testing_data1/528;17.png
# Processed and replaced: ./testing_data1/529;17.png
# Processed and replaced: ./testing_data1/530;17.png
# Processed and replaced: ./testing_data1/531;17.png
# Processed and replaced: ./testing_data1/532;17.png
# Processed and replaced: ./testing_data1/533;18.png
# Processed and replaced: ./testing_data1/534;18.png
# Processed and replaced: ./testing_data1/535;18.png
# Processed and replaced: ./testing_data1/536;18.png
# Processed and replaced: ./testing_data1/537;18.png
# Processed and replaced: ./testing_data1/538;18.png
# Processed and replaced: ./testing_data1/539;18.png
# Processed and replaced: ./testing_data1/540;19.png
# Processed and replaced: ./testing_data1/541;19.png
# Processed and replaced: ./testing_data1/542;19.png
# Processed and replaced: ./testing_data1/543;19.png
# Processed and replaced: ./testing_data1/544;19.png
# Processed and replaced: ./testing_data1/545;20.png
# Processed and replaced: ./testing_data1/546;20.png
# Processed and replaced: ./testing_data1/547;20.png
# Processed and replaced: ./testing_data1/548;20.png
# Processed and replaced: ./testing_data1/549;21.png
# Processed and replaced: ./testing_data1/550;21.png
# Processed and replaced: ./testing_data1/551;21.png
# Processed and replaced: ./testing_data1/552;21.png
# Processed and replaced: ./testing_data1/553;21.png
# Processed and replaced: ./testing_data1/554;22.png
# Processed and replaced: ./testing_data1/555;22.png
# Processed and replaced: ./testing_data1/556;22.png
# Processed and replaced: ./testing_data1/557;22.png
# Processed and replaced: ./testing_data1/558;22.png
# Processed and replaced: ./testing_data1/559;22.png
# Processed and replaced: ./testing_data1/560;22.png
# Processed and replaced: ./testing_data1/561;23.png
# Processed and replaced: ./testing_data1/562;23.png
# Processed and replaced: ./testing_data1/563;23.png
# Processed and replaced: ./testing_data1/564;23.png
# Processed and replaced: ./testing_data1/565;23.png
# Processed and replaced: ./testing_data1/566;23.png
# Processed and replaced: ./testing_data1/567;23.png
# Processed and replaced: ./testing_data1/568;23.png
# Processed and replaced: ./testing_data1/569;23.png
# Processed and replaced: ./testing_data1/570;24.png
# Processed and replaced: ./testing_data1/571;0.png
# Processed and replaced: ./testing_data1/572;0.png
# Processed and replaced: ./testing_data1/573;0.png
# Processed and replaced: ./testing_data1/574;0.png
# Processed and replaced: ./testing_data1/575;0.png
# Processed and replaced: ./testing_data1/576;0.png
# Processed and replaced: ./testing_data1/577;1.png
# Processed and replaced: ./testing_data1/578;1.png
# Processed and replaced: ./testing_data1/579;1.png
# Processed and replaced: ./testing_data1/580;1.png
# Processed and replaced: ./testing_data1/581;1.png
# Processed and replaced: ./testing_data1/582;1.png
# Processed and replaced: ./testing_data1/583;1.png
# Processed and replaced: ./testing_data1/584;1.png
# Processed and replaced: ./testing_data1/585;2.png
# Processed and replaced: ./testing_data1/586;2.png
# Processed and replaced: ./testing_data1/587;2.png
# Processed and replaced: ./testing_data1/588;2.png
# Processed and replaced: ./testing_data1/589;2.png
# Processed and replaced: ./testing_data1/590;2.png
# Processed and replaced: ./testing_data1/591;2.png
# Processed and replaced: ./testing_data1/592;2.png
# Processed and replaced: ./testing_data1/593;2.png
# Processed and replaced: ./testing_data1/594;2.png
# Processed and replaced: ./testing_data1/595;3.png
# Processed and replaced: ./testing_data1/596;3.png
# Processed and replaced: ./testing_data1/597;3.png
# Processed and replaced: ./testing_data1/598;3.png
# Processed and replaced: ./testing_data1/599;3.png
# Processed and replaced: ./testing_data1/600;3.png
# Processed and replaced: ./testing_data1/601;3.png
# Processed and replaced: ./testing_data1/602;4.png
# Processed and replaced: ./testing_data1/603;4.png
# Processed and replaced: ./testing_data1/604;4.png
# Processed and replaced: ./testing_data1/605;4.png
# Processed and replaced: ./testing_data1/606;4.png
# Processed and replaced: ./testing_data1/607;5.png
# Processed and replaced: ./testing_data1/608;5.png
# Processed and replaced: ./testing_data1/609;5.png
# Processed and replaced: ./testing_data1/610;5.png
# Processed and replaced: ./testing_data1/611;5.png
# Processed and replaced: ./testing_data1/612;5.png
# Processed and replaced: ./testing_data1/613;5.png
# Processed and replaced: ./testing_data1/614;6.png
# Processed and replaced: ./testing_data1/615;6.png
# Processed and replaced: ./testing_data1/616;6.png
# Processed and replaced: ./testing_data1/617;6.png
# Processed and replaced: ./testing_data1/618;6.png
# Processed and replaced: ./testing_data1/619;7.png
# Processed and replaced: ./testing_data1/620;7.png
# Processed and replaced: ./testing_data1/621;7.png
# Processed and replaced: ./testing_data1/622;7.png
# Processed and replaced: ./testing_data1/623;7.png
# Processed and replaced: ./testing_data1/624;7.png
# Processed and replaced: ./testing_data1/625;8.png
# Processed and replaced: ./testing_data1/626;8.png
# Processed and replaced: ./testing_data1/627;8.png
# Processed and replaced: ./testing_data1/628;8.png
# Processed and replaced: ./testing_data1/629;8.png
# Processed and replaced: ./testing_data1/630;9.png
# Processed and replaced: ./testing_data1/631;9.png
# Processed and replaced: ./testing_data1/632;9.png
# Processed and replaced: ./testing_data1/633;9.png
# Processed and replaced: ./testing_data1/634;10.png
# Processed and replaced: ./testing_data1/635;10.png
# Processed and replaced: ./testing_data1/636;10.png
# Processed and replaced: ./testing_data1/637;10.png
# Processed and replaced: ./testing_data1/638;10.png
# Processed and replaced: ./testing_data1/639;10.png
# Processed and replaced: ./testing_data1/640;11.png
# Processed and replaced: ./testing_data1/641;11.png
# Processed and replaced: ./testing_data1/642;11.png
# Processed and replaced: ./testing_data1/643;11.png
# Processed and replaced: ./testing_data1/644;11.png
# Processed and replaced: ./testing_data1/645;11.png
# Processed and replaced: ./testing_data1/646;11.png
# Processed and replaced: ./testing_data1/647;11.png
# Processed and replaced: ./testing_data1/648;12.png
# Processed and replaced: ./testing_data1/649;12.png
# Processed and replaced: ./testing_data1/650;12.png
# Processed and replaced: ./testing_data1/651;12.png
# Processed and replaced: ./testing_data1/652;12.png
# Processed and replaced: ./testing_data1/653;12.png
# Processed and replaced: ./testing_data1/654;13.png
# Processed and replaced: ./testing_data1/655;13.png
# Processed and replaced: ./testing_data1/656;13.png
# Processed and replaced: ./testing_data1/657;13.png
# Processed and replaced: ./testing_data1/658;13.png
# Processed and replaced: ./testing_data1/659;13.png
# Processed and replaced: ./testing_data1/660;14.png
# Processed and replaced: ./testing_data1/661;14.png
# Processed and replaced: ./testing_data1/662;14.png
# Processed and replaced: ./testing_data1/663;15.png
# Processed and replaced: ./testing_data1/664;15.png
# Processed and replaced: ./testing_data1/665;15.png
# Processed and replaced: ./testing_data1/666;15.png
# Processed and replaced: ./testing_data1/667;15.png
# Processed and replaced: ./testing_data1/668;16.png
# Processed and replaced: ./testing_data1/669;16.png
# Processed and replaced: ./testing_data1/670;16.png
# Processed and replaced: ./testing_data1/671;16.png
# Processed and replaced: ./testing_data1/672;17.png
# Processed and replaced: ./testing_data1/673;17.png
# Processed and replaced: ./testing_data1/674;17.png
# Processed and replaced: ./testing_data1/675;17.png
# Processed and replaced: ./testing_data1/676;17.png
# Processed and replaced: ./testing_data1/677;17.png
# Processed and replaced: ./testing_data1/678;18.png
# Processed and replaced: ./testing_data1/679;18.png
# Processed and replaced: ./testing_data1/680;18.png
# Processed and replaced: ./testing_data1/681;18.png
# Processed and replaced: ./testing_data1/682;18.png
# Processed and replaced: ./testing_data1/683;18.png
# Processed and replaced: ./testing_data1/684;19.png
# Processed and replaced: ./testing_data1/685;20.png
# Processed and replaced: ./testing_data1/686;20.png
# Processed and replaced: ./testing_data1/687;20.png
# Processed and replaced: ./testing_data1/688;20.png
# Processed and replaced: ./testing_data1/689;21.png
# Processed and replaced: ./testing_data1/690;21.png
# Processed and replaced: ./testing_data1/691;21.png
# Processed and replaced: ./testing_data1/692;21.png
# Processed and replaced: ./testing_data1/693;21.png
# Processed and replaced: ./testing_data1/694;22.png
# Processed and replaced: ./testing_data1/695;22.png
# Processed and replaced: ./testing_data1/696;22.png
# Processed and replaced: ./testing_data1/697;22.png
# Processed and replaced: ./testing_data1/698;23.png
# Processed and replaced: ./testing_data1/699;23.png
# Processed and replaced: ./testing_data1/700;23.png
# Processed and replaced: ./testing_data1/701;23.png
# Processed and replaced: ./testing_data1/702;23.png
# Processed and replaced: ./testing_data1/703;24.png
# Processed and replaced: ./testing_data1/704;0.png
# Processed and replaced: ./testing_data1/705;0.png
# Processed and replaced: ./testing_data1/706;0.png
# Processed and replaced: ./testing_data1/707;0.png
# Processed and replaced: ./testing_data1/708;0.png
# Processed and replaced: ./testing_data1/709;1.png
# Processed and replaced: ./testing_data1/710;1.png
# Processed and replaced: ./testing_data1/711;1.png
# Processed and replaced: ./testing_data1/712;1.png
# Processed and replaced: ./testing_data1/713;1.png
# Processed and replaced: ./testing_data1/714;1.png
# Processed and replaced: ./testing_data1/715;1.png
# Processed and replaced: ./testing_data1/716;1.png
# Processed and replaced: ./testing_data1/717;2.png
# Processed and replaced: ./testing_data1/718;2.png
# Processed and replaced: ./testing_data1/719;2.png
# Processed and replaced: ./testing_data1/720;2.png
# Processed and replaced: ./testing_data1/721;2.png
# Processed and replaced: ./testing_data1/722;2.png
# Processed and replaced: ./testing_data1/723;3.png
# Processed and replaced: ./testing_data1/724;3.png
# Processed and replaced: ./testing_data1/725;3.png
# Processed and replaced: ./testing_data1/726;3.png
# Processed and replaced: ./testing_data1/727;4.png
# Processed and replaced: ./testing_data1/728;4.png
# Processed and replaced: ./testing_data1/729;4.png
# Processed and replaced: ./testing_data1/730;4.png
# Processed and replaced: ./testing_data1/731;4.png
# Processed and replaced: ./testing_data1/732;4.png
# Processed and replaced: ./testing_data1/733;4.png
# Processed and replaced: ./testing_data1/734;5.png
# Processed and replaced: ./testing_data1/735;5.png
# Processed and replaced: ./testing_data1/736;5.png
# Processed and replaced: ./testing_data1/737;5.png
# Processed and replaced: ./testing_data1/738;5.png
# Processed and replaced: ./testing_data1/739;6.png
# Processed and replaced: ./testing_data1/740;6.png
# Processed and replaced: ./testing_data1/741;6.png
# Processed and replaced: ./testing_data1/742;6.png
# Processed and replaced: ./testing_data1/743;7.png
# Processed and replaced: ./testing_data1/744;7.png
# Processed and replaced: ./testing_data1/745;7.png
# Processed and replaced: ./testing_data1/746;8.png
# Processed and replaced: ./testing_data1/747;8.png
# Processed and replaced: ./testing_data1/748;8.png
# Processed and replaced: ./testing_data1/749;8.png
# Processed and replaced: ./testing_data1/750;8.png
# Processed and replaced: ./testing_data1/751;8.png
# Processed and replaced: ./testing_data1/752;8.png
# Processed and replaced: ./testing_data1/753;9.png
# Processed and replaced: ./testing_data1/754;9.png
# Processed and replaced: ./testing_data1/755;9.png
# Processed and replaced: ./testing_data1/756;9.png
# Processed and replaced: ./testing_data1/757;9.png
# Processed and replaced: ./testing_data1/758;9.png
# Processed and replaced: ./testing_data1/759;10.png
# Processed and replaced: ./testing_data1/760;10.png
# Processed and replaced: ./testing_data1/761;10.png
# Processed and replaced: ./testing_data1/762;10.png
# Processed and replaced: ./testing_data1/763;10.png
# Processed and replaced: ./testing_data1/764;10.png
# Processed and replaced: ./testing_data1/765;11.png
# Processed and replaced: ./testing_data1/766;11.png
# Processed and replaced: ./testing_data1/767;11.png
# Processed and replaced: ./testing_data1/768;11.png
# Processed and replaced: ./testing_data1/769;11.png
# Processed and replaced: ./testing_data1/770;11.png
# Processed and replaced: ./testing_data1/771;11.png
# Processed and replaced: ./testing_data1/772;11.png
# Processed and replaced: ./testing_data1/773;12.png
# Processed and replaced: ./testing_data1/774;12.png
# Processed and replaced: ./testing_data1/775;12.png
# Processed and replaced: ./testing_data1/776;12.png
# Processed and replaced: ./testing_data1/777;12.png
# Processed and replaced: ./testing_data1/778;12.png
# Processed and replaced: ./testing_data1/779;12.png
# Processed and replaced: ./testing_data1/780;12.png
# Processed and replaced: ./testing_data1/781;12.png
# Processed and replaced: ./testing_data1/782;13.png
# Processed and replaced: ./testing_data1/783;13.png
# Processed and replaced: ./testing_data1/784;13.png
# Processed and replaced: ./testing_data1/785;13.png
# Processed and replaced: ./testing_data1/786;13.png
# Processed and replaced: ./testing_data1/787;13.png
# Processed and replaced: ./testing_data1/788;13.png
# Processed and replaced: ./testing_data1/789;14.png
# Processed and replaced: ./testing_data1/790;14.png
# Processed and replaced: ./testing_data1/791;14.png
# Processed and replaced: ./testing_data1/792;14.png
# Processed and replaced: ./testing_data1/793;14.png
# Processed and replaced: ./testing_data1/794;14.png
# Processed and replaced: ./testing_data1/795;14.png
# Processed and replaced: ./testing_data1/796;15.png
# Processed and replaced: ./testing_data1/797;15.png
# Processed and replaced: ./testing_data1/798;15.png
# Processed and replaced: ./testing_data1/799;15.png
# Processed and replaced: ./testing_data1/800;15.png
# Processed and replaced: ./testing_data1/801;15.png
# Processed and replaced: ./testing_data1/802;15.png
# Processed and replaced: ./testing_data1/803;16.png
# Processed and replaced: ./testing_data1/804;16.png
# Processed and replaced: ./testing_data1/805;16.png
# Processed and replaced: ./testing_data1/806;16.png
# Processed and replaced: ./testing_data1/807;16.png
# Processed and replaced: ./testing_data1/808;16.png
# Processed and replaced: ./testing_data1/809;17.png
# Processed and replaced: ./testing_data1/810;17.png
# Processed and replaced: ./testing_data1/811;17.png
# Processed and replaced: ./testing_data1/812;17.png
# Processed and replaced: ./testing_data1/813;17.png
# Processed and replaced: ./testing_data1/814;17.png
# Processed and replaced: ./testing_data1/815;18.png
# Processed and replaced: ./testing_data1/816;18.png
# Processed and replaced: ./testing_data1/817;18.png
# Processed and replaced: ./testing_data1/818;18.png
# Processed and replaced: ./testing_data1/819;18.png
# Processed and replaced: ./testing_data1/820;19.png
# Processed and replaced: ./testing_data1/821;19.png
# Processed and replaced: ./testing_data1/822;19.png
# Processed and replaced: ./testing_data1/823;19.png
# Processed and replaced: ./testing_data1/824;19.png
# Processed and replaced: ./testing_data1/825;19.png
# Processed and replaced: ./testing_data1/826;19.png
# Processed and replaced: ./testing_data1/827;19.png
# Processed and replaced: ./testing_data1/828;19.png
# Processed and replaced: ./testing_data1/829;20.png
# Processed and replaced: ./testing_data1/830;20.png
# Processed and replaced: ./testing_data1/831;20.png
# Processed and replaced: ./testing_data1/832;20.png
# Processed and replaced: ./testing_data1/833;20.png
# Processed and replaced: ./testing_data1/834;20.png
# Processed and replaced: ./testing_data1/835;21.png
# Processed and replaced: ./testing_data1/836;21.png
# Processed and replaced: ./testing_data1/837;21.png
# Processed and replaced: ./testing_data1/838;21.png
# Processed and replaced: ./testing_data1/839;21.png
# Processed and replaced: ./testing_data1/840;21.png
# Processed and replaced: ./testing_data1/841;21.png
# Processed and replaced: ./testing_data1/842;21.png
# Processed and replaced: ./testing_data1/843;21.png
# Processed and replaced: ./testing_data1/844;22.png
# Processed and replaced: ./testing_data1/845;22.png
# Processed and replaced: ./testing_data1/846;22.png
# Processed and replaced: ./testing_data1/847;22.png
# Processed and replaced: ./testing_data1/848;22.png
# Processed and replaced: ./testing_data1/849;23.png
# Processed and replaced: ./testing_data1/850;23.png
# Processed and replaced: ./testing_data1/851;23.png
# Processed and replaced: ./testing_data1/852;23.png
# Processed and replaced: ./testing_data1/853;23.png
# Processed and replaced: ./testing_data1/854;24.png
# Processed and replaced: ./testing_data2/855;0.png
# Processed and replaced: ./testing_data2/856;1.png
# Processed and replaced: ./testing_data2/857;1.png
# Processed and replaced: ./testing_data2/858;2.png
# Processed and replaced: ./testing_data2/859;2.png
# Processed and replaced: ./testing_data2/860;3.png
# Processed and replaced: ./testing_data2/861;4.png
# Processed and replaced: ./testing_data2/862;4.png
# Processed and replaced: ./testing_data2/863;4.png
# Processed and replaced: ./testing_data2/864;4.png
# Processed and replaced: ./testing_data2/865;5.png
# Processed and replaced: ./testing_data2/866;5.png
# Processed and replaced: ./testing_data2/867;5.png
# Processed and replaced: ./testing_data2/868;5.png
# Processed and replaced: ./testing_data2/869;6.png
# Processed and replaced: ./testing_data2/870;6.png
# Processed and replaced: ./testing_data2/871;7.png
# Processed and replaced: ./testing_data2/872;7.png
# Processed and replaced: ./testing_data2/873;7.png
# Processed and replaced: ./testing_data2/874;7.png
# Processed and replaced: ./testing_data2/875;8.png
# Processed and replaced: ./testing_data2/876;8.png
# Processed and replaced: ./testing_data2/877;8.png
# Processed and replaced: ./testing_data2/878;8.png
# Processed and replaced: ./testing_data2/879;8.png
# Processed and replaced: ./testing_data2/880;8.png
# Processed and replaced: ./testing_data2/881;8.png
# Processed and replaced: ./testing_data2/882;9.png
# Processed and replaced: ./testing_data2/883;9.png
# Processed and replaced: ./testing_data2/884;9.png
# Processed and replaced: ./testing_data2/885;9.png
# Processed and replaced: ./testing_data2/886;9.png
# Processed and replaced: ./testing_data2/887;9.png
# Processed and replaced: ./testing_data2/888;10.png
# Processed and replaced: ./testing_data2/889;10.png
# Processed and replaced: ./testing_data2/890;10.png
# Processed and replaced: ./testing_data2/891;11.png
# Processed and replaced: ./testing_data2/892;11.png
# Processed and replaced: ./testing_data2/893;11.png
# Processed and replaced: ./testing_data2/894;11.png
# Processed and replaced: ./testing_data2/895;11.png
# Processed and replaced: ./testing_data2/896;11.png
# Processed and replaced: ./testing_data2/897;11.png
# Processed and replaced: ./testing_data2/898;12.png
# Processed and replaced: ./testing_data2/899;12.png
# Processed and replaced: ./testing_data2/900;12.png
# Processed and replaced: ./testing_data2/901;12.png
# Processed and replaced: ./testing_data2/902;12.png
# Processed and replaced: ./testing_data2/903;12.png
# Processed and replaced: ./testing_data2/904;13.png
# Processed and replaced: ./testing_data2/905;13.png
# Processed and replaced: ./testing_data2/906;13.png
# Processed and replaced: ./testing_data2/907;13.png
# Processed and replaced: ./testing_data2/908;13.png
# Processed and replaced: ./testing_data2/909;13.png
# Processed and replaced: ./testing_data2/910;14.png
# Processed and replaced: ./testing_data2/911;14.png
# Processed and replaced: ./testing_data2/912;14.png
# Processed and replaced: ./testing_data2/913;14.png
# Processed and replaced: ./testing_data2/914;14.png
# Processed and replaced: ./testing_data2/915;15.png
# Processed and replaced: ./testing_data2/916;15.png
# Processed and replaced: ./testing_data2/917;15.png
# Processed and replaced: ./testing_data2/918;15.png
# Processed and replaced: ./testing_data2/919;15.png
# Processed and replaced: ./testing_data2/920;16.png
# Processed and replaced: ./testing_data2/921;16.png
# Processed and replaced: ./testing_data2/922;16.png
# Processed and replaced: ./testing_data2/923;17.png
# Processed and replaced: ./testing_data2/924;17.png
# Processed and replaced: ./testing_data2/925;17.png
# Processed and replaced: ./testing_data2/926;17.png
# Processed and replaced: ./testing_data2/927;17.png
# Processed and replaced: ./testing_data2/928;17.png
# Processed and replaced: ./testing_data2/929;17.png
# Processed and replaced: ./testing_data2/930;17.png
# Processed and replaced: ./testing_data2/931;17.png
# Processed and replaced: ./testing_data2/932;18.png
# Processed and replaced: ./testing_data2/933;18.png
# Processed and replaced: ./testing_data2/934;18.png
# Processed and replaced: ./testing_data2/935;18.png
# Processed and replaced: ./testing_data2/936;18.png
# Processed and replaced: ./testing_data2/937;18.png
# Processed and replaced: ./testing_data2/938;19.png
# Processed and replaced: ./testing_data2/939;19.png
# Processed and replaced: ./testing_data2/940;19.png
# Processed and replaced: ./testing_data2/941;19.png
# Processed and replaced: ./testing_data2/942;20.png
# Processed and replaced: ./testing_data2/943;0.png
# Processed and replaced: ./testing_data2/944;0.png
# Processed and replaced: ./testing_data2/945;0.png
# Processed and replaced: ./testing_data2/946;0.png
# Processed and replaced: ./testing_data2/947;1.png
# Processed and replaced: ./testing_data2/948;1.png
# Processed and replaced: ./testing_data2/949;1.png
# ...
# Processed and replaced: ./testing_data2/4959;13.png
# Processed and replaced: ./testing_data2/4960;13.png
# Processed and replaced: ./testing_data2/4961;13.png
# Processed and replaced: ./testing_data2/4962;13.png
# Processed and replaced: ./testing_data2/4963;13.png
# Processed and replaced: ./testing_data2/4964;14.png
# Processed and replaced: ./testing_data2/4965;14.png
# Processed and replaced: ./testing_data2/4966;14.png
# Processed and replaced: ./testing_data2/4967;14.png
# Processed and replaced: ./testing_data2/4968;14.png
# Processed and replaced: ./testing_data2/4969;14.png
# Processed and replaced: ./testing_data2/4970;14.png
# Processed and replaced: ./testing_data2/4971;14.png
# Processed and replaced: ./testing_data2/4972;15.png
# Processed and replaced: ./testing_data2/4973;15.png
# Processed and replaced: ./testing_data2/4974;15.png
# Processed and replaced: ./testing_data2/4975;15.png
# Processed and replaced: ./testing_data2/4976;16.png
# Processed and replaced: ./testing_data2/4977;16.png
# Processed and replaced: ./testing_data2/4978;16.png
# Processed and replaced: ./testing_data2/4979;16.png
# Processed and replaced: ./testing_data2/4980;16.png
# Processed and replaced: ./testing_data2/4981;16.png
# Processed and replaced: ./testing_data2/4982;17.png
# Processed and replaced: ./testing_data2/4983;17.png
# Processed and replaced: ./testing_data2/4984;17.png
# Processed and replaced: ./testing_data2/4985;17.png
# Processed and replaced: ./testing_data2/4986;17.png
# Processed and replaced: ./testing_data2/4987;18.png
# Processed and replaced: ./testing_data2/4988;18.png
# Processed and replaced: ./testing_data2/4989;18.png
# Processed and replaced: ./testing_data2/4990;18.png
# Processed and replaced: ./testing_data2/4991;19.png
# Processed and replaced: ./testing_data2/4992;19.png
# Processed and replaced: ./testing_data2/4993;19.png
# Processed and replaced: ./testing_data2/4994;19.png
# Processed and replaced: ./testing_data2/4995;19.png
# Processed and replaced: ./testing_data2/4996;20.png
# Processed and replaced: ./testing_data2/4997;20.png
# Processed and replaced: ./testing_data2/4998;20.png
# Processed and replaced: ./testing_data2/4999;20.png
# Processed and replaced: ./testing_data2/5000;20.png
# Processed and replaced: ./testing_data2/5001;20.png
# Processed and replaced: ./testing_data2/5002;20.png
# Processed and replaced: ./testing_data2/5003;20.png
# Processed and replaced: ./testing_data2/5004;21.png
# Processed and replaced: ./testing_data2/5005;21.png
# Processed and replaced: ./testing_data2/5006;21.png
# Processed and replaced: ./testing_data2/5007;21.png
# Processed and replaced: ./testing_data2/5008;21.png
# Processed and replaced: ./testing_data2/5009;22.png
# Processed and replaced: ./testing_data2/5010;22.png
# Processed and replaced: ./testing_data2/5011;22.png
# Processed and replaced: ./testing_data2/5012;22.png
# Processed and replaced: ./testing_data2/5013;22.png
# Processed and replaced: ./testing_data2/5014;22.png
# Processed and replaced: ./testing_data2/5015;23.png
# Processed and replaced: ./testing_data2/5016;23.png
# Processed and replaced: ./testing_data2/5017;23.png
# Processed and replaced: ./testing_data2/5018;23.png
# Processed and replaced: ./testing_data2/5019;23.png
# Processed and replaced: ./testing_data2/5020;24.png
# Processed and replaced: ./testing_data2/5021;0.png
# Processed and replaced: ./testing_data2/5022;0.png
# Processed and replaced: ./testing_data2/5023;0.png
# Processed and replaced: ./testing_data2/5024;0.png
# Processed and replaced: ./testing_data2/5025;0.png
# Processed and replaced: ./testing_data2/5026;0.png
# Processed and replaced: ./testing_data2/5027;0.png
# Processed and replaced: ./testing_data2/5028;1.png
# Processed and replaced: ./testing_data2/5029;1.png
# Processed and replaced: ./testing_data2/5030;1.png
# Processed and replaced: ./testing_data2/5031;1.png
# Processed and replaced: ./testing_data2/5032;1.png
# Processed and replaced: ./testing_data2/5033;1.png
# Processed and replaced: ./testing_data2/5034;2.png
# Processed and replaced: ./testing_data2/5035;2.png
# Processed and replaced: ./testing_data2/5036;2.png
# Processed and replaced: ./testing_data2/5037;2.png
# Processed and replaced: ./testing_data2/5038;2.png
# Processed and replaced: ./testing_data2/5039;3.png
# Processed and replaced: ./testing_data2/5040;3.png
# Processed and replaced: ./testing_data2/5041;3.png
# Processed and replaced: ./testing_data2/5042;3.png
# Processed and replaced: ./testing_data2/5043;3.png
# Processed and replaced: ./testing_data2/5044;3.png
# Processed and replaced: ./testing_data2/5045;4.png
# Processed and replaced: ./testing_data2/5046;4.png
# Processed and replaced: ./testing_data2/5047;4.png
# Processed and replaced: ./testing_data2/5048;4.png
# Processed and replaced: ./testing_data2/5049;4.png
# Processed and replaced: ./testing_data2/5050;5.png
# Processed and replaced: ./testing_data2/5051;5.png
# Processed and replaced: ./testing_data2/5052;5.png
# Processed and replaced: ./testing_data2/5053;5.png
# Processed and replaced: ./testing_data2/5054;5.png
# Processed and replaced: ./testing_data2/5055;5.png
# Processed and replaced: ./testing_data2/5056;5.png
# Processed and replaced: ./testing_data2/5057;5.png
# Processed and replaced: ./testing_data2/5058;6.png
# Processed and replaced: ./testing_data2/5059;7.png
# Processed and replaced: ./testing_data2/5060;7.png
# Processed and replaced: ./testing_data2/5061;7.png
# Processed and replaced: ./testing_data2/5062;7.png
# Processed and replaced: ./testing_data2/5063;7.png
# Processed and replaced: ./testing_data2/5064;7.png
# Processed and replaced: ./testing_data2/5065;8.png
# Processed and replaced: ./testing_data2/5066;8.png
# Processed and replaced: ./testing_data2/5067;8.png
# Processed and replaced: ./testing_data2/5068;8.png
# Processed and replaced: ./testing_data2/5069;8.png
# Processed and replaced: ./testing_data2/5070;8.png
# Processed and replaced: ./testing_data2/5071;9.png
# Processed and replaced: ./testing_data2/5072;9.png
# Processed and replaced: ./testing_data2/5073;9.png
# Processed and replaced: ./testing_data2/5074;10.png
# Processed and replaced: ./testing_data2/5075;10.png
# Processed and replaced: ./testing_data2/5076;10.png
# Processed and replaced: ./testing_data2/5077;10.png
# Processed and replaced: ./testing_data2/5078;10.png
# Processed and replaced: ./testing_data2/5079;10.png
# Processed and replaced: ./testing_data2/5080;11.png
# Processed and replaced: ./testing_data2/5081;11.png
# Processed and replaced: ./testing_data2/5082;11.png
# Processed and replaced: ./testing_data2/5083;11.png
# Processed and replaced: ./testing_data2/5084;11.png
# Processed and replaced: ./testing_data2/5085;11.png
# Processed and replaced: ./testing_data2/5086;12.png
# Processed and replaced: ./testing_data2/5087;12.png
# Processed and replaced: ./testing_data2/5088;12.png
# Processed and replaced: ./testing_data2/5089;12.png
# Processed and replaced: ./testing_data2/5090;12.png
# Processed and replaced: ./testing_data2/5091;12.png
# Processed and replaced: ./testing_data2/5092;12.png
# Processed and replaced: ./testing_data2/5093;13.png
# Processed and replaced: ./testing_data2/5094;13.png
# Processed and replaced: ./testing_data2/5095;14.png
# Processed and replaced: ./testing_data2/5096;14.png
# Processed and replaced: ./testing_data2/5097;14.png
# Processed and replaced: ./testing_data2/5098;14.png
# Processed and replaced: ./testing_data2/5099;15.png
# Processed and replaced: ./testing_data2/5100;15.png
# Processed and replaced: ./testing_data2/5101;15.png
# Processed and replaced: ./testing_data2/5102;15.png
# Processed and replaced: ./testing_data2/5103;15.png
# Processed and replaced: ./testing_data2/5104;15.png
# Processed and replaced: ./testing_data2/5105;16.png
# Processed and replaced: ./testing_data2/5106;16.png
# Processed and replaced: ./testing_data2/5107;16.png
# Processed and replaced: ./testing_data2/5108;16.png
# Processed and replaced: ./testing_data2/5109;16.png
# Processed and replaced: ./testing_data2/5110;16.png
# Processed and replaced: ./testing_data2/5111;16.png
# Processed and replaced: ./testing_data2/5112;17.png
# Processed and replaced: ./testing_data2/5113;17.png
# Processed and replaced: ./testing_data2/5114;17.png
# Processed and replaced: ./testing_data2/5115;17.png
# Processed and replaced: ./testing_data2/5116;17.png
# Processed and replaced: ./testing_data2/5117;18.png
# Processed and replaced: ./testing_data2/5118;18.png
# Processed and replaced: ./testing_data2/5119;18.png
# Processed and replaced: ./testing_data2/5120;18.png
# Processed and replaced: ./testing_data2/5121;18.png
# Processed and replaced: ./testing_data2/5122;18.png
# Processed and replaced: ./testing_data2/5123;19.png
# Processed and replaced: ./testing_data2/5124;19.png
# Processed and replaced: ./testing_data2/5125;19.png
# Processed and replaced: ./testing_data2/5126;19.png
# Processed and replaced: ./testing_data2/5127;19.png
# Processed and replaced: ./testing_data2/5128;20.png
# Processed and replaced: ./testing_data2/5129;20.png
# Processed and replaced: ./testing_data2/5130;20.png
# Processed and replaced: ./testing_data2/5131;20.png
# Processed and replaced: ./testing_data2/5132;20.png
# Processed and replaced: ./testing_data2/5133;20.png
# Processed and replaced: ./testing_data2/5134;20.png
# Processed and replaced: ./testing_data2/5135;21.png
# Processed and replaced: ./testing_data2/5136;21.png
# Processed and replaced: ./testing_data2/5137;21.png
# Processed and replaced: ./testing_data2/5138;21.png
# Processed and replaced: ./testing_data2/5139;21.png
# Processed and replaced: ./testing_data2/5140;21.png
# Processed and replaced: ./testing_data2/5141;21.png
# Processed and replaced: ./testing_data2/5142;22.png
# Processed and replaced: ./testing_data2/5143;23.png
# Processed and replaced: ./testing_data2/5144;23.png
# Processed and replaced: ./testing_data2/5145;23.png
# Processed and replaced: ./testing_data2/5146;23.png
# Processed and replaced: ./testing_data2/5147;23.png
# Processed and replaced: ./testing_data2/5148;24.png
# Processed and replaced: ./testing_data2/5149;0.png
# Processed and replaced: ./testing_data2/5150;0.png
# Processed and replaced: ./testing_data2/5151;0.png
# Processed and replaced: ./testing_data2/5152;0.png
# Processed and replaced: ./testing_data2/5153;0.png
# Processed and replaced: ./testing_data2/5154;0.png
# Processed and replaced: ./testing_data2/5155;0.png
# Processed and replaced: ./testing_data2/5156;0.png
# Processed and replaced: ./testing_data2/5157;1.png
# Processed and replaced: ./testing_data2/5158;1.png
# Processed and replaced: ./testing_data2/5159;2.png
# Processed and replaced: ./testing_data2/5160;2.png
# Processed and replaced: ./testing_data2/5161;2.png
# Processed and replaced: ./testing_data2/5162;2.png
# Processed and replaced: ./testing_data2/5163;2.png
# Processed and replaced: ./testing_data2/5164;2.png
# Processed and replaced: ./testing_data2/5165;2.png
# Processed and replaced: ./testing_data2/5166;2.png
# Processed and replaced: ./testing_data2/5167;3.png
# Processed and replaced: ./testing_data2/5168;3.png
# Processed and replaced: ./testing_data2/5169;3.png
# Processed and replaced: ./testing_data2/5170;3.png
# Processed and replaced: ./testing_data2/5171;3.png
# Processed and replaced: ./testing_data2/5172;4.png
# Processed and replaced: ./testing_data2/5173;4.png
# Processed and replaced: ./testing_data2/5174;4.png
# Processed and replaced: ./testing_data2/5175;4.png
# Processed and replaced: ./testing_data2/5176;4.png
# Processed and replaced: ./testing_data2/5177;4.png
# Processed and replaced: ./testing_data2/5178;4.png
# Processed and replaced: ./testing_data2/5179;5.png
# Processed and replaced: ./testing_data2/5180;5.png
# Processed and replaced: ./testing_data2/5181;5.png
# Processed and replaced: ./testing_data2/5182;5.png
# Processed and replaced: ./testing_data2/5183;5.png
# Processed and replaced: ./testing_data2/5184;5.png
# Processed and replaced: ./testing_data2/5185;6.png
# Processed and replaced: ./testing_data2/5186;6.png
# Processed and replaced: ./testing_data2/5187;7.png
# Processed and replaced: ./testing_data2/5188;7.png
# Processed and replaced: ./testing_data2/5189;7.png
# Processed and replaced: ./testing_data2/5190;7.png
# Processed and replaced: ./testing_data2/5191;8.png
# Processed and replaced: ./testing_data2/5192;8.png
# Processed and replaced: ./testing_data2/5193;8.png
# Processed and replaced: ./testing_data2/5194;9.png
# Processed and replaced: ./testing_data2/5195;9.png
# Processed and replaced: ./testing_data2/5196;9.png
# Processed and replaced: ./testing_data2/5197;10.png
# Processed and replaced: ./testing_data2/5198;10.png
# Processed and replaced: ./testing_data2/5199;10.png
# Processed and replaced: ./testing_data2/5200;10.png
# Processed and replaced: ./testing_data2/5201;10.png
# Processed and replaced: ./testing_data2/5202;11.png
# Processed and replaced: ./testing_data2/5203;11.png
# Processed and replaced: ./testing_data2/5204;11.png
# Processed and replaced: ./testing_data2/5205;11.png
# Processed and replaced: ./testing_data2/5206;11.png
# Processed and replaced: ./testing_data2/5207;12.png
# Processed and replaced: ./testing_data2/5208;12.png
# Processed and replaced: ./testing_data2/5209;12.png
# Processed and replaced: ./testing_data2/5210;12.png
# Processed and replaced: ./testing_data2/5211;12.png
# Processed and replaced: ./testing_data2/5212;13.png
# Processed and replaced: ./testing_data2/5213;13.png
# Processed and replaced: ./testing_data2/5214;13.png
# Processed and replaced: ./testing_data2/5215;13.png
# Processed and replaced: ./testing_data2/5216;13.png
# Processed and replaced: ./testing_data2/5217;13.png
# Processed and replaced: ./testing_data2/5218;14.png
# Processed and replaced: ./testing_data2/5219;14.png
# Processed and replaced: ./testing_data2/5220;14.png
# Processed and replaced: ./testing_data2/5221;14.png
# Processed and replaced: ./testing_data2/5222;14.png
# Processed and replaced: ./testing_data2/5223;14.png
# Processed and replaced: ./testing_data2/5224;15.png
# Processed and replaced: ./testing_data2/5225;15.png
# Processed and replaced: ./testing_data2/5226;15.png
# Processed and replaced: ./testing_data2/5227;16.png
# Processed and replaced: ./testing_data2/5228;16.png
# Processed and replaced: ./testing_data2/5229;16.png
# Processed and replaced: ./testing_data2/5230;16.png
# Processed and replaced: ./testing_data2/5231;16.png
# Processed and replaced: ./testing_data2/5232;17.png
# Processed and replaced: ./testing_data2/5233;17.png
# Processed and replaced: ./testing_data2/5234;17.png
# Processed and replaced: ./testing_data2/5235;17.png
# Processed and replaced: ./testing_data2/5236;18.png
# Processed and replaced: ./testing_data2/5237;18.png
# Processed and replaced: ./testing_data2/5238;18.png
# Processed and replaced: ./testing_data2/5239;18.png
# Processed and replaced: ./testing_data2/5240;19.png
# Processed and replaced: ./testing_data2/5241;19.png
# Processed and replaced: ./testing_data2/5242;19.png
# Processed and replaced: ./testing_data2/5243;19.png
# Processed and replaced: ./testing_data2/5244;19.png
# Processed and replaced: ./testing_data2/5245;19.png
# Processed and replaced: ./testing_data2/5246;19.png
# Processed and replaced: ./testing_data2/5247;20.png
# Processed and replaced: ./testing_data2/5248;20.png
# Processed and replaced: ./testing_data2/5249;20.png
# Processed and replaced: ./testing_data2/5250;20.png
# Processed and replaced: ./testing_data2/5251;20.png
# Processed and replaced: ./testing_data2/5252;20.png
# Processed and replaced: ./testing_data2/5253;20.png
# Processed and replaced: ./testing_data2/5254;21.png
# Processed and replaced: ./testing_data2/5255;21.png
# Processed and replaced: ./testing_data2/5256;21.png
# Processed and replaced: ./testing_data2/5257;21.png
# Processed and replaced: ./testing_data2/5258;21.png
# Processed and replaced: ./testing_data2/5259;21.png
# Processed and replaced: ./testing_data2/5260;22.png
# Processed and replaced: ./testing_data2/5261;22.png
# Processed and replaced: ./testing_data2/5262;22.png
# Processed and replaced: ./testing_data2/5263;22.png
# Processed and replaced: ./testing_data2/5264;23.png
# Processed and replaced: ./testing_data2/5265;23.png
# Processed and replaced: ./testing_data2/5266;23.png
# Processed and replaced: ./testing_data2/5267;23.png

# %% [markdown]
# # Gathering Training Data

# %% [markdown]
# ### Manually Corrected Training data

# %%
# Training data, corrrected manually
# !gdown 'https://drive.google.com/uc?id=1Gd9BWP0aixcSrs_vkDXJewd1sZEir8-m'
# !unzip outputCorrected.zip
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1Gd9BWP0aixcSrs_vkDXJewd1sZEir8-m
# To: /home/psyduck/GSOC/outputCorrected.zip
# 100%|██████████████████████████████████████| 1.81M/1.81M [00:00<00:00, 6.41MB/s]
# Archive:  outputCorrected.zip
#    creating: outputChanged/output/
#  extracting: outputChanged/output/a.png
#  extracting: outputChanged/output/abatio.png
#  extracting: outputChanged/output/abatirse.png
#  extracting: outputChanged/output/aborre.png
#  extracting: outputChanged/output/ac.png
#  extracting: outputChanged/output/acavallo.png
#  extracting: outputChanged/output/acciones.png
#  extracting: outputChanged/output/acometer.png
#  extracting: outputChanged/output/Acudireys.png
#  extracting: outputChanged/output/Acuдa.png
#   inflating: outputChanged/output/admitiendo.png
#  extracting: outputChanged/output/ador-.png
#   inflating: outputChanged/output/afeminados,.png
#  extracting: outputChanged/output/affi.png
#  extracting: outputChanged/output/afligi.png
#  extracting: outputChanged/output/afsi.png
#   inflating: outputChanged/output/agradecido.png
#   inflating: outputChanged/output/agravio.png
#   inflating: outputChanged/output/Agustin,.png
#  extracting: outputChanged/output/al (2).png
#  extracting: outputChanged/output/al.png
#  extracting: outputChanged/output/alabareys.png
#  extracting: outputChanged/output/Ale.png
#  extracting: outputChanged/output/alegre.png
#  extracting: outputChanged/output/alegrбa.png
#  extracting: outputChanged/output/alguna.png
#   inflating: outputChanged/output/alhombras,.png
#  extracting: outputChanged/output/alli.png
#  extracting: outputChanged/output/alma.png
#  extracting: outputChanged/output/alo.png
#  extracting: outputChanged/output/Alonso.png
#  extracting: outputChanged/output/Altar.png
#  extracting: outputChanged/output/Ambrosio,.png
#  extracting: outputChanged/output/amenaza.png
#  extracting: outputChanged/output/amigos.png
#  extracting: outputChanged/output/ampara.png
#  extracting: outputChanged/output/amparo.png
#  extracting: outputChanged/output/an.png
#  extracting: outputChanged/output/aдade.png
#  extracting: outputChanged/output/aдadire.png
#  extracting: outputChanged/output/Angel.png
#  extracting: outputChanged/output/Anibal,.png
#  extracting: outputChanged/output/animo.png
#  extracting: outputChanged/output/aдo.png
#  extracting: outputChanged/output/aдos.png
#   inflating: outputChanged/output/antemano.png
#  extracting: outputChanged/output/aora.png
#  extracting: outputChanged/output/apli-.png
#  extracting: outputChanged/output/apo.png
#  extracting: outputChanged/output/apostatar.png
#  extracting: outputChanged/output/apro.png
#   inflating: outputChanged/output/aprovecha-.png
#   inflating: outputChanged/output/aprovechar.png
#  extracting: outputChanged/output/aquel.png
#   inflating: outputChanged/output/aquellas.png
#   inflating: outputChanged/output/aquellos.png
#  extracting: outputChanged/output/Aqui.png
#  extracting: outputChanged/output/aquб.png
#  extracting: outputChanged/output/ar-.png
#  extracting: outputChanged/output/arduas.png
#  extracting: outputChanged/output/Aristo-.png
#   inflating: outputChanged/output/Aristoteles.png
#  extracting: outputChanged/output/armas.png
#  extracting: outputChanged/output/Arneses.png
#  extracting: outputChanged/output/Arre.png
#  extracting: outputChanged/output/Artifices.png
#  extracting: outputChanged/output/artilleria.png
#  extracting: outputChanged/output/Artus-.png
#   inflating: outputChanged/output/asentado.png
#   inflating: outputChanged/output/asistencia.png
#  extracting: outputChanged/output/asistid.png
#  extracting: outputChanged/output/assi.png
#  extracting: outputChanged/output/assiento.png
#  extracting: outputChanged/output/Assistid.png
#  extracting: outputChanged/output/assistio.png
#  extracting: outputChanged/output/atencion,y.png
#   inflating: outputChanged/output/atribuyen.png
#  extracting: outputChanged/output/Auftria.png
#  extracting: outputChanged/output/aunque.png
#  extracting: outputChanged/output/Aurelio.png
#   inflating: outputChanged/output/aventurada.png
#  extracting: outputChanged/output/averos.png
#  extracting: outputChanged/output/aveys.png
#  extracting: outputChanged/output/avia.png
#   inflating: outputChanged/output/aviendose.png
#  extracting: outputChanged/output/ay (2).png
#  extracting: outputChanged/output/ay.png
#  extracting: outputChanged/output/aya.png
#  extracting: outputChanged/output/ayudareys.png
#  extracting: outputChanged/output/Basilio.png
#   inflating: outputChanged/output/Bautismo,.png
#  extracting: outputChanged/output/baxeza.png
#  extracting: outputChanged/output/beneficio.png
#  extracting: outputChanged/output/beralidad.png
#   inflating: outputChanged/output/Bernardo.png
#  extracting: outputChanged/output/bertad.png
#  extracting: outputChanged/output/bien (2).png
#  extracting: outputChanged/output/Bien.png
#  extracting: outputChanged/output/bienes.png
#   inflating: outputChanged/output/bisposprocurad.png
#  extracting: outputChanged/output/bistes.png
#  extracting: outputChanged/output/bjen.png
#  extracting: outputChanged/output/ble.png
#  extracting: outputChanged/output/blen.png
#   inflating: outputChanged/output/bligados.png
#  extracting: outputChanged/output/bolver.png
#  extracting: outputChanged/output/bondad.png
#  extracting: outputChanged/output/bre.png
#  extracting: outputChanged/output/brindis.png
#  extracting: outputChanged/output/Bruno.png
#  extracting: outputChanged/output/buen.png
#  extracting: outputChanged/output/buena.png
#  extracting: outputChanged/output/Buendia.png
#  extracting: outputChanged/output/buenos.png
#  extracting: outputChanged/output/Bullon,.png
#  extracting: outputChanged/output/bus.png
#  extracting: outputChanged/output/busca,.png
#  extracting: outputChanged/output/buscando.png
#  extracting: outputChanged/output/cabezas.png
#  extracting: outputChanged/output/caciвn,.png
#  extracting: outputChanged/output/cada.png
#  extracting: outputChanged/output/cadaver.png
#   inflating: outputChanged/output/calamidades.png
#  extracting: outputChanged/output/calidad.png
#  extracting: outputChanged/output/cama.png
#  extracting: outputChanged/output/camino.png
#   inflating: outputChanged/output/campal.png
#  extracting: outputChanged/output/candalo.png
#  extracting: outputChanged/output/cando.png
#  extracting: outputChanged/output/cante.png
#  extracting: outputChanged/output/capaz.png
#   inflating: outputChanged/output/Cardinales,y.png
#  extracting: outputChanged/output/care.png
#  extracting: outputChanged/output/Carlo.png
#  extracting: outputChanged/output/casa.png
#  extracting: outputChanged/output/caso.png
#  extracting: outputChanged/output/casos.png
#  extracting: outputChanged/output/Castilla,.png
#  extracting: outputChanged/output/Castillo.png
#  extracting: outputChanged/output/Caton,.png
#  extracting: outputChanged/output/Cavalleros,y.png
#  extracting: outputChanged/output/cays,.png
#  extracting: outputChanged/output/celentes.png
#  extracting: outputChanged/output/cencia,y.png
#  extracting: outputChanged/output/censuras.png
#  extracting: outputChanged/output/cente.png
#   inflating: outputChanged/output/ceremonias.png
#  extracting: outputChanged/output/ceron,.png
#  extracting: outputChanged/output/ces.png
#  extracting: outputChanged/output/Cesar,Sci-.png
#  extracting: outputChanged/output/chia.png
#  extracting: outputChanged/output/chos (2).png
#  extracting: outputChanged/output/Christiana.png
#  extracting: outputChanged/output/Ci.png
#  extracting: outputChanged/output/cia.png
#  extracting: outputChanged/output/Cicero.png
#  extracting: outputChanged/output/Ciceron,.png
#  extracting: outputChanged/output/cidentes.png
#  extracting: outputChanged/output/cierto.png
#  extracting: outputChanged/output/cimiento.png
#  extracting: outputChanged/output/cio.png
#  extracting: outputChanged/output/cion.png
#  extracting: outputChanged/output/cionales.png
#  extracting: outputChanged/output/cipio,.png
#  extracting: outputChanged/output/civil.png
#  extracting: outputChanged/output/clemencia.png
#  extracting: outputChanged/output/Clerigos,.png
#  extracting: outputChanged/output/co.png
#  extracting: outputChanged/output/cobreys.png
#  extracting: outputChanged/output/cochero.png
#  extracting: outputChanged/output/cofo,y.png
#  extracting: outputChanged/output/colgar,.png
#   inflating: outputChanged/output/colgarle.png
#  extracting: outputChanged/output/combites,.png
#   inflating: outputChanged/output/compostura.png
#  extracting: outputChanged/output/comun.png
#   inflating: outputChanged/output/comunicaciвn.png
#  extracting: outputChanged/output/comunion.png
#  extracting: outputChanged/output/con (1).png
#  extracting: outputChanged/output/con (2).png
#  extracting: outputChanged/output/con (3).png
#   inflating: outputChanged/output/conciencia.png
#  extracting: outputChanged/output/conclu.png
#  extracting: outputChanged/output/condederа.png
#  extracting: outputChanged/output/Condesa.png
#   inflating: outputChanged/output/conforma.png
#   inflating: outputChanged/output/conformidad.png
#  extracting: outputChanged/output/connatural.png
#  extracting: outputChanged/output/conocen.png
#  extracting: outputChanged/output/conocer.png
#  extracting: outputChanged/output/conocida.png
#  extracting: outputChanged/output/conocido.png
#  extracting: outputChanged/output/conocieron.png
#  extracting: outputChanged/output/conocio.png
#  extracting: outputChanged/output/conozcays.png
#   inflating: outputChanged/output/Consejos.png
#  extracting: outputChanged/output/conserva.png
#   inflating: outputChanged/output/consideracion.png
#   inflating: outputChanged/output/Considerad.png
#  extracting: outputChanged/output/consintays.png
#  extracting: outputChanged/output/consolaciones.png
#   inflating: outputChanged/output/constancia.png
#   inflating: outputChanged/output/Constantino.png
#   inflating: outputChanged/output/contentandose.png
#  extracting: outputChanged/output/contenteys.png
#  extracting: outputChanged/output/conti.png
#  extracting: outputChanged/output/Continencia.png
#  extracting: outputChanged/output/continuo.png
#  extracting: outputChanged/output/contra.png
#  extracting: outputChanged/output/conveniente.png
#   inflating: outputChanged/output/Conventos.png
#  extracting: outputChanged/output/coponer.png
#  extracting: outputChanged/output/coracon.png
#  extracting: outputChanged/output/corazon.png
#  extracting: outputChanged/output/corrieren.png
#  extracting: outputChanged/output/cortesia.png
#  extracting: outputChanged/output/cortesias.png
#  extracting: outputChanged/output/cosa.png
#  extracting: outputChanged/output/cosas.png
#   inflating: outputChanged/output/costumbres.png
#  extracting: outputChanged/output/creacion.png
#  extracting: outputChanged/output/creed.png
#   inflating: outputChanged/output/creyendo.png
#  extracting: outputChanged/output/criado (2).png
#  extracting: outputChanged/output/criados.png
#  extracting: outputChanged/output/crian.png
#  extracting: outputChanged/output/crio.png
#   inflating: outputChanged/output/cualquiera.png
#  extracting: outputChanged/output/cubran.png
#  extracting: outputChanged/output/cubrir.png
#  extracting: outputChanged/output/cuenta.png
#   inflating: outputChanged/output/cumplieredes,.png
#   inflating: outputChanged/output/cumplimiento.png
#  extracting: outputChanged/output/cumplir.png
#  extracting: outputChanged/output/curioso.png
#  extracting: outputChanged/output/cuva.png
#  extracting: outputChanged/output/cuya.png
#  extracting: outputChanged/output/cuydar.png
#  extracting: outputChanged/output/da.png
#  extracting: outputChanged/output/dad.png
#  extracting: outputChanged/output/dadles.png
#  extracting: outputChanged/output/dados.png
#  extracting: outputChanged/output/dan.png
#  extracting: outputChanged/output/dar.png
#  extracting: outputChanged/output/darme.png
#  extracting: outputChanged/output/daros.png
#  extracting: outputChanged/output/das.png
#  extracting: outputChanged/output/David.png
#  extracting: outputChanged/output/de (2).png
#  extracting: outputChanged/output/de (3).png
#  extracting: outputChanged/output/de (4).png
#  extracting: outputChanged/output/de (5).png
#  extracting: outputChanged/output/de (6).png
#  extracting: outputChanged/output/de (7).png
#  extracting: outputChanged/output/De.png
#   inflating: outputChanged/output/DEDICATORIA.png
#   inflating: outputChanged/output/defcomulgado.png
#  extracting: outputChanged/output/defde.png
#  extracting: outputChanged/output/del (2).png
#  extracting: outputChanged/output/del (3).png
#  extracting: outputChanged/output/del.png
#  extracting: outputChanged/output/delan-.png
#  extracting: outputChanged/output/della.png
#  extracting: outputChanged/output/dellas.png
#  extracting: outputChanged/output/dencia,.png
#   inflating: outputChanged/output/depravadas.png
#  extracting: outputChanged/output/dera.png
#  extracting: outputChanged/output/derillo.png
#  extracting: outputChanged/output/des-.png
#   inflating: outputChanged/output/descubierto.png
#  extracting: outputChanged/output/descuento.png
#   inflating: outputChanged/output/descuydeys.png
#  extracting: outputChanged/output/desdicha.png
#   inflating: outputChanged/output/desprecio.png
#  extracting: outputChanged/output/despuВs.png
#  extracting: outputChanged/output/desseando.png
#  extracting: outputChanged/output/dessear.png
#  extracting: outputChanged/output/desseo.png
#  extracting: outputChanged/output/desta.png
#  extracting: outputChanged/output/destas.png
#  extracting: outputChanged/output/desto.png
#  extracting: outputChanged/output/destos.png
#  extracting: outputChanged/output/desuelo.png
#  extracting: outputChanged/output/desve.png
#  extracting: outputChanged/output/deuda,y.png
#  extracting: outputChanged/output/deue.png
#  extracting: outputChanged/output/deveys.png
#  extracting: outputChanged/output/devidas.png
#  extracting: outputChanged/output/devo.png
#  extracting: outputChanged/output/devotos.png
#  extracting: outputChanged/output/devria.png
#  extracting: outputChanged/output/dexaros.png
#  extracting: outputChanged/output/dexeys.png
#  extracting: outputChanged/output/dexo.png
#  extracting: outputChanged/output/dexв.png
#  extracting: outputChanged/output/di-.png
#  extracting: outputChanged/output/dia,.png
#  extracting: outputChanged/output/dicha.png
#  extracting: outputChanged/output/dichoso.png
#  extracting: outputChanged/output/diencia.png
#  extracting: outputChanged/output/diendose.png
#  extracting: outputChanged/output/diera.png
#  extracting: outputChanged/output/dieron.png
#   inflating: outputChanged/output/diferencias,.png
#  extracting: outputChanged/output/dificil.png
#   inflating: outputChanged/output/dignidad.png
#  extracting: outputChanged/output/digno.png
#  extracting: outputChanged/output/Digo.png
#  extracting: outputChanged/output/dio.png
#  extracting: outputChanged/output/Dios.png
#  extracting: outputChanged/output/discursos.png
#  extracting: outputChanged/output/dispa.png
#   inflating: outputChanged/output/distraerlos.png
#  extracting: outputChanged/output/divina.png
#  extracting: outputChanged/output/Divino.png
#  extracting: outputChanged/output/divinos.png
#  extracting: outputChanged/output/dixo (2).png
#  extracting: outputChanged/output/dixo.png
#  extracting: outputChanged/output/dize.png
#  extracting: outputChanged/output/do.png
#  extracting: outputChanged/output/doce.png
#  extracting: outputChanged/output/Doctores.png
#  extracting: outputChanged/output/Doctos.png
#  extracting: outputChanged/output/documen.png
#  extracting: outputChanged/output/dola.png
#  extracting: outputChanged/output/dole,.png
#  extracting: outputChanged/output/dolores.png
#  extracting: outputChanged/output/dominio.png
#  extracting: outputChanged/output/Don.png
#  extracting: outputChanged/output/Doдa.png
#  extracting: outputChanged/output/donde.png
#  extracting: outputChanged/output/dos,y.png
#  extracting: outputChanged/output/dos.png
#  extracting: outputChanged/output/dres.png
#  extracting: outputChanged/output/e.png
#   inflating: outputChanged/output/Eclesiastico.png
#  extracting: outputChanged/output/educacion.png
#  extracting: outputChanged/output/educaciвn.png
#  extracting: outputChanged/output/effe.png
#  extracting: outputChanged/output/efte.png
#  extracting: outputChanged/output/Eibie.png
#  extracting: outputChanged/output/el (2).png
#  extracting: outputChanged/output/el (3).png
#  extracting: outputChanged/output/Вl,.png
#  extracting: outputChanged/output/el.png
#  extracting: outputChanged/output/elegir.png
#  extracting: outputChanged/output/ella,.png
#  extracting: outputChanged/output/ellas.png
#   inflating: outputChanged/output/ello,alumbradle.png
#  extracting: outputChanged/output/ellos (2).png
#  extracting: outputChanged/output/ellos.png
#  extracting: outputChanged/output/em-.png
#  extracting: outputChanged/output/Em.png
#  extracting: outputChanged/output/emas,.png
#  extracting: outputChanged/output/en (2).png
#  extracting: outputChanged/output/en (3).png
#  extracting: outputChanged/output/en (4).png
#  extracting: outputChanged/output/en (5).png
#  extracting: outputChanged/output/en (6).png
#  extracting: outputChanged/output/en (7).png
#  extracting: outputChanged/output/en (8).png
#  extracting: outputChanged/output/en (9).png
#  extracting: outputChanged/output/en.png
#  extracting: outputChanged/output/en-.png
#   inflating: outputChanged/output/enamorados,.png
#  extracting: outputChanged/output/encamina-.png
#  extracting: outputChanged/output/encaminar.png
#  extracting: outputChanged/output/encar.png
#  extracting: outputChanged/output/encontran-.png
#  extracting: outputChanged/output/enfadados.png
#  extracting: outputChanged/output/enfermos.png
#  extracting: outputChanged/output/enga.png
#   inflating: outputChanged/output/engaдado.png
#   inflating: outputChanged/output/engaдar.png
#   inflating: outputChanged/output/engrandecen.png
#   inflating: outputChanged/output/engrandezido.png
#  extracting: outputChanged/output/enseдan.png
#  extracting: outputChanged/output/ente.png
#  extracting: outputChanged/output/enternezer.png
#  extracting: outputChanged/output/entienden.png
#  extracting: outputChanged/output/enton-.png
#   inflating: outputChanged/output/entraдable.png
#  extracting: outputChanged/output/entrar.png
#   inflating: outputChanged/output/entregandose.png
#  extracting: outputChanged/output/entriste-.png
#   inflating: outputChanged/output/equidad.png
#  extracting: outputChanged/output/era.png
#  extracting: outputChanged/output/ero.png
#  extracting: outputChanged/output/es (2).png
#  extracting: outputChanged/output/es (3).png
#  extracting: outputChanged/output/es.png
#  extracting: outputChanged/output/escribe.png
#  extracting: outputChanged/output/escrito.png
#  extracting: outputChanged/output/Escritura.png
#  extracting: outputChanged/output/Espaдa.png
#   inflating: outputChanged/output/esperanza.png
#  extracting: outputChanged/output/Espero.png
#  extracting: outputChanged/output/espiri-.png
#  extracting: outputChanged/output/Espбri.png
#  extracting: outputChanged/output/espiritu.png
#  extracting: outputChanged/output/Esta.png
#  extracting: outputChanged/output/estad.png
#  extracting: outputChanged/output/Estado.png
#  extracting: outputChanged/output/Estados,.png
#  extracting: outputChanged/output/estando.png
#  extracting: outputChanged/output/estar.png
#  extracting: outputChanged/output/estas.png
#  extracting: outputChanged/output/estava.png
#   inflating: outputChanged/output/este.png
#   inflating: outputChanged/output/Estephano.png
#  extracting: outputChanged/output/esteys.png
#  extracting: outputChanged/output/esti.png
#  extracting: outputChanged/output/estima.png
#  extracting: outputChanged/output/estos.png
#  extracting: outputChanged/output/estrecha.png
#   inflating: outputChanged/output/estudiosidad.png
#  extracting: outputChanged/output/eterna.png
#  extracting: outputChanged/output/ex-.png
#  extracting: outputChanged/output/excede.png
#  extracting: outputChanged/output/exceder.png
#   inflating: outputChanged/output/excelencia.png
#   inflating: outputChanged/output/excelente.png
#  extracting: outputChanged/output/executaros.png
#  extracting: outputChanged/output/exem.png
#   inflating: outputChanged/output/exempciones.png
#   inflating: outputChanged/output/exemplar.png
#  extracting: outputChanged/output/exerci-.png
#  extracting: outputChanged/output/exercicio.png
#  extracting: outputChanged/output/exercitan.png
#  extracting: outputChanged/output/exercitar.png
#  extracting: outputChanged/output/exorto.png
#  extracting: outputChanged/output/ey.png
#  extracting: outputChanged/output/eyes.png
#  extracting: outputChanged/output/F.png
#  extracting: outputChanged/output/fa-.png
#  extracting: outputChanged/output/factibles.png
#   inflating: outputChanged/output/fagacidad,.png
#  extracting: outputChanged/output/falta.png
#  extracting: outputChanged/output/faltan.png
#   inflating: outputChanged/output/faltandoles.png
#  extracting: outputChanged/output/faltar.png
#  extracting: outputChanged/output/falua,A.png
#  extracting: outputChanged/output/familiares.png
#   inflating: outputChanged/output/Familias.png
#  extracting: outputChanged/output/fas (2).png
#  extracting: outputChanged/output/fas.png
#  extracting: outputChanged/output/favor.png
#  extracting: outputChanged/output/fe (2).png
#  extracting: outputChanged/output/Fe.png
#  extracting: outputChanged/output/fealdad.png
#  extracting: outputChanged/output/feccion.png
#  extracting: outputChanged/output/fegun.png
#  extracting: outputChanged/output/fermedad.png
#  extracting: outputChanged/output/feruid.png
#  extracting: outputChanged/output/festasse.png
#  extracting: outputChanged/output/feuar.png
#  extracting: outputChanged/output/ffiones.png
#  extracting: outputChanged/output/fi.png
#  extracting: outputChanged/output/Fiesta,.png
#  extracting: outputChanged/output/fiestas.png
#  extracting: outputChanged/output/fin.png
#  extracting: outputChanged/output/fineza.png
#  extracting: outputChanged/output/fino.png
#  extracting: outputChanged/output/fintiendo.png
#  extracting: outputChanged/output/fluos.png
#  extracting: outputChanged/output/fola.png
#  extracting: outputChanged/output/folo.png
#  extracting: outputChanged/output/for-.png
#  extracting: outputChanged/output/Fortaleza.png
#  extracting: outputChanged/output/forzosa.png
#  extracting: outputChanged/output/forzosos.png
#  extracting: outputChanged/output/fos (2).png
#  extracting: outputChanged/output/fos.png
#  extracting: outputChanged/output/fu.png
#  extracting: outputChanged/output/fuerza.png
#  extracting: outputChanged/output/fues.png
#  extracting: outputChanged/output/fuesse.png
#  extracting: outputChanged/output/funda.png
#   inflating: outputChanged/output/fundadores.png
#   inflating: outputChanged/output/fundamen.png
#   inflating: outputChanged/output/fundandole.png
#  extracting: outputChanged/output/fuya.png
#   inflating: outputChanged/output/gacion.png
#   inflating: outputChanged/output/gaciones.png
#  extracting: outputChanged/output/galas,.png
#  extracting: outputChanged/output/gana.png
#   inflating: outputChanged/output/ganareys.png
#   inflating: outputChanged/output/ganaron.png
#  extracting: outputChanged/output/gаndole.png
#  extracting: outputChanged/output/gas-.png
#  extracting: outputChanged/output/gays.png
#  extracting: outputChanged/output/ge.png
#  extracting: outputChanged/output/gen.png
#  extracting: outputChanged/output/general.png
#   inflating: outputChanged/output/generoso.png
#  extracting: outputChanged/output/gente.png
#  extracting: outputChanged/output/Gentiles.png
#   inflating: outputChanged/output/Gentilica.png
#   inflating: outputChanged/output/gestad.png
#   inflating: outputChanged/output/giones.png
#  extracting: outputChanged/output/glesia.png
#  extracting: outputChanged/output/gloria.png
#  extracting: outputChanged/output/gra-.png
#  extracting: outputChanged/output/gracia.png
#  extracting: outputChanged/output/gracio.png
#  extracting: outputChanged/output/gran.png
#   inflating: outputChanged/output/grande,.png
#   inflating: outputChanged/output/grandeza.png
#   inflating: outputChanged/output/grangear.png
#  extracting: outputChanged/output/grato.png
#  extracting: outputChanged/output/graue.png
#  extracting: outputChanged/output/Guarda.png
#  extracting: outputChanged/output/guerra.png
#  extracting: outputChanged/output/guia,.png
#  extracting: outputChanged/output/gunos.png
#  extracting: outputChanged/output/gusto.png
#  extracting: outputChanged/output/ha.png
#  extracting: outputChanged/output/habito.png
#  extracting: outputChanged/output/hablad.png
#  extracting: outputChanged/output/hafta.png
#  extracting: outputChanged/output/hago.png
#  extracting: outputChanged/output/hallan.png
#  extracting: outputChanged/output/hallar.png
#  extracting: outputChanged/output/hallaredes.png
#  extracting: outputChanged/output/hallo.png
#  extracting: outputChanged/output/han.png
#  extracting: outputChanged/output/hareys.png
#  extracting: outputChanged/output/haze (2).png
#  extracting: outputChanged/output/hazed.png
#  extracting: outputChanged/output/hazen.png
#  extracting: outputChanged/output/hazer (2).png
#  extracting: outputChanged/output/hazer.png
#  extracting: outputChanged/output/hazerlos.png
#  extracting: outputChanged/output/hazerse.png
#  extracting: outputChanged/output/hazienda.png
#  extracting: outputChanged/output/he.png
#  extracting: outputChanged/output/hecho.png
#  extracting: outputChanged/output/Her.png
#  extracting: outputChanged/output/here.png
#   inflating: outputChanged/output/heredada,.png
#  extracting: outputChanged/output/herencia.png
#  extracting: outputChanged/output/hermanos.png
#  extracting: outputChanged/output/hijo.png
#  extracting: outputChanged/output/hijos.png
#  extracting: outputChanged/output/hin-.png
#  extracting: outputChanged/output/hizo.png
#  extracting: outputChanged/output/hombre.png
#  extracting: outputChanged/output/honra.png
#  extracting: outputChanged/output/hora.png
#  extracting: outputChanged/output/horror.png
#  extracting: outputChanged/output/hu.png
#  extracting: outputChanged/output/huesped.png
#  extracting: outputChanged/output/huma.png
#   inflating: outputChanged/output/huvieredes.png
#  extracting: outputChanged/output/huyr.png
#  extracting: outputChanged/output/IE.png
#   inflating: outputChanged/output/Iglesias.png
#  extracting: outputChanged/output/illus-.png
#  extracting: outputChanged/output/Ilustres.png
#  extracting: outputChanged/output/im.png
#  extracting: outputChanged/output/imitando.png
#   inflating: outputChanged/output/immortal.png
#  extracting: outputChanged/output/importantes.png
#  extracting: outputChanged/output/in.png
#   inflating: outputChanged/output/incansable.png
#  extracting: outputChanged/output/incentivo.png
#  extracting: outputChanged/output/inchado.png
#  extracting: outputChanged/output/inchirla.png
#  extracting: outputChanged/output/incluye.png
#  extracting: outputChanged/output/incurrir.png
#   inflating: outputChanged/output/indecencia.png
#  extracting: outputChanged/output/indignam.png
#   inflating: outputChanged/output/individuaros.png
#  extracting: outputChanged/output/inestimables.png
#  extracting: outputChanged/output/Ingles.png
#   inflating: outputChanged/output/injustamente.png
#   inflating: outputChanged/output/inquietos.png
#  extracting: outputChanged/output/Inquisi.png
#  extracting: outputChanged/output/instante.png
#  extracting: outputChanged/output/interior.png
#   inflating: outputChanged/output/interiormente.png
#  extracting: outputChanged/output/introdu-.png
#  extracting: outputChanged/output/introduzirse.png
#  extracting: outputChanged/output/io.png
#  extracting: outputChanged/output/Italia.png
#  extracting: outputChanged/output/Iuliaco,.png
#  extracting: outputChanged/output/Iusticia.png
#  extracting: outputChanged/output/jamas.png
#   inflating: outputChanged/output/juftamete.png
#  extracting: outputChanged/output/jun.png
#  extracting: outputChanged/output/jus-.png
#  extracting: outputChanged/output/justicia.png
#   inflating: outputChanged/output/justificacion.png
#   inflating: outputChanged/output/justos.png
#  extracting: outputChanged/output/juyzios.png
#   inflating: outputChanged/output/juzgadotan.png
#   inflating: outputChanged/output/juzgando.png
#  extracting: outputChanged/output/juzgar.png
#  extracting: outputChanged/output/la (2).png
#  extracting: outputChanged/output/la (3).png
#  extracting: outputChanged/output/la (4).png
#  extracting: outputChanged/output/la.png
#   inflating: outputChanged/output/labios,atentos.png
#  extracting: outputChanged/output/lares.png
#   inflating: outputChanged/output/largamente.png
#  extracting: outputChanged/output/largos.png
#  extracting: outputChanged/output/las (2).png
#  extracting: outputChanged/output/las (3).png
#  extracting: outputChanged/output/las.png
#  extracting: outputChanged/output/lastimosas.png
#  extracting: outputChanged/output/Leon.png
#  extracting: outputChanged/output/les.png
#  extracting: outputChanged/output/leve.png
#  extracting: outputChanged/output/lexos.png
#  extracting: outputChanged/output/li (2).png
#  extracting: outputChanged/output/li.png
#   inflating: outputChanged/output/Liberalidad.png
#  extracting: outputChanged/output/libreys.png
#  extracting: outputChanged/output/licencio.png
#  extracting: outputChanged/output/limos.png
#  extracting: outputChanged/output/limosneros.png
#   inflating: outputChanged/output/limpiarle.png
#  extracting: outputChanged/output/limpio,.png
#  extracting: outputChanged/output/lla.png
#  extracting: outputChanged/output/llamado.png
#  extracting: outputChanged/output/llega.png
#   inflating: outputChanged/output/llegando.png
#  extracting: outputChanged/output/llegareys.png
#  extracting: outputChanged/output/llorado.png
#  extracting: outputChanged/output/llos.png
#  extracting: outputChanged/output/lo (2).png
#  extracting: outputChanged/output/lo.png
#  extracting: outputChanged/output/locos.png
#  extracting: outputChanged/output/lorio.png
#  extracting: outputChanged/output/los (2).png
#  extracting: outputChanged/output/los (3).png
#  extracting: outputChanged/output/los (4).png
#  extracting: outputChanged/output/los (5).png
#  extracting: outputChanged/output/LOS.png
#  extracting: outputChanged/output/lugares.png
#  extracting: outputChanged/output/lum-.png
#  extracting: outputChanged/output/lumi-.png
#  extracting: outputChanged/output/lumnas.png
#  extracting: outputChanged/output/Luys.png
#  extracting: outputChanged/output/luz.png
#  extracting: outputChanged/output/ma.png
#  extracting: outputChanged/output/mable.png
#  extracting: outputChanged/output/macion.png
#  extracting: outputChanged/output/mad.png
#  extracting: outputChanged/output/Madre.png
#  extracting: outputChanged/output/Maestro.png
#   inflating: outputChanged/output/Magestad.png
#  extracting: outputChanged/output/magna-.png
#  extracting: outputChanged/output/Magno.png
#  extracting: outputChanged/output/mal.png
#   inflating: outputChanged/output/maliciosos.png
#  extracting: outputChanged/output/mandando.png
#  extracting: outputChanged/output/mani.png
#   inflating: outputChanged/output/manifiesta,pues.png
#  extracting: outputChanged/output/manos.png
#  extracting: outputChanged/output/Manual.png
#   inflating: outputChanged/output/maquinas.png
#  extracting: outputChanged/output/Marco.png
#  extracting: outputChanged/output/Maria.png
#  extracting: outputChanged/output/mas (2).png
#  extracting: outputChanged/output/Mas.png
#  extracting: outputChanged/output/mаs.png
#  extracting: outputChanged/output/materia.png
#  extracting: outputChanged/output/mayor.png
#   inflating: outputChanged/output/mayores.png
#  extracting: outputChanged/output/medio.png
#  extracting: outputChanged/output/mejor.png
#  extracting: outputChanged/output/memoria.png
#  extracting: outputChanged/output/menes.png
#  extracting: outputChanged/output/menos.png
#   inflating: outputChanged/output/menosprecio.png
#  extracting: outputChanged/output/mentado.png
#  extracting: outputChanged/output/mercedes.png
#  extracting: outputChanged/output/merecer.png
#  extracting: outputChanged/output/mesa,.png
#  extracting: outputChanged/output/meses.png
#  extracting: outputChanged/output/mi-.png
#  extracting: outputChanged/output/mildad.png
#   inflating: outputChanged/output/miliaridad.png
#   inflating: outputChanged/output/ministros.png
#  extracting: outputChanged/output/mios.png
#  extracting: outputChanged/output/mirad.png
#   inflating: outputChanged/output/misericordia,la.png
#  extracting: outputChanged/output/misma.png
#  extracting: outputChanged/output/mismas.png
#  extracting: outputChanged/output/mismo.png
#  extracting: outputChanged/output/Missa.png
#  extracting: outputChanged/output/Misterio.png
#  extracting: outputChanged/output/mitas.png
#  extracting: outputChanged/output/mo-.png
#  extracting: outputChanged/output/monedas.png
#  extracting: outputChanged/output/Morales.png
#  extracting: outputChanged/output/mortales.png
#  extracting: outputChanged/output/mostrarles.png
#  extracting: outputChanged/output/mostruosas.png
#  extracting: outputChanged/output/motivos.png
#  extracting: outputChanged/output/mucha.png
#  extracting: outputChanged/output/muchoq.png
#  extracting: outputChanged/output/muchos.png
#  extracting: outputChanged/output/muerte.png
#  extracting: outputChanged/output/muestra.png
#  extracting: outputChanged/output/muestras.png
#  extracting: outputChanged/output/mugeres.png
#  extracting: outputChanged/output/muy.png
#  extracting: outputChanged/output/na,y.png
#  extracting: outputChanged/output/nace.png
#  extracting: outputChanged/output/nacen.png
#  extracting: outputChanged/output/nacido.png
#  extracting: outputChanged/output/naciones.png
#  extracting: outputChanged/output/nada,ni.png
#  extracting: outputChanged/output/narias.png
#  extracting: outputChanged/output/nas.png
#  extracting: outputChanged/output/natu.png
#  extracting: outputChanged/output/natural.png
#  extracting: outputChanged/output/necesaria.png
#   inflating: outputChanged/output/necessitamos.png
#  extracting: outputChanged/output/negocios.png
#  extracting: outputChanged/output/nerales.png
#  extracting: outputChanged/output/nбa.png
#  extracting: outputChanged/output/nidad.png
#  extracting: outputChanged/output/niebla.png
#  extracting: outputChanged/output/nietos.png
#  extracting: outputChanged/output/nima.png
#  extracting: outputChanged/output/ningun.png
#  extracting: outputChanged/output/ninguno.png
#  extracting: outputChanged/output/nio,a.png
#  extracting: outputChanged/output/no.png
#  extracting: outputChanged/output/Nobles,.png
#  extracting: outputChanged/output/nobleza.png
#  extracting: outputChanged/output/nombre.png
#  extracting: outputChanged/output/nos.png
#  extracting: outputChanged/output/дos.png
#  extracting: outputChanged/output/nota.png
#  extracting: outputChanged/output/nua.png
#  extracting: outputChanged/output/nues.png
#  extracting: outputChanged/output/nuestra.png
#  extracting: outputChanged/output/nuestro.png
#   inflating: outputChanged/output/nuestros.png
#  extracting: outputChanged/output/nuevas.png
#  extracting: outputChanged/output/Numa.png
#  extracting: outputChanged/output/nunca.png
#  extracting: outputChanged/output/o (2).png
#  extracting: outputChanged/output/o.png
#  extracting: outputChanged/output/obfcuro.png
#  extracting: outputChanged/output/Obispos.png
#  extracting: outputChanged/output/obli.png
#  extracting: outputChanged/output/obliga.png
#   inflating: outputChanged/output/obligacion.png
#  extracting: outputChanged/output/obligado.png
#  extracting: outputChanged/output/obligados.png
#   inflating: outputChanged/output/obligaros.png
#  extracting: outputChanged/output/obras.png
#  extracting: outputChanged/output/observase.png
#  extracting: outputChanged/output/obtenerse.png
#  extracting: outputChanged/output/ocasiones.png
#   inflating: outputChanged/output/ociosidad.png
#  extracting: outputChanged/output/ocu.png
#  extracting: outputChanged/output/ocul.png
#  extracting: outputChanged/output/ocultв.png
#  extracting: outputChanged/output/offiey.png
#  extracting: outputChanged/output/Oficios.png
#  extracting: outputChanged/output/ofrecer.png
#   inflating: outputChanged/output/ofrecerseos.png
#  extracting: outputChanged/output/ojos.png
#  extracting: outputChanged/output/oraciones.png
#   inflating: outputChanged/output/ordinario.png
#  extracting: outputChanged/output/orfandad.png
#  extracting: outputChanged/output/ornato.png
#  extracting: outputChanged/output/oro.png
#  extracting: outputChanged/output/os (2).png
#  extracting: outputChanged/output/os (3).png
#  extracting: outputChanged/output/os.png
#  extracting: outputChanged/output/otra.png
#  extracting: outputChanged/output/otras.png
#  extracting: outputChanged/output/otro.png
#  extracting: outputChanged/output/otros.png
#  extracting: outputChanged/output/oveji.png
#  extracting: outputChanged/output/Oyd.png
#  extracting: outputChanged/output/oydo.png
#  extracting: outputChanged/output/oyendo.png
#   inflating: outputChanged/output/oyendolos.png
#  extracting: outputChanged/output/pa.png
#  extracting: outputChanged/output/Pacien.png
#  extracting: outputChanged/output/paga.png
#  extracting: outputChanged/output/pagan.png
#  extracting: outputChanged/output/paдo.png
#  extracting: outputChanged/output/par.png
#  extracting: outputChanged/output/para (2).png
#  extracting: outputChanged/output/para.png
#  extracting: outputChanged/output/paraef-.png
#  extracting: outputChanged/output/Parece.png
#   inflating: outputChanged/output/parecido.png
#  extracting: outputChanged/output/parte.png
#  extracting: outputChanged/output/partes.png
#   inflating: outputChanged/output/particular.png
#   inflating: outputChanged/output/particulares.png
#   inflating: outputChanged/output/passar.png
#  extracting: outputChanged/output/patente.png
#  extracting: outputChanged/output/patroci.png
#  extracting: outputChanged/output/paz.png
#   inflating: outputChanged/output/pellanes.png
#  extracting: outputChanged/output/penosos.png
#  extracting: outputChanged/output/per-.png
#  extracting: outputChanged/output/perador.png
#  extracting: outputChanged/output/perar.png
#   inflating: outputChanged/output/perfectas.png
#  extracting: outputChanged/output/perfo-.png
#   inflating: outputChanged/output/perfumado.png
#  extracting: outputChanged/output/perfumar.png
#   inflating: outputChanged/output/permitiendo.png
#   inflating: outputChanged/output/permitireys.png
#  extracting: outputChanged/output/pero.png
#  extracting: outputChanged/output/Persia.png
#   inflating: outputChanged/output/persona.png
#  extracting: outputChanged/output/peso.png
#  extracting: outputChanged/output/peste.png
#  extracting: outputChanged/output/pia.png
#   inflating: outputChanged/output/pidieren.png
#   inflating: outputChanged/output/pidбrsela.png
#  extracting: outputChanged/output/pie,en.png
#  extracting: outputChanged/output/piedad.png
#  extracting: outputChanged/output/piedras,q.png
#  extracting: outputChanged/output/piensan.png
#  extracting: outputChanged/output/pinas.png
#   inflating: outputChanged/output/pintaros.png
#  extracting: outputChanged/output/pion,.png
#  extracting: outputChanged/output/plead.png
#   inflating: outputChanged/output/poblada.png
#   inflating: outputChanged/output/podays,meditando.png
#  extracting: outputChanged/output/podays.png
#  extracting: outputChanged/output/pode.png
#   inflating: outputChanged/output/podrian.png
#  extracting: outputChanged/output/Poetas (2).png
#  extracting: outputChanged/output/Poetas.png
#   inflating: outputChanged/output/pofible.png
#  extracting: outputChanged/output/poner.png
#  extracting: outputChanged/output/Pontifice.png
#  extracting: outputChanged/output/por (2).png
#  extracting: outputChanged/output/por (3).png
#  extracting: outputChanged/output/por (4).png
#  extracting: outputChanged/output/poral,.png
#  extracting: outputChanged/output/porque (2).png
#  extracting: outputChanged/output/porque.png
#  extracting: outputChanged/output/possible (2).png
#  extracting: outputChanged/output/possible.png
#   inflating: outputChanged/output/Potentados.png
#  extracting: outputChanged/output/pre.png
#   inflating: outputChanged/output/preceptos.png
#   inflating: outputChanged/output/preciad,.png
#  extracting: outputChanged/output/Preciaos.png
#  extracting: outputChanged/output/preciar.png
#   inflating: outputChanged/output/predeterminacion.png
#  extracting: outputChanged/output/preg.png
#  extracting: outputChanged/output/Prelados.png
#  extracting: outputChanged/output/premio.png
#  extracting: outputChanged/output/premo.png
#  extracting: outputChanged/output/prendas.png
#  extracting: outputChanged/output/presas.png
#   inflating: outputChanged/output/presentarle.png
#   inflating: outputChanged/output/preside.png
#   inflating: outputChanged/output/pretendiendo.png
#  extracting: outputChanged/output/primera.png
#  extracting: outputChanged/output/primero.png
#   inflating: outputChanged/output/PrimogВnito.png
#  extracting: outputChanged/output/Prin (2).png
#  extracting: outputChanged/output/prin.png
#   inflating: outputChanged/output/princi.png
#   inflating: outputChanged/output/principalmente.png
#   inflating: outputChanged/output/principalmete.png
#  extracting: outputChanged/output/Principes.png
#   inflating: outputChanged/output/principio.png
#   inflating: outputChanged/output/privilegio.png
#  extracting: outputChanged/output/pro.png
#  extracting: outputChanged/output/proce.png
#  extracting: outputChanged/output/procede.png
#  extracting: outputChanged/output/procuran.png
#  extracting: outputChanged/output/procuro.png
#  extracting: outputChanged/output/professando.png
#   inflating: outputChanged/output/profession.png
#  extracting: outputChanged/output/promete.png
#   inflating: outputChanged/output/pronuncian.png
#  extracting: outputChanged/output/Propheta.png
#  extracting: outputChanged/output/propia,.png
#   inflating: outputChanged/output/propio.png
#  extracting: outputChanged/output/propios.png
#   inflating: outputChanged/output/prosperidades.png
#   inflating: outputChanged/output/provecho.png
#   inflating: outputChanged/output/providencia.png
#   inflating: outputChanged/output/prudencia.png
#   inflating: outputChanged/output/prudencias.png
#  extracting: outputChanged/output/pu.png
#   inflating: outputChanged/output/publica.png
#  extracting: outputChanged/output/puede.png
#  extracting: outputChanged/output/pueden.png
#  extracting: outputChanged/output/puedo.png
#  extracting: outputChanged/output/puertas.png
#  extracting: outputChanged/output/puesto.png
#  extracting: outputChanged/output/puntos.png
#  extracting: outputChanged/output/puntual.png
#  extracting: outputChanged/output/q (2).png
#  extracting: outputChanged/output/q (3).png
#  extracting: outputChanged/output/q.png
#   inflating: outputChanged/output/quadraredes.png
#  extracting: outputChanged/output/qual (2).png
#  extracting: outputChanged/output/qual.png
#   inflating: outputChanged/output/qualidad.png
#  extracting: outputChanged/output/qualquier.png
#   inflating: outputChanged/output/qualquiera.png
#  extracting: outputChanged/output/quan.png
#  extracting: outputChanged/output/quanto.png
#  extracting: outputChanged/output/quantos.png
#  extracting: outputChanged/output/que (2).png
#  extracting: outputChanged/output/que (3).png
#  extracting: outputChanged/output/que (4).png
#  extracting: outputChanged/output/que (5).png
#  extracting: outputChanged/output/que (6).png
#  extracting: outputChanged/output/que.png
#  extracting: outputChanged/output/queda.png
#   inflating: outputChanged/output/quedando.png
#   inflating: outputChanged/output/quedar.png
#  extracting: outputChanged/output/quepa.png
#  extracting: outputChanged/output/quien.png
#  extracting: outputChanged/output/quiera.png
#  extracting: outputChanged/output/quieren.png
#  extracting: outputChanged/output/Quinto.png
#  extracting: outputChanged/output/quiso.png
#  extracting: outputChanged/output/quita.png
#   inflating: outputChanged/output/quitarles.png
#  extracting: outputChanged/output/ra.png
#  extracting: outputChanged/output/rad.png
#  extracting: outputChanged/output/raleza.png
#  extracting: outputChanged/output/ran.png
#  extracting: outputChanged/output/rancifco.png
#  extracting: outputChanged/output/rara.png
#  extracting: outputChanged/output/raron.png
#  extracting: outputChanged/output/rase.png
#  extracting: outputChanged/output/rc.png
#  extracting: outputChanged/output/Re-.png
#  extracting: outputChanged/output/Real.png
#  extracting: outputChanged/output/realce.png
#  extracting: outputChanged/output/recatada.png
#  extracting: outputChanged/output/reci.png
#   inflating: outputChanged/output/recibidos.png
#  extracting: outputChanged/output/recibie-.png
#  extracting: outputChanged/output/recibio,y.png
#  extracting: outputChanged/output/recibir.png
#   inflating: outputChanged/output/recogido.png
#  extracting: outputChanged/output/reconocer.png
#  extracting: outputChanged/output/reconocimien-.png
#  extracting: outputChanged/output/rectamente.png
#   inflating: outputChanged/output/rectisimos.png
#   inflating: outputChanged/output/redempcion.png
#   inflating: outputChanged/output/regalos.png
#  extracting: outputChanged/output/Reli-.png
#  extracting: outputChanged/output/Religion.png
#   inflating: outputChanged/output/Religiosas.png
#   inflating: outputChanged/output/Religioso.png
#   inflating: outputChanged/output/Religiosos,.png
#  extracting: outputChanged/output/rendida.png
#  extracting: outputChanged/output/rendimi.png
#  extracting: outputChanged/output/rentas (2).png
#  extracting: outputChanged/output/rentas.png
#   inflating: outputChanged/output/repartirla.png
#   inflating: outputChanged/output/reposteros.png
#  extracting: outputChanged/output/res.png
#  extracting: outputChanged/output/reser-.png
#   inflating: outputChanged/output/respec-.png
#  extracting: outputChanged/output/respecto.png
#  extracting: outputChanged/output/respeto.png
#   inflating: outputChanged/output/respondio.png
#  extracting: outputChanged/output/Retablos.png
#   inflating: outputChanged/output/reverenciad.png
#  extracting: outputChanged/output/Rey (2).png
#  extracting: outputChanged/output/Rey.png
#  extracting: outputChanged/output/rica.png
#  extracting: outputChanged/output/rin.png
#  extracting: outputChanged/output/Ro.png
#  extracting: outputChanged/output/rodilla.png
#  extracting: outputChanged/output/rodillas.png
#  extracting: outputChanged/output/rodos,.png
#  extracting: outputChanged/output/ron.png
#  extracting: outputChanged/output/saber.png
#  extracting: outputChanged/output/sabios.png
#  extracting: outputChanged/output/Sacra-.png
#   inflating: outputChanged/output/Sacramentolo.png
#  extracting: outputChanged/output/saldreys.png
#  extracting: outputChanged/output/saliendo.png
#  extracting: outputChanged/output/salir.png
#  extracting: outputChanged/output/sallos.png
#  extracting: outputChanged/output/samente.png
#  extracting: outputChanged/output/San (2).png
#  extracting: outputChanged/output/San.png
#  extracting: outputChanged/output/sangre.png
#  extracting: outputChanged/output/santa (2).png
#  extracting: outputChanged/output/Santa.png
#   inflating: outputChanged/output/Santissimo.png
#  extracting: outputChanged/output/Santo.png
#  extracting: outputChanged/output/Santos.png
#  extracting: outputChanged/output/saqueys.png
#  extracting: outputChanged/output/se.png
#  extracting: outputChanged/output/sea.png
#  extracting: outputChanged/output/sean.png
#  extracting: outputChanged/output/seays.png
#  extracting: outputChanged/output/sectarios.png
#  extracting: outputChanged/output/sed.png
#   inflating: outputChanged/output/seguidor.png
#  extracting: outputChanged/output/seguir.png
#  extracting: outputChanged/output/segun.png
#  extracting: outputChanged/output/selas.png
#  extracting: outputChanged/output/sencillez.png
#  extracting: outputChanged/output/Seneca.png
#  extracting: outputChanged/output/Seno.png
#  extracting: outputChanged/output/seдor.png
#  extracting: outputChanged/output/Seдora,.png
#  extracting: outputChanged/output/Seдores.png
#  extracting: outputChanged/output/sente.png
#   inflating: outputChanged/output/sentimiento.png
#  extracting: outputChanged/output/sepa.png
#  extracting: outputChanged/output/ser.png
#  extracting: outputChanged/output/serlo.png
#  extracting: outputChanged/output/Sermones.png
#  extracting: outputChanged/output/sernos.png
#  extracting: outputChanged/output/servaros.png
#  extracting: outputChanged/output/servido.png
#  extracting: outputChanged/output/servir.png
#  extracting: outputChanged/output/Sexto,.png
#  extracting: outputChanged/output/siem.png
#  extracting: outputChanged/output/siempre.png
#  extracting: outputChanged/output/sien-.png
#  extracting: outputChanged/output/siepre.png
#   inflating: outputChanged/output/signacion.png
#  extracting: outputChanged/output/sin.png
#  extracting: outputChanged/output/sino.png
#  extracting: outputChanged/output/sintieron.png
#  extracting: outputChanged/output/siones.png
#  extracting: outputChanged/output/sirve.png
#  extracting: outputChanged/output/so.png
#  extracting: outputChanged/output/soberania.png
#  extracting: outputChanged/output/sobre.png
#   inflating: outputChanged/output/sobrenatural.png
#  extracting: outputChanged/output/Socra.png
#  extracting: outputChanged/output/Socrates.png
#  extracting: outputChanged/output/Sol.png
#  extracting: outputChanged/output/sola.png
#  extracting: outputChanged/output/solo.png
#  extracting: outputChanged/output/sombrero.png
#  extracting: outputChanged/output/son.png
#  extracting: outputChanged/output/soys.png
#  extracting: outputChanged/output/su.png
#  extracting: outputChanged/output/subditos.png
#  extracting: outputChanged/output/sucede.png
#  extracting: outputChanged/output/suerte.png
#   inflating: outputChanged/output/suficiente.png
#  extracting: outputChanged/output/sufrir,.png
#  extracting: outputChanged/output/sugetas.png
#  extracting: outputChanged/output/sujeto.png
#  extracting: outputChanged/output/sumen.png
#  extracting: outputChanged/output/Sumo.png
#  extracting: outputChanged/output/sus.png
#  extracting: outputChanged/output/sustenteys.png
#  extracting: outputChanged/output/suyo.png
#  extracting: outputChanged/output/suyos.png
#  extracting: outputChanged/output/ta.png
#  extracting: outputChanged/output/tal.png
#  extracting: outputChanged/output/talentos.png
#  extracting: outputChanged/output/tales.png
#  extracting: outputChanged/output/taleza.png
#  extracting: outputChanged/output/tambien.png
#  extracting: outputChanged/output/tamente.png
#  extracting: outputChanged/output/Tampoco.png
#   inflating: outputChanged/output/tan.png
#  extracting: outputChanged/output/tando.png
#  extracting: outputChanged/output/tanta.png
#  extracting: outputChanged/output/tantas.png
#  extracting: outputChanged/output/tanto.png
#  extracting: outputChanged/output/tantos.png
#  extracting: outputChanged/output/te.png
#  extracting: outputChanged/output/tecessores.png
#   inflating: outputChanged/output/Templanca,ifmo,Obe.png
#   inflating: outputChanged/output/Templos,ef-.png
#  extracting: outputChanged/output/tempora-.png
#   inflating: outputChanged/output/tempos,.png
#  extracting: outputChanged/output/ten.png
#  extracting: outputChanged/output/tendra.png
#  extracting: outputChanged/output/tendreys.png
#  extracting: outputChanged/output/tener (2).png
#  extracting: outputChanged/output/tener.png
#  extracting: outputChanged/output/tengan.png
#   inflating: outputChanged/output/tengo.png
#  extracting: outputChanged/output/ter.png
#  extracting: outputChanged/output/tereses.png
#  extracting: outputChanged/output/tes.png
#   inflating: outputChanged/output/Theodosio.png
#   inflating: outputChanged/output/Theologales,MoraleslaPen.png
#  extracting: outputChanged/output/tia.png
#  extracting: outputChanged/output/tial.png
#  extracting: outputChanged/output/tiempo.png
#  extracting: outputChanged/output/tiempos,oi.png
#  extracting: outputChanged/output/tiernos.png
#  extracting: outputChanged/output/Tiles.png
#  extracting: outputChanged/output/Tito (2).png
#  extracting: outputChanged/output/titulo.png
#  extracting: outputChanged/output/tivar.png
#  extracting: outputChanged/output/to.png
#  extracting: outputChanged/output/toca.png
#  extracting: outputChanged/output/tocantes.png
#  extracting: outputChanged/output/tocar.png
#  extracting: outputChanged/output/toda (2).png
#  extracting: outputChanged/output/toda.png
#  extracting: outputChanged/output/todas.png
#  extracting: outputChanged/output/todo.png
#  extracting: outputChanged/output/todos,.png
#  extracting: outputChanged/output/toleran.png
#  extracting: outputChanged/output/tomad.png
#  extracting: outputChanged/output/tomando.png
#  extracting: outputChanged/output/toque.png
#  extracting: outputChanged/output/tos.png
#  extracting: outputChanged/output/trabajo,.png
#  extracting: outputChanged/output/trabajos.png
#  extracting: outputChanged/output/traerle.png
#  extracting: outputChanged/output/Trajano.png
#  extracting: outputChanged/output/tras.png
#  extracting: outputChanged/output/tratar.png
#   inflating: outputChanged/output/tratarlos.png
#  extracting: outputChanged/output/trato.png
#  extracting: outputChanged/output/trayan.png
#  extracting: outputChanged/output/tre.png
#  extracting: outputChanged/output/tres.png
#  extracting: outputChanged/output/trinit.png
#  extracting: outputChanged/output/triunfo.png
#  extracting: outputChanged/output/tro.png
#  extracting: outputChanged/output/tros.png
#  extracting: outputChanged/output/truhanes.png
#  extracting: outputChanged/output/truxeron.png
#  extracting: outputChanged/output/tu.png
#  extracting: outputChanged/output/tuoso.png
#  extracting: outputChanged/output/turales.png
#  extracting: outputChanged/output/tutela (2).png
#  extracting: outputChanged/output/tutela.png
#  extracting: outputChanged/output/tuviera.png
#   inflating: outputChanged/output/ultimamente.png
#  extracting: outputChanged/output/una.png
#  extracting: outputChanged/output/uno.png
#  extracting: outputChanged/output/unos.png
#  extracting: outputChanged/output/uplem.png
#  extracting: outputChanged/output/usan.png
#  extracting: outputChanged/output/usar.png
#  extracting: outputChanged/output/useys.png
#  extracting: outputChanged/output/va-.png
#  extracting: outputChanged/output/vad.png
#  extracting: outputChanged/output/vaffallos.png
#  extracting: outputChanged/output/valde,y.png
#  extracting: outputChanged/output/valernos.png
#  extracting: outputChanged/output/valor.png
#  extracting: outputChanged/output/van.png
#  extracting: outputChanged/output/varias.png
#  extracting: outputChanged/output/vas.png
#  extracting: outputChanged/output/vasallos.png
#  extracting: outputChanged/output/vassallos.png
#  extracting: outputChanged/output/vayan-.png
#  extracting: outputChanged/output/vemos.png
#   inflating: outputChanged/output/vendiciendo.png
#  extracting: outputChanged/output/vene-.png
#  extracting: outputChanged/output/venerad.png
#  extracting: outputChanged/output/venereys,y.png
#  extracting: outputChanged/output/venia.png
#  extracting: outputChanged/output/veniencia.png
#  extracting: outputChanged/output/veo.png
#  extracting: outputChanged/output/ver.png
#   inflating: outputChanged/output/verdadera.png
#  extracting: outputChanged/output/verdades.png
#  extracting: outputChanged/output/versos.png
#  extracting: outputChanged/output/Viatico.png
#  extracting: outputChanged/output/vicios.png
#  extracting: outputChanged/output/vida (2).png
#  extracting: outputChanged/output/vida.png
#  extracting: outputChanged/output/vien-.png
#  extracting: outputChanged/output/viendole.png
#   inflating: outputChanged/output/vinculada.png
#  extracting: outputChanged/output/vio.png
#  extracting: outputChanged/output/Vir-.png
#  extracting: outputChanged/output/Virgen.png
#  extracting: outputChanged/output/virtud (2).png
#  extracting: outputChanged/output/virtud.png
#  extracting: outputChanged/output/virtudes.png
#  extracting: outputChanged/output/virtuo-.png
#  extracting: outputChanged/output/virtuosa.png
#  extracting: outputChanged/output/virtuoso.png
#  extracting: outputChanged/output/vitra.png
#  extracting: outputChanged/output/vivir.png
#  extracting: outputChanged/output/vna.png
#  extracting: outputChanged/output/vos,.png
#  extracting: outputChanged/output/vosotros.png
#  extracting: outputChanged/output/vueftra (2).png
#  extracting: outputChanged/output/vueftra.png
#  extracting: outputChanged/output/vuestras.png
#  extracting: outputChanged/output/vuestro.png
#  extracting: outputChanged/output/vuestros.png
#  extracting: outputChanged/output/xandro.png
#  extracting: outputChanged/output/y (2).png
#  extracting: outputChanged/output/y (3).png
#  extracting: outputChanged/output/y (4).png
#   inflating: outputChanged/output/yadornarlas.png
#  extracting: outputChanged/output/ye.png
#  extracting: outputChanged/output/yo.png
#  extracting: outputChanged/output/za (2).png
#  extracting: outputChanged/output/za.png
#  extracting: outputChanged/output/zelo.png
#  extracting: outputChanged/output/zer.png
#  extracting: outputChanged/output/zidas.png

# %%
# Transferring the corrected dataset to the correct location for training
# !mv './outputChanged/output' './training_data'

# %% [markdown]
# # Working on Training_data

# %% [markdown]
# ### Padding small sized words for no distortion

# %%
# adding padding to the left and right of small sized words
training_data = './training_data'
pad_and_resize_images(training_data)
# Out:
# Processed and replaced: ./training_data/a.png
# Processed and replaced: ./training_data/abatio.png
# Processed and replaced: ./training_data/abatirse.png
# Processed and replaced: ./training_data/aborre.png
# Processed and replaced: ./training_data/ac.png
# Processed and replaced: ./training_data/acavallo.png
# Processed and replaced: ./training_data/acciones.png
# Processed and replaced: ./training_data/acometer.png
# Processed and replaced: ./training_data/Acudireys.png
# Processed and replaced: ./training_data/Acuдa.png
# Processed and replaced: ./training_data/admitiendo.png
# Processed and replaced: ./training_data/ador-.png
# Processed and replaced: ./training_data/afeminados,.png
# Processed and replaced: ./training_data/affi.png
# Processed and replaced: ./training_data/afligi.png
# Processed and replaced: ./training_data/afsi.png
# Processed and replaced: ./training_data/agradecido.png
# Processed and replaced: ./training_data/agravio.png
# Processed and replaced: ./training_data/Agustin,.png
# Processed and replaced: ./training_data/al (2).png
# Processed and replaced: ./training_data/al.png
# Processed and replaced: ./training_data/alabareys.png
# Processed and replaced: ./training_data/Ale.png
# Processed and replaced: ./training_data/alegre.png
# Processed and replaced: ./training_data/alegrбa.png
# Processed and replaced: ./training_data/alguna.png
# Processed and replaced: ./training_data/alhombras,.png
# Processed and replaced: ./training_data/alli.png
# Processed and replaced: ./training_data/alma.png
# Processed and replaced: ./training_data/alo.png
# Processed and replaced: ./training_data/Alonso.png
# Processed and replaced: ./training_data/Altar.png
# Processed and replaced: ./training_data/Ambrosio,.png
# Processed and replaced: ./training_data/amenaza.png
# Processed and replaced: ./training_data/amigos.png
# Processed and replaced: ./training_data/ampara.png
# Processed and replaced: ./training_data/amparo.png
# Processed and replaced: ./training_data/an.png
# Processed and replaced: ./training_data/aдade.png
# Processed and replaced: ./training_data/aдadire.png
# Processed and replaced: ./training_data/Angel.png
# Processed and replaced: ./training_data/Anibal,.png
# Processed and replaced: ./training_data/animo.png
# Processed and replaced: ./training_data/aдo.png
# Processed and replaced: ./training_data/aдos.png
# Processed and replaced: ./training_data/antemano.png
# Processed and replaced: ./training_data/aora.png
# Processed and replaced: ./training_data/apli-.png
# Processed and replaced: ./training_data/apo.png
# Processed and replaced: ./training_data/apostatar.png
# Processed and replaced: ./training_data/apro.png
# Processed and replaced: ./training_data/aprovecha-.png
# Processed and replaced: ./training_data/aprovechar.png
# Processed and replaced: ./training_data/aquel.png
# Processed and replaced: ./training_data/aquellas.png
# Processed and replaced: ./training_data/aquellos.png
# Processed and replaced: ./training_data/Aqui.png
# Processed and replaced: ./training_data/aquб.png
# Processed and replaced: ./training_data/ar-.png
# Processed and replaced: ./training_data/arduas.png
# Processed and replaced: ./training_data/Aristo-.png
# Processed and replaced: ./training_data/Aristoteles.png
# Processed and replaced: ./training_data/armas.png
# Processed and replaced: ./training_data/Arneses.png
# Processed and replaced: ./training_data/Arre.png
# Processed and replaced: ./training_data/Artifices.png
# Processed and replaced: ./training_data/artilleria.png
# Processed and replaced: ./training_data/Artus-.png
# Processed and replaced: ./training_data/asentado.png
# Processed and replaced: ./training_data/asistencia.png
# Processed and replaced: ./training_data/asistid.png
# Processed and replaced: ./training_data/assi.png
# Processed and replaced: ./training_data/assiento.png
# Processed and replaced: ./training_data/Assistid.png
# Processed and replaced: ./training_data/assistio.png
# Processed and replaced: ./training_data/atencion,y.png
# Processed and replaced: ./training_data/atribuyen.png
# Processed and replaced: ./training_data/Auftria.png
# Processed and replaced: ./training_data/aunque.png
# Processed and replaced: ./training_data/Aurelio.png
# Processed and replaced: ./training_data/aventurada.png
# Processed and replaced: ./training_data/averos.png
# Processed and replaced: ./training_data/aveys.png
# Processed and replaced: ./training_data/avia.png
# Processed and replaced: ./training_data/aviendose.png
# Processed and replaced: ./training_data/ay (2).png
# Processed and replaced: ./training_data/ay.png
# Processed and replaced: ./training_data/aya.png
# Processed and replaced: ./training_data/ayudareys.png
# Processed and replaced: ./training_data/Basilio.png
# Processed and replaced: ./training_data/Bautismo,.png
# Processed and replaced: ./training_data/baxeza.png
# Processed and replaced: ./training_data/beneficio.png
# Processed and replaced: ./training_data/beralidad.png
# Processed and replaced: ./training_data/Bernardo.png
# Processed and replaced: ./training_data/bertad.png
# Processed and replaced: ./training_data/bien (2).png
# Processed and replaced: ./training_data/Bien.png
# Processed and replaced: ./training_data/bienes.png
# Processed and replaced: ./training_data/bisposprocurad.png
# Processed and replaced: ./training_data/bistes.png
# Processed and replaced: ./training_data/bjen.png
# Processed and replaced: ./training_data/ble.png
# Processed and replaced: ./training_data/blen.png
# Processed and replaced: ./training_data/bligados.png
# Processed and replaced: ./training_data/bolver.png
# Processed and replaced: ./training_data/bondad.png
# Processed and replaced: ./training_data/bre.png
# Processed and replaced: ./training_data/brindis.png
# Processed and replaced: ./training_data/Bruno.png
# Processed and replaced: ./training_data/buen.png
# Processed and replaced: ./training_data/buena.png
# Processed and replaced: ./training_data/Buendia.png
# Processed and replaced: ./training_data/buenos.png
# Processed and replaced: ./training_data/Bullon,.png
# Processed and replaced: ./training_data/bus.png
# Processed and replaced: ./training_data/busca,.png
# Processed and replaced: ./training_data/buscando.png
# Processed and replaced: ./training_data/cabezas.png
# Processed and replaced: ./training_data/caciвn,.png
# Processed and replaced: ./training_data/cada.png
# Processed and replaced: ./training_data/cadaver.png
# Processed and replaced: ./training_data/calamidades.png
# Processed and replaced: ./training_data/calidad.png
# Processed and replaced: ./training_data/cama.png
# Processed and replaced: ./training_data/camino.png
# Processed and replaced: ./training_data/campal.png
# Processed and replaced: ./training_data/candalo.png
# Processed and replaced: ./training_data/cando.png
# Processed and replaced: ./training_data/cante.png
# Processed and replaced: ./training_data/capaz.png
# Processed and replaced: ./training_data/Cardinales,y.png
# Processed and replaced: ./training_data/care.png
# Processed and replaced: ./training_data/Carlo.png
# Processed and replaced: ./training_data/casa.png
# Processed and replaced: ./training_data/caso.png
# Processed and replaced: ./training_data/casos.png
# Processed and replaced: ./training_data/Castilla,.png
# Processed and replaced: ./training_data/Castillo.png
# Processed and replaced: ./training_data/Caton,.png
# Processed and replaced: ./training_data/Cavalleros,y.png
# Processed and replaced: ./training_data/cays,.png
# Processed and replaced: ./training_data/celentes.png
# Processed and replaced: ./training_data/cencia,y.png
# Processed and replaced: ./training_data/censuras.png
# Processed and replaced: ./training_data/cente.png
# Processed and replaced: ./training_data/ceremonias.png
# Processed and replaced: ./training_data/ceron,.png
# Processed and replaced: ./training_data/ces.png
# Processed and replaced: ./training_data/Cesar,Sci-.png
# Processed and replaced: ./training_data/chia.png
# Processed and replaced: ./training_data/chos (2).png
# Processed and replaced: ./training_data/Christiana.png
# Processed and replaced: ./training_data/Ci.png
# Processed and replaced: ./training_data/cia.png
# Processed and replaced: ./training_data/Cicero.png
# Processed and replaced: ./training_data/Ciceron,.png
# Processed and replaced: ./training_data/cidentes.png
# Processed and replaced: ./training_data/cierto.png
# Processed and replaced: ./training_data/cimiento.png
# Processed and replaced: ./training_data/cio.png
# Processed and replaced: ./training_data/cion.png
# Processed and replaced: ./training_data/cionales.png
# Processed and replaced: ./training_data/cipio,.png
# Processed and replaced: ./training_data/civil.png
# Processed and replaced: ./training_data/clemencia.png
# Processed and replaced: ./training_data/Clerigos,.png
# Processed and replaced: ./training_data/co.png
# Processed and replaced: ./training_data/cobreys.png
# Processed and replaced: ./training_data/cochero.png
# Processed and replaced: ./training_data/cofo,y.png
# Processed and replaced: ./training_data/colgar,.png
# Processed and replaced: ./training_data/colgarle.png
# Processed and replaced: ./training_data/combites,.png
# Processed and replaced: ./training_data/compostura.png
# Processed and replaced: ./training_data/comun.png
# Processed and replaced: ./training_data/comunicaciвn.png
# Processed and replaced: ./training_data/comunion.png
# Processed and replaced: ./training_data/con (1).png
# Processed and replaced: ./training_data/con (2).png
# Processed and replaced: ./training_data/con (3).png
# Processed and replaced: ./training_data/conciencia.png
# Processed and replaced: ./training_data/conclu.png
# Processed and replaced: ./training_data/condederа.png
# Processed and replaced: ./training_data/Condesa.png
# Processed and replaced: ./training_data/conforma.png
# Processed and replaced: ./training_data/conformidad.png
# Processed and replaced: ./training_data/connatural.png
# Processed and replaced: ./training_data/conocen.png
# Processed and replaced: ./training_data/conocer.png
# Processed and replaced: ./training_data/conocida.png
# Processed and replaced: ./training_data/conocido.png
# Processed and replaced: ./training_data/conocieron.png
# Processed and replaced: ./training_data/conocio.png
# Processed and replaced: ./training_data/conozcays.png
# Processed and replaced: ./training_data/Consejos.png
# Processed and replaced: ./training_data/conserva.png
# Processed and replaced: ./training_data/consideracion.png
# Processed and replaced: ./training_data/Considerad.png
# Processed and replaced: ./training_data/consintays.png
# Processed and replaced: ./training_data/consolaciones.png
# Processed and replaced: ./training_data/constancia.png
# Processed and replaced: ./training_data/Constantino.png
# Processed and replaced: ./training_data/contentandose.png
# Processed and replaced: ./training_data/contenteys.png
# Processed and replaced: ./training_data/conti.png
# Processed and replaced: ./training_data/Continencia.png
# Processed and replaced: ./training_data/continuo.png
# Processed and replaced: ./training_data/contra.png
# Processed and replaced: ./training_data/conveniente.png
# Processed and replaced: ./training_data/Conventos.png
# Processed and replaced: ./training_data/coponer.png
# Processed and replaced: ./training_data/coracon.png
# Processed and replaced: ./training_data/corazon.png
# Processed and replaced: ./training_data/corrieren.png
# Processed and replaced: ./training_data/cortesia.png
# Processed and replaced: ./training_data/cortesias.png
# Processed and replaced: ./training_data/cosa.png
# Processed and replaced: ./training_data/cosas.png
# Processed and replaced: ./training_data/costumbres.png
# Processed and replaced: ./training_data/creacion.png
# Processed and replaced: ./training_data/creed.png
# Processed and replaced: ./training_data/creyendo.png
# Processed and replaced: ./training_data/criado (2).png
# Processed and replaced: ./training_data/criados.png
# Processed and replaced: ./training_data/crian.png
# Processed and replaced: ./training_data/crio.png
# Processed and replaced: ./training_data/cualquiera.png
# Processed and replaced: ./training_data/cubran.png
# Processed and replaced: ./training_data/cubrir.png
# Processed and replaced: ./training_data/cuenta.png
# Processed and replaced: ./training_data/cumplieredes,.png
# Processed and replaced: ./training_data/cumplimiento.png
# Processed and replaced: ./training_data/cumplir.png
# Processed and replaced: ./training_data/curioso.png
# Processed and replaced: ./training_data/cuva.png
# Processed and replaced: ./training_data/cuya.png
# Processed and replaced: ./training_data/cuydar.png
# Processed and replaced: ./training_data/da.png
# Processed and replaced: ./training_data/dad.png
# Processed and replaced: ./training_data/dadles.png
# Processed and replaced: ./training_data/dados.png
# Processed and replaced: ./training_data/dan.png
# Processed and replaced: ./training_data/dar.png
# Processed and replaced: ./training_data/darme.png
# Processed and replaced: ./training_data/daros.png
# Processed and replaced: ./training_data/das.png
# Processed and replaced: ./training_data/David.png
# Processed and replaced: ./training_data/de (2).png
# Processed and replaced: ./training_data/de (3).png
# Processed and replaced: ./training_data/de (4).png
# Processed and replaced: ./training_data/de (5).png
# Processed and replaced: ./training_data/de (6).png
# Processed and replaced: ./training_data/de (7).png
# Processed and replaced: ./training_data/De.png
# Processed and replaced: ./training_data/DEDICATORIA.png
# Processed and replaced: ./training_data/defcomulgado.png
# Processed and replaced: ./training_data/defde.png
# Processed and replaced: ./training_data/del (2).png
# Processed and replaced: ./training_data/del (3).png
# Processed and replaced: ./training_data/del.png
# Processed and replaced: ./training_data/delan-.png
# Processed and replaced: ./training_data/della.png
# Processed and replaced: ./training_data/dellas.png
# Processed and replaced: ./training_data/dencia,.png
# Processed and replaced: ./training_data/depravadas.png
# Processed and replaced: ./training_data/dera.png
# Processed and replaced: ./training_data/derillo.png
# Processed and replaced: ./training_data/des-.png
# Processed and replaced: ./training_data/descubierto.png
# Processed and replaced: ./training_data/descuento.png
# Processed and replaced: ./training_data/descuydeys.png
# Processed and replaced: ./training_data/desdicha.png
# Processed and replaced: ./training_data/desprecio.png
# Processed and replaced: ./training_data/despuВs.png
# Processed and replaced: ./training_data/desseando.png
# Processed and replaced: ./training_data/dessear.png
# Processed and replaced: ./training_data/desseo.png
# Processed and replaced: ./training_data/desta.png
# Processed and replaced: ./training_data/destas.png
# Processed and replaced: ./training_data/desto.png
# Processed and replaced: ./training_data/destos.png
# Processed and replaced: ./training_data/desuelo.png
# Processed and replaced: ./training_data/desve.png
# Processed and replaced: ./training_data/deuda,y.png
# Processed and replaced: ./training_data/deue.png
# Processed and replaced: ./training_data/deveys.png
# Processed and replaced: ./training_data/devidas.png
# Processed and replaced: ./training_data/devo.png
# Processed and replaced: ./training_data/devotos.png
# Processed and replaced: ./training_data/devria.png
# Processed and replaced: ./training_data/dexaros.png
# Processed and replaced: ./training_data/dexeys.png
# Processed and replaced: ./training_data/dexo.png
# Processed and replaced: ./training_data/dexв.png
# Processed and replaced: ./training_data/di-.png
# Processed and replaced: ./training_data/dia,.png
# Processed and replaced: ./training_data/dicha.png
# Processed and replaced: ./training_data/dichoso.png
# Processed and replaced: ./training_data/diencia.png
# Processed and replaced: ./training_data/diendose.png
# Processed and replaced: ./training_data/diera.png
# Processed and replaced: ./training_data/dieron.png
# Processed and replaced: ./training_data/diferencias,.png
# Processed and replaced: ./training_data/dificil.png
# Processed and replaced: ./training_data/dignidad.png
# Processed and replaced: ./training_data/digno.png
# Processed and replaced: ./training_data/Digo.png
# Processed and replaced: ./training_data/dio.png
# Processed and replaced: ./training_data/Dios.png
# Processed and replaced: ./training_data/discursos.png
# Processed and replaced: ./training_data/dispa.png
# Processed and replaced: ./training_data/distraerlos.png
# Processed and replaced: ./training_data/divina.png
# Processed and replaced: ./training_data/Divino.png
# Processed and replaced: ./training_data/divinos.png
# Processed and replaced: ./training_data/dixo (2).png
# Processed and replaced: ./training_data/dixo.png
# Processed and replaced: ./training_data/dize.png
# Processed and replaced: ./training_data/do.png
# Processed and replaced: ./training_data/doce.png
# Processed and replaced: ./training_data/Doctores.png
# Processed and replaced: ./training_data/Doctos.png
# Processed and replaced: ./training_data/documen.png
# Processed and replaced: ./training_data/dola.png
# Processed and replaced: ./training_data/dole,.png
# Processed and replaced: ./training_data/dolores.png
# Processed and replaced: ./training_data/dominio.png
# Processed and replaced: ./training_data/Don.png
# Processed and replaced: ./training_data/Doдa.png
# Processed and replaced: ./training_data/donde.png
# Processed and replaced: ./training_data/dos,y.png
# Processed and replaced: ./training_data/dos.png
# Processed and replaced: ./training_data/dres.png
# Processed and replaced: ./training_data/e.png
# Processed and replaced: ./training_data/Eclesiastico.png
# Processed and replaced: ./training_data/educacion.png
# Processed and replaced: ./training_data/educaciвn.png
# Processed and replaced: ./training_data/effe.png
# Processed and replaced: ./training_data/efte.png
# Processed and replaced: ./training_data/Eibie.png
# Processed and replaced: ./training_data/el (2).png
# Processed and replaced: ./training_data/el (3).png
# Processed and replaced: ./training_data/Вl,.png
# Processed and replaced: ./training_data/el.png
# Processed and replaced: ./training_data/elegir.png
# Processed and replaced: ./training_data/ella,.png
# Processed and replaced: ./training_data/ellas.png
# Processed and replaced: ./training_data/ello,alumbradle.png
# Processed and replaced: ./training_data/ellos (2).png
# Processed and replaced: ./training_data/ellos.png
# Processed and replaced: ./training_data/em-.png
# Processed and replaced: ./training_data/Em.png
# Processed and replaced: ./training_data/emas,.png
# Processed and replaced: ./training_data/en (2).png
# Processed and replaced: ./training_data/en (3).png
# Processed and replaced: ./training_data/en (4).png
# Processed and replaced: ./training_data/en (5).png
# Processed and replaced: ./training_data/en (6).png
# Processed and replaced: ./training_data/en (7).png
# Processed and replaced: ./training_data/en (8).png
# Processed and replaced: ./training_data/en (9).png
# Processed and replaced: ./training_data/en.png
# Processed and replaced: ./training_data/en-.png
# Processed and replaced: ./training_data/enamorados,.png
# Processed and replaced: ./training_data/encamina-.png
# Processed and replaced: ./training_data/encaminar.png
# Processed and replaced: ./training_data/encar.png
# Processed and replaced: ./training_data/encontran-.png
# Processed and replaced: ./training_data/enfadados.png
# Processed and replaced: ./training_data/enfermos.png
# Processed and replaced: ./training_data/enga.png
# Processed and replaced: ./training_data/engaдado.png
# Processed and replaced: ./training_data/engaдar.png
# Processed and replaced: ./training_data/engrandecen.png
# Processed and replaced: ./training_data/engrandezido.png
# Processed and replaced: ./training_data/enseдan.png
# Processed and replaced: ./training_data/ente.png
# Processed and replaced: ./training_data/enternezer.png
# Processed and replaced: ./training_data/entienden.png
# Processed and replaced: ./training_data/enton-.png
# Processed and replaced: ./training_data/entraдable.png
# Processed and replaced: ./training_data/entrar.png
# Processed and replaced: ./training_data/entregandose.png
# Processed and replaced: ./training_data/entriste-.png
# Processed and replaced: ./training_data/equidad.png
# Processed and replaced: ./training_data/era.png
# Processed and replaced: ./training_data/ero.png
# Processed and replaced: ./training_data/es (2).png
# Processed and replaced: ./training_data/es (3).png
# Processed and replaced: ./training_data/es.png
# Processed and replaced: ./training_data/escribe.png
# Processed and replaced: ./training_data/escrito.png
# Processed and replaced: ./training_data/Escritura.png
# Processed and replaced: ./training_data/Espaдa.png
# Processed and replaced: ./training_data/esperanza.png
# Processed and replaced: ./training_data/Espero.png
# Processed and replaced: ./training_data/espiri-.png
# Processed and replaced: ./training_data/Espбri.png
# Processed and replaced: ./training_data/espiritu.png
# Processed and replaced: ./training_data/Esta.png
# Processed and replaced: ./training_data/estad.png
# Processed and replaced: ./training_data/Estado.png
# Processed and replaced: ./training_data/Estados,.png
# Processed and replaced: ./training_data/estando.png
# Processed and replaced: ./training_data/estar.png
# Processed and replaced: ./training_data/estas.png
# Processed and replaced: ./training_data/estava.png
# Processed and replaced: ./training_data/este.png
# Processed and replaced: ./training_data/Estephano.png
# Processed and replaced: ./training_data/esteys.png
# Processed and replaced: ./training_data/esti.png
# Processed and replaced: ./training_data/estima.png
# Processed and replaced: ./training_data/estos.png
# Processed and replaced: ./training_data/estrecha.png
# Processed and replaced: ./training_data/estudiosidad.png
# Processed and replaced: ./training_data/eterna.png
# Processed and replaced: ./training_data/ex-.png
# Processed and replaced: ./training_data/excede.png
# Processed and replaced: ./training_data/exceder.png
# Processed and replaced: ./training_data/excelencia.png
# Processed and replaced: ./training_data/excelente.png
# Processed and replaced: ./training_data/executaros.png
# Processed and replaced: ./training_data/exem.png
# Processed and replaced: ./training_data/exempciones.png
# Processed and replaced: ./training_data/exemplar.png
# Processed and replaced: ./training_data/exerci-.png
# Processed and replaced: ./training_data/exercicio.png
# Processed and replaced: ./training_data/exercitan.png
# Processed and replaced: ./training_data/exercitar.png
# Processed and replaced: ./training_data/exorto.png
# Processed and replaced: ./training_data/ey.png
# Processed and replaced: ./training_data/eyes.png
# Processed and replaced: ./training_data/F.png
# Processed and replaced: ./training_data/fa-.png
# Processed and replaced: ./training_data/factibles.png
# Processed and replaced: ./training_data/fagacidad,.png
# Processed and replaced: ./training_data/falta.png
# Processed and replaced: ./training_data/faltan.png
# Processed and replaced: ./training_data/faltandoles.png
# Processed and replaced: ./training_data/faltar.png
# Processed and replaced: ./training_data/falua,A.png
# Processed and replaced: ./training_data/familiares.png
# Processed and replaced: ./training_data/Familias.png
# Processed and replaced: ./training_data/fas (2).png
# Processed and replaced: ./training_data/fas.png
# Processed and replaced: ./training_data/favor.png
# Processed and replaced: ./training_data/fe (2).png
# Processed and replaced: ./training_data/Fe.png
# Processed and replaced: ./training_data/fealdad.png
# Processed and replaced: ./training_data/feccion.png
# Processed and replaced: ./training_data/fegun.png
# Processed and replaced: ./training_data/fermedad.png
# Processed and replaced: ./training_data/feruid.png
# Processed and replaced: ./training_data/festasse.png
# Processed and replaced: ./training_data/feuar.png
# Processed and replaced: ./training_data/ffiones.png
# Processed and replaced: ./training_data/fi.png
# Processed and replaced: ./training_data/Fiesta,.png
# Processed and replaced: ./training_data/fiestas.png
# Processed and replaced: ./training_data/fin.png
# Processed and replaced: ./training_data/fineza.png
# Processed and replaced: ./training_data/fino.png
# Processed and replaced: ./training_data/fintiendo.png
# Processed and replaced: ./training_data/fluos.png
# Processed and replaced: ./training_data/fola.png
# Processed and replaced: ./training_data/folo.png
# Processed and replaced: ./training_data/for-.png
# Processed and replaced: ./training_data/Fortaleza.png
# Processed and replaced: ./training_data/forzosa.png
# Processed and replaced: ./training_data/forzosos.png
# Processed and replaced: ./training_data/fos (2).png
# Processed and replaced: ./training_data/fos.png
# Processed and replaced: ./training_data/fu.png
# Processed and replaced: ./training_data/fuerza.png
# Processed and replaced: ./training_data/fues.png
# Processed and replaced: ./training_data/fuesse.png
# Processed and replaced: ./training_data/funda.png
# Processed and replaced: ./training_data/fundadores.png
# Processed and replaced: ./training_data/fundamen.png
# Processed and replaced: ./training_data/fundandole.png
# Processed and replaced: ./training_data/fuya.png
# Processed and replaced: ./training_data/gacion.png
# Processed and replaced: ./training_data/gaciones.png
# Processed and replaced: ./training_data/galas,.png
# Processed and replaced: ./training_data/gana.png
# Processed and replaced: ./training_data/ganareys.png
# Processed and replaced: ./training_data/ganaron.png
# Processed and replaced: ./training_data/gаndole.png
# Processed and replaced: ./training_data/gas-.png
# Processed and replaced: ./training_data/gays.png
# Processed and replaced: ./training_data/ge.png
# Processed and replaced: ./training_data/gen.png
# Processed and replaced: ./training_data/general.png
# Processed and replaced: ./training_data/generoso.png
# Processed and replaced: ./training_data/gente.png
# Processed and replaced: ./training_data/Gentiles.png
# Processed and replaced: ./training_data/Gentilica.png
# Processed and replaced: ./training_data/gestad.png
# Processed and replaced: ./training_data/giones.png
# Processed and replaced: ./training_data/glesia.png
# Processed and replaced: ./training_data/gloria.png
# Processed and replaced: ./training_data/gra-.png
# Processed and replaced: ./training_data/gracia.png
# Processed and replaced: ./training_data/gracio.png
# Processed and replaced: ./training_data/gran.png
# Processed and replaced: ./training_data/grande,.png
# Processed and replaced: ./training_data/grandeza.png
# Processed and replaced: ./training_data/grangear.png
# Processed and replaced: ./training_data/grato.png
# Processed and replaced: ./training_data/graue.png
# Processed and replaced: ./training_data/Guarda.png
# Processed and replaced: ./training_data/guerra.png
# Processed and replaced: ./training_data/guia,.png
# Processed and replaced: ./training_data/gunos.png
# Processed and replaced: ./training_data/gusto.png
# Processed and replaced: ./training_data/ha.png
# Processed and replaced: ./training_data/habito.png
# Processed and replaced: ./training_data/hablad.png
# Processed and replaced: ./training_data/hafta.png
# Processed and replaced: ./training_data/hago.png
# Processed and replaced: ./training_data/hallan.png
# Processed and replaced: ./training_data/hallar.png
# Processed and replaced: ./training_data/hallaredes.png
# Processed and replaced: ./training_data/hallo.png
# Processed and replaced: ./training_data/han.png
# Processed and replaced: ./training_data/hareys.png
# Processed and replaced: ./training_data/haze (2).png
# Processed and replaced: ./training_data/hazed.png
# Processed and replaced: ./training_data/hazen.png
# Processed and replaced: ./training_data/hazer (2).png
# Processed and replaced: ./training_data/hazer.png
# Processed and replaced: ./training_data/hazerlos.png
# Processed and replaced: ./training_data/hazerse.png
# Processed and replaced: ./training_data/hazienda.png
# Processed and replaced: ./training_data/he.png
# Processed and replaced: ./training_data/hecho.png
# Processed and replaced: ./training_data/Her.png
# Processed and replaced: ./training_data/here.png
# Processed and replaced: ./training_data/heredada,.png
# Processed and replaced: ./training_data/herencia.png
# Processed and replaced: ./training_data/hermanos.png
# Processed and replaced: ./training_data/hijo.png
# Processed and replaced: ./training_data/hijos.png
# Processed and replaced: ./training_data/hin-.png
# Processed and replaced: ./training_data/hizo.png
# Processed and replaced: ./training_data/hombre.png
# Processed and replaced: ./training_data/honra.png
# Processed and replaced: ./training_data/hora.png
# Processed and replaced: ./training_data/horror.png
# Processed and replaced: ./training_data/hu.png
# Processed and replaced: ./training_data/huesped.png
# Processed and replaced: ./training_data/huma.png
# Processed and replaced: ./training_data/huvieredes.png
# Processed and replaced: ./training_data/huyr.png
# Processed and replaced: ./training_data/IE.png
# Processed and replaced: ./training_data/Iglesias.png
# Processed and replaced: ./training_data/illus-.png
# Processed and replaced: ./training_data/Ilustres.png
# Processed and replaced: ./training_data/im.png
# Processed and replaced: ./training_data/imitando.png
# Processed and replaced: ./training_data/immortal.png
# Processed and replaced: ./training_data/importantes.png
# Processed and replaced: ./training_data/in.png
# Processed and replaced: ./training_data/incansable.png
# Processed and replaced: ./training_data/incentivo.png
# Processed and replaced: ./training_data/inchado.png
# Processed and replaced: ./training_data/inchirla.png
# Processed and replaced: ./training_data/incluye.png
# Processed and replaced: ./training_data/incurrir.png
# Processed and replaced: ./training_data/indecencia.png
# Processed and replaced: ./training_data/indignam.png
# Processed and replaced: ./training_data/individuaros.png
# Processed and replaced: ./training_data/inestimables.png
# Processed and replaced: ./training_data/Ingles.png
# Processed and replaced: ./training_data/injustamente.png
# Processed and replaced: ./training_data/inquietos.png
# Processed and replaced: ./training_data/Inquisi.png
# Processed and replaced: ./training_data/instante.png
# Processed and replaced: ./training_data/interior.png
# Processed and replaced: ./training_data/interiormente.png
# Processed and replaced: ./training_data/introdu-.png
# Processed and replaced: ./training_data/introduzirse.png
# Processed and replaced: ./training_data/io.png
# Processed and replaced: ./training_data/Italia.png
# Processed and replaced: ./training_data/Iuliaco,.png
# Processed and replaced: ./training_data/Iusticia.png
# Processed and replaced: ./training_data/jamas.png
# Processed and replaced: ./training_data/juftamete.png
# Processed and replaced: ./training_data/jun.png
# Processed and replaced: ./training_data/jus-.png
# Processed and replaced: ./training_data/justicia.png
# Processed and replaced: ./training_data/justificacion.png
# Processed and replaced: ./training_data/justos.png
# Processed and replaced: ./training_data/juyzios.png
# Processed and replaced: ./training_data/juzgadotan.png
# Processed and replaced: ./training_data/juzgando.png
# Processed and replaced: ./training_data/juzgar.png
# Processed and replaced: ./training_data/la (2).png
# Processed and replaced: ./training_data/la (3).png
# Processed and replaced: ./training_data/la (4).png
# Processed and replaced: ./training_data/la.png
# Processed and replaced: ./training_data/labios,atentos.png
# Processed and replaced: ./training_data/lares.png
# Processed and replaced: ./training_data/largamente.png
# Processed and replaced: ./training_data/largos.png
# Processed and replaced: ./training_data/las (2).png
# Processed and replaced: ./training_data/las (3).png
# Processed and replaced: ./training_data/las.png
# Processed and replaced: ./training_data/lastimosas.png
# Processed and replaced: ./training_data/Leon.png
# Processed and replaced: ./training_data/les.png
# Processed and replaced: ./training_data/leve.png
# Processed and replaced: ./training_data/lexos.png
# Processed and replaced: ./training_data/li (2).png
# Processed and replaced: ./training_data/li.png
# Processed and replaced: ./training_data/Liberalidad.png
# Processed and replaced: ./training_data/libreys.png
# Processed and replaced: ./training_data/licencio.png
# Processed and replaced: ./training_data/limos.png
# Processed and replaced: ./training_data/limosneros.png
# Processed and replaced: ./training_data/limpiarle.png
# Processed and replaced: ./training_data/limpio,.png
# Processed and replaced: ./training_data/lla.png
# Processed and replaced: ./training_data/llamado.png
# Processed and replaced: ./training_data/llega.png
# Processed and replaced: ./training_data/llegando.png
# Processed and replaced: ./training_data/llegareys.png
# Processed and replaced: ./training_data/llorado.png
# Processed and replaced: ./training_data/llos.png
# Processed and replaced: ./training_data/lo (2).png
# Processed and replaced: ./training_data/lo.png
# Processed and replaced: ./training_data/locos.png
# Processed and replaced: ./training_data/lorio.png
# Processed and replaced: ./training_data/los (2).png
# Processed and replaced: ./training_data/los (3).png
# Processed and replaced: ./training_data/los (4).png
# Processed and replaced: ./training_data/los (5).png
# Processed and replaced: ./training_data/LOS.png
# Processed and replaced: ./training_data/lugares.png
# Processed and replaced: ./training_data/lum-.png
# Processed and replaced: ./training_data/lumi-.png
# Processed and replaced: ./training_data/lumnas.png
# Processed and replaced: ./training_data/Luys.png
# Processed and replaced: ./training_data/luz.png
# Processed and replaced: ./training_data/ma.png
# Processed and replaced: ./training_data/mable.png
# Processed and replaced: ./training_data/macion.png
# Processed and replaced: ./training_data/mad.png
# Processed and replaced: ./training_data/Madre.png
# Processed and replaced: ./training_data/Maestro.png
# Processed and replaced: ./training_data/Magestad.png
# Processed and replaced: ./training_data/magna-.png
# Processed and replaced: ./training_data/Magno.png
# Processed and replaced: ./training_data/mal.png
# Processed and replaced: ./training_data/maliciosos.png
# Processed and replaced: ./training_data/mandando.png
# Processed and replaced: ./training_data/mani.png
# Processed and replaced: ./training_data/manifiesta,pues.png
# Processed and replaced: ./training_data/manos.png
# Processed and replaced: ./training_data/Manual.png
# Processed and replaced: ./training_data/maquinas.png
# Processed and replaced: ./training_data/Marco.png
# Processed and replaced: ./training_data/Maria.png
# Processed and replaced: ./training_data/mas (2).png
# Processed and replaced: ./training_data/Mas.png
# Processed and replaced: ./training_data/mаs.png
# Processed and replaced: ./training_data/materia.png
# Processed and replaced: ./training_data/mayor.png
# Processed and replaced: ./training_data/mayores.png
# Processed and replaced: ./training_data/medio.png
# Processed and replaced: ./training_data/mejor.png
# Processed and replaced: ./training_data/memoria.png
# Processed and replaced: ./training_data/menes.png
# Processed and replaced: ./training_data/menos.png
# Processed and replaced: ./training_data/menosprecio.png
# Processed and replaced: ./training_data/mentado.png
# Processed and replaced: ./training_data/mercedes.png
# Processed and replaced: ./training_data/merecer.png
# Processed and replaced: ./training_data/mesa,.png
# Processed and replaced: ./training_data/meses.png
# Processed and replaced: ./training_data/mi-.png
# Processed and replaced: ./training_data/mildad.png
# Processed and replaced: ./training_data/miliaridad.png
# Processed and replaced: ./training_data/ministros.png
# Processed and replaced: ./training_data/mios.png
# Processed and replaced: ./training_data/mirad.png
# Processed and replaced: ./training_data/misericordia,la.png
# Processed and replaced: ./training_data/misma.png
# Processed and replaced: ./training_data/mismas.png
# Processed and replaced: ./training_data/mismo.png
# Processed and replaced: ./training_data/Missa.png
# Processed and replaced: ./training_data/Misterio.png
# Processed and replaced: ./training_data/mitas.png
# Processed and replaced: ./training_data/mo-.png
# Processed and replaced: ./training_data/monedas.png
# Processed and replaced: ./training_data/Morales.png
# Processed and replaced: ./training_data/mortales.png
# Processed and replaced: ./training_data/mostrarles.png
# Processed and replaced: ./training_data/mostruosas.png
# Processed and replaced: ./training_data/motivos.png
# Processed and replaced: ./training_data/mucha.png
# Processed and replaced: ./training_data/muchoq.png
# Processed and replaced: ./training_data/muchos.png
# Processed and replaced: ./training_data/muerte.png
# Processed and replaced: ./training_data/muestra.png
# Processed and replaced: ./training_data/muestras.png
# Processed and replaced: ./training_data/mugeres.png
# Processed and replaced: ./training_data/muy.png
# Processed and replaced: ./training_data/na,y.png
# Processed and replaced: ./training_data/nace.png
# Processed and replaced: ./training_data/nacen.png
# Processed and replaced: ./training_data/nacido.png
# Processed and replaced: ./training_data/naciones.png
# Processed and replaced: ./training_data/nada,ni.png
# Processed and replaced: ./training_data/narias.png
# Processed and replaced: ./training_data/nas.png
# Processed and replaced: ./training_data/natu.png
# Processed and replaced: ./training_data/natural.png
# Processed and replaced: ./training_data/necesaria.png
# Processed and replaced: ./training_data/necessitamos.png
# Processed and replaced: ./training_data/negocios.png
# Processed and replaced: ./training_data/nerales.png
# Processed and replaced: ./training_data/nбa.png
# Processed and replaced: ./training_data/nidad.png
# Processed and replaced: ./training_data/niebla.png
# Processed and replaced: ./training_data/nietos.png
# Processed and replaced: ./training_data/nima.png
# Processed and replaced: ./training_data/ningun.png
# Processed and replaced: ./training_data/ninguno.png
# Processed and replaced: ./training_data/nio,a.png
# Processed and replaced: ./training_data/no.png
# Processed and replaced: ./training_data/Nobles,.png
# Processed and replaced: ./training_data/nobleza.png
# Processed and replaced: ./training_data/nombre.png
# Processed and replaced: ./training_data/nos.png
# Processed and replaced: ./training_data/дos.png
# Processed and replaced: ./training_data/nota.png
# Processed and replaced: ./training_data/nua.png
# Processed and replaced: ./training_data/nues.png
# Processed and replaced: ./training_data/nuestra.png
# Processed and replaced: ./training_data/nuestro.png
# Processed and replaced: ./training_data/nuestros.png
# Processed and replaced: ./training_data/nuevas.png
# Processed and replaced: ./training_data/Numa.png
# Processed and replaced: ./training_data/nunca.png
# Processed and replaced: ./training_data/o (2).png
# Processed and replaced: ./training_data/o.png
# Processed and replaced: ./training_data/obfcuro.png
# Processed and replaced: ./training_data/Obispos.png
# Processed and replaced: ./training_data/obli.png
# Processed and replaced: ./training_data/obliga.png
# Processed and replaced: ./training_data/obligacion.png
# Processed and replaced: ./training_data/obligado.png
# Processed and replaced: ./training_data/obligados.png
# Processed and replaced: ./training_data/obligaros.png
# Processed and replaced: ./training_data/obras.png
# Processed and replaced: ./training_data/observase.png
# Processed and replaced: ./training_data/obtenerse.png
# Processed and replaced: ./training_data/ocasiones.png
# Processed and replaced: ./training_data/ociosidad.png
# Processed and replaced: ./training_data/ocu.png
# Processed and replaced: ./training_data/ocul.png
# Processed and replaced: ./training_data/ocultв.png
# Processed and replaced: ./training_data/offiey.png
# Processed and replaced: ./training_data/Oficios.png
# Processed and replaced: ./training_data/ofrecer.png
# Processed and replaced: ./training_data/ofrecerseos.png
# Processed and replaced: ./training_data/ojos.png
# Processed and replaced: ./training_data/oraciones.png
# Processed and replaced: ./training_data/ordinario.png
# Processed and replaced: ./training_data/orfandad.png
# Processed and replaced: ./training_data/ornato.png
# Processed and replaced: ./training_data/oro.png
# Processed and replaced: ./training_data/os (2).png
# Processed and replaced: ./training_data/os (3).png
# Processed and replaced: ./training_data/os.png
# Processed and replaced: ./training_data/otra.png
# Processed and replaced: ./training_data/otras.png
# Processed and replaced: ./training_data/otro.png
# Processed and replaced: ./training_data/otros.png
# Processed and replaced: ./training_data/oveji.png
# Processed and replaced: ./training_data/Oyd.png
# Processed and replaced: ./training_data/oydo.png
# Processed and replaced: ./training_data/oyendo.png
# Processed and replaced: ./training_data/oyendolos.png
# Processed and replaced: ./training_data/pa.png
# Processed and replaced: ./training_data/Pacien.png
# Processed and replaced: ./training_data/paga.png
# Processed and replaced: ./training_data/pagan.png
# Processed and replaced: ./training_data/paдo.png
# Processed and replaced: ./training_data/par.png
# Processed and replaced: ./training_data/para (2).png
# Processed and replaced: ./training_data/para.png
# Processed and replaced: ./training_data/paraef-.png
# Processed and replaced: ./training_data/Parece.png
# Processed and replaced: ./training_data/parecido.png
# Processed and replaced: ./training_data/parte.png
# Processed and replaced: ./training_data/partes.png
# Processed and replaced: ./training_data/particular.png
# Processed and replaced: ./training_data/particulares.png
# Processed and replaced: ./training_data/passar.png
# Processed and replaced: ./training_data/patente.png
# Processed and replaced: ./training_data/patroci.png
# Processed and replaced: ./training_data/paz.png
# Processed and replaced: ./training_data/pellanes.png
# Processed and replaced: ./training_data/penosos.png
# Processed and replaced: ./training_data/per-.png
# Processed and replaced: ./training_data/perador.png
# Processed and replaced: ./training_data/perar.png
# Processed and replaced: ./training_data/perfectas.png
# Processed and replaced: ./training_data/perfo-.png
# Processed and replaced: ./training_data/perfumado.png
# Processed and replaced: ./training_data/perfumar.png
# Processed and replaced: ./training_data/permitiendo.png
# Processed and replaced: ./training_data/permitireys.png
# Processed and replaced: ./training_data/pero.png
# Processed and replaced: ./training_data/Persia.png
# Processed and replaced: ./training_data/persona.png
# Processed and replaced: ./training_data/peso.png
# Processed and replaced: ./training_data/peste.png
# Processed and replaced: ./training_data/pia.png
# Processed and replaced: ./training_data/pidieren.png
# Processed and replaced: ./training_data/pidбrsela.png
# Processed and replaced: ./training_data/pie,en.png
# Processed and replaced: ./training_data/piedad.png
# Processed and replaced: ./training_data/piedras,q.png
# Processed and replaced: ./training_data/piensan.png
# Processed and replaced: ./training_data/pinas.png
# Processed and replaced: ./training_data/pintaros.png
# Processed and replaced: ./training_data/pion,.png
# Processed and replaced: ./training_data/plead.png
# Processed and replaced: ./training_data/poblada.png
# Processed and replaced: ./training_data/podays,meditando.png
# Processed and replaced: ./training_data/podays.png
# Processed and replaced: ./training_data/pode.png
# Processed and replaced: ./training_data/podrian.png
# Processed and replaced: ./training_data/Poetas (2).png
# Processed and replaced: ./training_data/Poetas.png
# Processed and replaced: ./training_data/pofible.png
# Processed and replaced: ./training_data/poner.png
# Processed and replaced: ./training_data/Pontifice.png
# Processed and replaced: ./training_data/por (2).png
# Processed and replaced: ./training_data/por (3).png
# Processed and replaced: ./training_data/por (4).png
# Processed and replaced: ./training_data/poral,.png
# Processed and replaced: ./training_data/porque (2).png
# Processed and replaced: ./training_data/porque.png
# Processed and replaced: ./training_data/possible (2).png
# Processed and replaced: ./training_data/possible.png
# Processed and replaced: ./training_data/Potentados.png
# Processed and replaced: ./training_data/pre.png
# Processed and replaced: ./training_data/preceptos.png
# Processed and replaced: ./training_data/preciad,.png
# Processed and replaced: ./training_data/Preciaos.png
# Processed and replaced: ./training_data/preciar.png
# Processed and replaced: ./training_data/predeterminacion.png
# Processed and replaced: ./training_data/preg.png
# Processed and replaced: ./training_data/Prelados.png
# Processed and replaced: ./training_data/premio.png
# Processed and replaced: ./training_data/premo.png
# Processed and replaced: ./training_data/prendas.png
# Processed and replaced: ./training_data/presas.png
# Processed and replaced: ./training_data/presentarle.png
# Processed and replaced: ./training_data/preside.png
# Processed and replaced: ./training_data/pretendiendo.png
# Processed and replaced: ./training_data/primera.png
# Processed and replaced: ./training_data/primero.png
# Processed and replaced: ./training_data/PrimogВnito.png
# Processed and replaced: ./training_data/Prin (2).png
# Processed and replaced: ./training_data/prin.png
# Processed and replaced: ./training_data/princi.png
# Processed and replaced: ./training_data/principalmente.png
# Processed and replaced: ./training_data/principalmete.png
# Processed and replaced: ./training_data/Principes.png
# Processed and replaced: ./training_data/principio.png
# Processed and replaced: ./training_data/privilegio.png
# Processed and replaced: ./training_data/pro.png
# Processed and replaced: ./training_data/proce.png
# Processed and replaced: ./training_data/procede.png
# Processed and replaced: ./training_data/procuran.png
# Processed and replaced: ./training_data/procuro.png
# Processed and replaced: ./training_data/professando.png
# Processed and replaced: ./training_data/profession.png
# Processed and replaced: ./training_data/promete.png
# Processed and replaced: ./training_data/pronuncian.png
# Processed and replaced: ./training_data/Propheta.png
# Processed and replaced: ./training_data/propia,.png
# Processed and replaced: ./training_data/propio.png
# Processed and replaced: ./training_data/propios.png
# Processed and replaced: ./training_data/prosperidades.png
# Processed and replaced: ./training_data/provecho.png
# Processed and replaced: ./training_data/providencia.png
# Processed and replaced: ./training_data/prudencia.png
# Processed and replaced: ./training_data/prudencias.png
# Processed and replaced: ./training_data/pu.png
# Processed and replaced: ./training_data/publica.png
# Processed and replaced: ./training_data/puede.png
# Processed and replaced: ./training_data/pueden.png
# Processed and replaced: ./training_data/puedo.png
# Processed and replaced: ./training_data/puertas.png
# Processed and replaced: ./training_data/puesto.png
# Processed and replaced: ./training_data/puntos.png
# Processed and replaced: ./training_data/puntual.png
# Processed and replaced: ./training_data/q (2).png
# Processed and replaced: ./training_data/q (3).png
# Processed and replaced: ./training_data/q.png
# Processed and replaced: ./training_data/quadraredes.png
# Processed and replaced: ./training_data/qual (2).png
# Processed and replaced: ./training_data/qual.png
# Processed and replaced: ./training_data/qualidad.png
# Processed and replaced: ./training_data/qualquier.png
# Processed and replaced: ./training_data/qualquiera.png
# Processed and replaced: ./training_data/quan.png
# Processed and replaced: ./training_data/quanto.png
# Processed and replaced: ./training_data/quantos.png
# Processed and replaced: ./training_data/que (2).png
# Processed and replaced: ./training_data/que (3).png
# Processed and replaced: ./training_data/que (4).png
# Processed and replaced: ./training_data/que (5).png
# Processed and replaced: ./training_data/que (6).png
# Processed and replaced: ./training_data/que.png
# Processed and replaced: ./training_data/queda.png
# Processed and replaced: ./training_data/quedando.png
# Processed and replaced: ./training_data/quedar.png
# Processed and replaced: ./training_data/quepa.png
# Processed and replaced: ./training_data/quien.png
# Processed and replaced: ./training_data/quiera.png
# Processed and replaced: ./training_data/quieren.png
# Processed and replaced: ./training_data/Quinto.png
# Processed and replaced: ./training_data/quiso.png
# Processed and replaced: ./training_data/quita.png
# Processed and replaced: ./training_data/quitarles.png
# Processed and replaced: ./training_data/ra.png
# Processed and replaced: ./training_data/rad.png
# Processed and replaced: ./training_data/raleza.png
# Processed and replaced: ./training_data/ran.png
# Processed and replaced: ./training_data/rancifco.png
# Processed and replaced: ./training_data/rara.png
# Processed and replaced: ./training_data/raron.png
# Processed and replaced: ./training_data/rase.png
# Processed and replaced: ./training_data/rc.png
# Processed and replaced: ./training_data/Re-.png
# Processed and replaced: ./training_data/Real.png
# Processed and replaced: ./training_data/realce.png
# Processed and replaced: ./training_data/recatada.png
# Processed and replaced: ./training_data/reci.png
# Processed and replaced: ./training_data/recibidos.png
# Processed and replaced: ./training_data/recibie-.png
# Processed and replaced: ./training_data/recibio,y.png
# Processed and replaced: ./training_data/recibir.png
# Processed and replaced: ./training_data/recogido.png
# Processed and replaced: ./training_data/reconocer.png
# Processed and replaced: ./training_data/reconocimien-.png
# Processed and replaced: ./training_data/rectamente.png
# Processed and replaced: ./training_data/rectisimos.png
# Processed and replaced: ./training_data/redempcion.png
# Processed and replaced: ./training_data/regalos.png
# Processed and replaced: ./training_data/Reli-.png
# Processed and replaced: ./training_data/Religion.png
# Processed and replaced: ./training_data/Religiosas.png
# Processed and replaced: ./training_data/Religioso.png
# Processed and replaced: ./training_data/Religiosos,.png
# Processed and replaced: ./training_data/rendida.png
# Processed and replaced: ./training_data/rendimi.png
# Processed and replaced: ./training_data/rentas (2).png
# Processed and replaced: ./training_data/rentas.png
# Processed and replaced: ./training_data/repartirla.png
# Processed and replaced: ./training_data/reposteros.png
# Processed and replaced: ./training_data/res.png
# Processed and replaced: ./training_data/reser-.png
# Processed and replaced: ./training_data/respec-.png
# Processed and replaced: ./training_data/respecto.png
# Processed and replaced: ./training_data/respeto.png
# Processed and replaced: ./training_data/respondio.png
# Processed and replaced: ./training_data/Retablos.png
# Processed and replaced: ./training_data/reverenciad.png
# Processed and replaced: ./training_data/Rey (2).png
# Processed and replaced: ./training_data/Rey.png
# Processed and replaced: ./training_data/rica.png
# Processed and replaced: ./training_data/rin.png
# Processed and replaced: ./training_data/Ro.png
# Processed and replaced: ./training_data/rodilla.png
# Processed and replaced: ./training_data/rodillas.png
# Processed and replaced: ./training_data/rodos,.png
# Processed and replaced: ./training_data/ron.png
# Processed and replaced: ./training_data/saber.png
# Processed and replaced: ./training_data/sabios.png
# Processed and replaced: ./training_data/Sacra-.png
# Processed and replaced: ./training_data/Sacramentolo.png
# Processed and replaced: ./training_data/saldreys.png
# Processed and replaced: ./training_data/saliendo.png
# Processed and replaced: ./training_data/salir.png
# Processed and replaced: ./training_data/sallos.png
# Processed and replaced: ./training_data/samente.png
# Processed and replaced: ./training_data/San (2).png
# Processed and replaced: ./training_data/San.png
# Processed and replaced: ./training_data/sangre.png
# Processed and replaced: ./training_data/santa (2).png
# Processed and replaced: ./training_data/Santa.png
# Processed and replaced: ./training_data/Santissimo.png
# Processed and replaced: ./training_data/Santo.png
# Processed and replaced: ./training_data/Santos.png
# Processed and replaced: ./training_data/saqueys.png
# Processed and replaced: ./training_data/se.png
# Processed and replaced: ./training_data/sea.png
# Processed and replaced: ./training_data/sean.png
# Processed and replaced: ./training_data/seays.png
# Processed and replaced: ./training_data/sectarios.png
# Processed and replaced: ./training_data/sed.png
# Processed and replaced: ./training_data/seguidor.png
# Processed and replaced: ./training_data/seguir.png
# Processed and replaced: ./training_data/segun.png
# Processed and replaced: ./training_data/selas.png
# Processed and replaced: ./training_data/sencillez.png
# Processed and replaced: ./training_data/Seneca.png
# Processed and replaced: ./training_data/Seno.png
# Processed and replaced: ./training_data/seдor.png
# Processed and replaced: ./training_data/Seдora,.png
# Processed and replaced: ./training_data/Seдores.png
# Processed and replaced: ./training_data/sente.png
# Processed and replaced: ./training_data/sentimiento.png
# Processed and replaced: ./training_data/sepa.png
# Processed and replaced: ./training_data/ser.png
# Processed and replaced: ./training_data/serlo.png
# Processed and replaced: ./training_data/Sermones.png
# Processed and replaced: ./training_data/sernos.png
# Processed and replaced: ./training_data/servaros.png
# Processed and replaced: ./training_data/servido.png
# Processed and replaced: ./training_data/servir.png
# Processed and replaced: ./training_data/Sexto,.png
# Processed and replaced: ./training_data/siem.png
# Processed and replaced: ./training_data/siempre.png
# Processed and replaced: ./training_data/sien-.png
# Processed and replaced: ./training_data/siepre.png
# Processed and replaced: ./training_data/signacion.png
# Processed and replaced: ./training_data/sin.png
# Processed and replaced: ./training_data/sino.png
# Processed and replaced: ./training_data/sintieron.png
# Processed and replaced: ./training_data/siones.png
# Processed and replaced: ./training_data/sirve.png
# Processed and replaced: ./training_data/so.png
# Processed and replaced: ./training_data/soberania.png
# Processed and replaced: ./training_data/sobre.png
# Processed and replaced: ./training_data/sobrenatural.png
# Processed and replaced: ./training_data/Socra.png
# Processed and replaced: ./training_data/Socrates.png
# Processed and replaced: ./training_data/Sol.png
# Processed and replaced: ./training_data/sola.png
# Processed and replaced: ./training_data/solo.png
# Processed and replaced: ./training_data/sombrero.png
# Processed and replaced: ./training_data/son.png
# Processed and replaced: ./training_data/soys.png
# Processed and replaced: ./training_data/su.png
# Processed and replaced: ./training_data/subditos.png
# Processed and replaced: ./training_data/sucede.png
# Processed and replaced: ./training_data/suerte.png
# Processed and replaced: ./training_data/suficiente.png
# Processed and replaced: ./training_data/sufrir,.png
# Processed and replaced: ./training_data/sugetas.png
# Processed and replaced: ./training_data/sujeto.png
# Processed and replaced: ./training_data/sumen.png
# Processed and replaced: ./training_data/Sumo.png
# Processed and replaced: ./training_data/sus.png
# Processed and replaced: ./training_data/sustenteys.png
# Processed and replaced: ./training_data/suyo.png
# Processed and replaced: ./training_data/suyos.png
# Processed and replaced: ./training_data/ta.png
# Processed and replaced: ./training_data/tal.png
# Processed and replaced: ./training_data/talentos.png
# Processed and replaced: ./training_data/tales.png
# Processed and replaced: ./training_data/taleza.png
# Processed and replaced: ./training_data/tambien.png
# Processed and replaced: ./training_data/tamente.png
# Processed and replaced: ./training_data/Tampoco.png
# Processed and replaced: ./training_data/tan.png
# Processed and replaced: ./training_data/tando.png
# Processed and replaced: ./training_data/tanta.png
# Processed and replaced: ./training_data/tantas.png
# Processed and replaced: ./training_data/tanto.png
# Processed and replaced: ./training_data/tantos.png
# Processed and replaced: ./training_data/te.png
# Processed and replaced: ./training_data/tecessores.png
# Processed and replaced: ./training_data/Templanca,ifmo,Obe.png
# Processed and replaced: ./training_data/Templos,ef-.png
# Processed and replaced: ./training_data/tempora-.png
# Processed and replaced: ./training_data/tempos,.png
# Processed and replaced: ./training_data/ten.png
# Processed and replaced: ./training_data/tendra.png
# Processed and replaced: ./training_data/tendreys.png
# Processed and replaced: ./training_data/tener (2).png
# Processed and replaced: ./training_data/tener.png
# Processed and replaced: ./training_data/tengan.png
# Processed and replaced: ./training_data/tengo.png
# Processed and replaced: ./training_data/ter.png
# Processed and replaced: ./training_data/tereses.png
# Processed and replaced: ./training_data/tes.png
# Processed and replaced: ./training_data/Theodosio.png
# Processed and replaced: ./training_data/Theologales,MoraleslaPen.png
# Processed and replaced: ./training_data/tia.png
# Processed and replaced: ./training_data/tial.png
# Processed and replaced: ./training_data/tiempo.png
# Processed and replaced: ./training_data/tiempos,oi.png
# Processed and replaced: ./training_data/tiernos.png
# Processed and replaced: ./training_data/Tiles.png
# Processed and replaced: ./training_data/Tito (2).png
# Processed and replaced: ./training_data/titulo.png
# Processed and replaced: ./training_data/tivar.png
# Processed and replaced: ./training_data/to.png
# Processed and replaced: ./training_data/toca.png
# Processed and replaced: ./training_data/tocantes.png
# Processed and replaced: ./training_data/tocar.png
# Processed and replaced: ./training_data/toda (2).png
# Processed and replaced: ./training_data/toda.png
# Processed and replaced: ./training_data/todas.png
# Processed and replaced: ./training_data/todo.png
# Processed and replaced: ./training_data/todos,.png
# Processed and replaced: ./training_data/toleran.png
# Processed and replaced: ./training_data/tomad.png
# Processed and replaced: ./training_data/tomando.png
# Processed and replaced: ./training_data/toque.png
# Processed and replaced: ./training_data/tos.png
# Processed and replaced: ./training_data/trabajo,.png
# Processed and replaced: ./training_data/trabajos.png
# Processed and replaced: ./training_data/traerle.png
# Processed and replaced: ./training_data/Trajano.png
# Processed and replaced: ./training_data/tras.png
# Processed and replaced: ./training_data/tratar.png
# Processed and replaced: ./training_data/tratarlos.png
# Processed and replaced: ./training_data/trato.png
# Processed and replaced: ./training_data/trayan.png
# Processed and replaced: ./training_data/tre.png
# Processed and replaced: ./training_data/tres.png
# Processed and replaced: ./training_data/trinit.png
# Processed and replaced: ./training_data/triunfo.png
# Processed and replaced: ./training_data/tro.png
# Processed and replaced: ./training_data/tros.png
# Processed and replaced: ./training_data/truhanes.png
# Processed and replaced: ./training_data/truxeron.png
# Processed and replaced: ./training_data/tu.png
# Processed and replaced: ./training_data/tuoso.png
# Processed and replaced: ./training_data/turales.png
# Processed and replaced: ./training_data/tutela (2).png
# Processed and replaced: ./training_data/tutela.png
# Processed and replaced: ./training_data/tuviera.png
# Processed and replaced: ./training_data/ultimamente.png
# Processed and replaced: ./training_data/una.png
# Processed and replaced: ./training_data/uno.png
# Processed and replaced: ./training_data/unos.png
# Processed and replaced: ./training_data/uplem.png
# Processed and replaced: ./training_data/usan.png
# Processed and replaced: ./training_data/usar.png
# Processed and replaced: ./training_data/useys.png
# Processed and replaced: ./training_data/va-.png
# Processed and replaced: ./training_data/vad.png
# Processed and replaced: ./training_data/vaffallos.png
# Processed and replaced: ./training_data/valde,y.png
# Processed and replaced: ./training_data/valernos.png
# Processed and replaced: ./training_data/valor.png
# Processed and replaced: ./training_data/van.png
# Processed and replaced: ./training_data/varias.png
# Processed and replaced: ./training_data/vas.png
# Processed and replaced: ./training_data/vasallos.png
# Processed and replaced: ./training_data/vassallos.png
# Processed and replaced: ./training_data/vayan-.png
# Processed and replaced: ./training_data/vemos.png
# Processed and replaced: ./training_data/vendiciendo.png
# Processed and replaced: ./training_data/vene-.png
# Processed and replaced: ./training_data/venerad.png
# Processed and replaced: ./training_data/venereys,y.png
# Processed and replaced: ./training_data/venia.png
# Processed and replaced: ./training_data/veniencia.png
# Processed and replaced: ./training_data/veo.png
# Processed and replaced: ./training_data/ver.png
# Processed and replaced: ./training_data/verdadera.png
# Processed and replaced: ./training_data/verdades.png
# Processed and replaced: ./training_data/versos.png
# Processed and replaced: ./training_data/Viatico.png
# Processed and replaced: ./training_data/vicios.png
# Processed and replaced: ./training_data/vida (2).png
# Processed and replaced: ./training_data/vida.png
# Processed and replaced: ./training_data/vien-.png
# Processed and replaced: ./training_data/viendole.png
# Processed and replaced: ./training_data/vinculada.png
# Processed and replaced: ./training_data/vio.png
# Processed and replaced: ./training_data/Vir-.png
# Processed and replaced: ./training_data/Virgen.png
# Processed and replaced: ./training_data/virtud (2).png
# Processed and replaced: ./training_data/virtud.png
# Processed and replaced: ./training_data/virtudes.png
# Processed and replaced: ./training_data/virtuo-.png
# Processed and replaced: ./training_data/virtuosa.png
# Processed and replaced: ./training_data/virtuoso.png
# Processed and replaced: ./training_data/vitra.png
# Processed and replaced: ./training_data/vivir.png
# Processed and replaced: ./training_data/vna.png
# Processed and replaced: ./training_data/vos,.png
# Processed and replaced: ./training_data/vosotros.png
# Processed and replaced: ./training_data/vueftra (2).png
# Processed and replaced: ./training_data/vueftra.png
# Processed and replaced: ./training_data/vuestras.png
# Processed and replaced: ./training_data/vuestro.png
# Processed and replaced: ./training_data/vuestros.png
# Processed and replaced: ./training_data/xandro.png
# Processed and replaced: ./training_data/y (2).png
# Processed and replaced: ./training_data/y (3).png
# Processed and replaced: ./training_data/y (4).png
# Processed and replaced: ./training_data/yadornarlas.png
# Processed and replaced: ./training_data/ye.png
# Processed and replaced: ./training_data/yo.png
# Processed and replaced: ./training_data/za (2).png
# Processed and replaced: ./training_data/za.png
# Processed and replaced: ./training_data/zelo.png
# Processed and replaced: ./training_data/zer.png
# Processed and replaced: ./training_data/zidas.png

# %% [markdown]
# ### Image Augmentation by Rotation

# %%
from utils import rotation_aug

training_data = './training_data'
rotation_aug(training_data)
print("Image augmentation by Rotation completed.")
# Out:
# Image augmentation by Rotation completed.

# %% [markdown]
# ### Image augmentation by Gaussian Noise

# %%
from utils import gaussian_noise_aug

training_data = './training_data'
gaussian_noise_aug(training_data)
print("Image augmentation by Gaussian Noise completed.")
# Out:
# Image augmentation by Gaussian Noise completed.

# %% [markdown]
# ### This part of code creates structured CSV files that can be used to organize and access the image data for future task, particularly for training and testing an OCR (Optical Character Recognition) model.

# %%
from utils import create_csv_from_folder

# Train data
training_data = './training_data'
train_csv_path = './training_data.csv'
create_csv_from_folder(training_data, train_csv_path)

# Test data
test_data1 = "./testing_data1"
test_csv_path1 = './testing_data1.csv'
create_csv_from_folder(test_data1, test_csv_path1)
# Out:
# CSV file "./training_data.csv" created successfully.
# CSV file "./testing_data1.csv" created successfully.

# %% [markdown]
# ### Splitting train and test dataset

# %%
df = pd.read_csv('training_data.csv')
df.shape
# Out:
# (26730, 2)

# %% [markdown]
# ### create a new column IDENTITY that contain the label of the images

# %%
df['IDENTITY'] = df['IDENTITY'].apply(lambda x: x.split('_')[0]).apply(lambda x: x.split(' ')[0])

# %%
TRAIN_SIZE = int(df.shape[0]*0.8)
df_train = df.iloc[:TRAIN_SIZE]
df_valid = df.iloc[TRAIN_SIZE+1:]

# %%
df_train.to_csv('train.csv', index=False)
df_train.head()
# Out:
#        FILENAME  IDENTITY
# 0         a.png         a
# 1    abatio.png    abatio
# 2  abatirse.png  abatirse
# 3    aborre.png    aborre
# 4        ac.png        ac

# %%
df_valid.to_csv('valid.csv', index=False)
df_valid.head()
# Out:
#                    FILENAME IDENTITY
# 21385  meses_rot1_gauss.png    meses
# 21386  meses_rot2_gauss.png    meses
# 21387  meses_rot3_gauss.png    meses
# 21388  meses_rot4_gauss.png    meses
# 21389  meses_rot5_gauss.png    meses

# %% [markdown]
# ### This code sets up configuration parameters and file paths for training, validating, and testing an OCR model, including image size, batch size, number of epochs, model name, callbacks, learning rate, random seeds, dataset file paths, data sizes, and prefetching settings.

# %%
# Image Size
IMG_WIDTH = 200
IMG_HEIGHT = 50
IMAGE_SIZE = (IMG_WIDTH, IMG_HEIGHT)

# Batch Size
BATCH_SIZE = 100

# EPOCHS
EPOCHS = 100

# Model Name
MODEL_NAME = 'SpanishOCR'

# Callbacks
CALLBACKS = [
    callbacks.EarlyStopping(patience=10, restore_best_weights=True),
    callbacks.ModelCheckpoint(filepath=MODEL_NAME + ".h5", save_best_only=True)  # .h5 extension removed
]

# Learning Rate
LEARNING_RATE = 1e-3

# Random Seed
np.random.seed(2569)
tf.random.set_seed(2569)

# File Paths ( replace 1 by 2,3 ... so as to test other folders)
train_csv_path = './train.csv'
valid_csv_path = './valid.csv'
test_csv_path = './testing_data1.csv'

train_image_dir = './training_data'
valid_image_dir = './training_data'
test_image_dir = './testing_data1'

# AUTOTUNE
AUTOTUNE = tfd.AUTOTUNE

# %%
# Train CSV
train_csv = pd.read_csv(train_csv_path)

# Validation CSV
valid_csv = pd.read_csv(valid_csv_path)

# Test CSV
test_csv = pd.read_csv(test_csv_path)

# %%
# In order to convert int to string to prevent tf error
test_csv['IDENTITY'] = test_csv['IDENTITY'].apply(lambda x: str(x))

# %%
labels = [str(word) for word in df['IDENTITY'].to_numpy()]
labels[:10]
# Out:
# ['a',
#  'abatio',
#  'abatirse',
#  'aborre',
#  'ac',
#  'acavallo',
#  'acciones',
#  'acometer',
#  'Acudireys',
#  'Acuдa']

# %% [markdown]
# ### This code extracts unique characters from the dataset labels, calculates the total number of unique characters, and prints both the count and the set of unique characters

# %%
# Unique characters
unique_chars = set(char for word in labels for char in word)
n_classes = len(unique_chars)

# Show
print(f"Total number of unique characters : {n_classes}")
print(f"Unique Characters : \n{unique_chars}")
# Out:
# Total number of unique characters : 50
# Unique Characters :
# {'g', 't', 'x', 'P', 'В', 'C', 'T', 'N', 'R', '-', 's', 'S', 'e', 'q', 'm', 'A', 'f', 'H', 'z', 'д', 'l', 'D', 'G', 'b', 'r', 'a', 'Q', 'I', 'F', 'd', 'в', 'а', 'б', 'o', 'i', 'j', 'B', 'n', 'u', 'O', 'M', 'L', 'c', 'y', ',', 'h', 'p', 'v', 'V', 'E'}

# %%
MAX_LABEL_LENGTH = max(map(len, labels))
print(f"Maximum length of a label : {MAX_LABEL_LENGTH}")
# Out:
# Maximum length of a label : 24

# %% [markdown]
# ### This code updates the file paths in the FILENAME columns of the training, validation, and test CSV dataframes by prepending the respective image directory paths to each filename.

# %%
train_csv['FILENAME'] = [train_image_dir + f"/{filename}" for filename in train_csv['FILENAME']]
valid_csv['FILENAME'] = [valid_image_dir + f"/{filename}" for filename in valid_csv['FILENAME']]
test_csv['FILENAME']  = [test_image_dir + f"/{filename}" for filename in test_csv['FILENAME']]

# %%
train_csv.head()
# Out:
#                        FILENAME  IDENTITY
# 0         ./training_data/a.png         a
# 1    ./training_data/abatio.png    abatio
# 2  ./training_data/abatirse.png  abatirse
# 3    ./training_data/aborre.png    aborre
# 4        ./training_data/ac.png        ac

# %%
test_csv.head()
# Out:
#                   FILENAME IDENTITY
# 0  ./testing_data1/0;0.png      0;0
# 1  ./testing_data1/1;0.png      1;0
# 2  ./testing_data1/2;0.png      2;0
# 3  ./testing_data1/3;0.png      3;0
# 4  ./testing_data1/4;0.png      4;0

# %% [markdown]
# ### This code creates two dictionaries: one that maps unique characters to numeric values using StringLookup, and another that reverses this mapping, converting numeric values back to characters.

# %%
# Character to numeric value dictionary
char_to_num = layers.StringLookup(
    vocabulary = list(unique_chars),
    mask_token = None
)

# Reverse dictionary
num_to_char = layers.StringLookup(
    vocabulary = char_to_num.get_vocabulary(),
    mask_token = None,
    invert = True
)

# %% [markdown]
# ### This function loads an image from a given path, decodes it as a JPEG, converts it to a tensor, resizes and normalizes it, and then returns the processed image as a tensor.

# %%
def load_image(image_path : str):
    '''
    This function loads and preprocesses images. It first receives the image path, which is used to
    decode the image as a JPEG using TensorFlow. Then, it converts the image to a tensor and applies
    two processing functions: resizing and normalization. The processed image is then returned by
    the function.

    Argument :
        image_path : The path of the image file to be loaded.

    Return:
        image : The loaded image as a tensor.
    '''

    # Read the Image
    image = tf.io.read_file(image_path)

    # Decode the image
    decoded_image = tf.image.decode_jpeg(contents = image, channels = 1)

    # Convert image data type.
    cnvt_image = tf.image.convert_image_dtype(image = decoded_image, dtype = tf.float32)

    # Resize the image
    resized_image = tf.image.resize(images = cnvt_image, size = (IMG_HEIGHT, IMG_WIDTH))

    # Transpose
    image = tf.transpose(resized_image, perm = [1, 0, 2])

    # Convert image to a tensor.
    image = tf.cast(image, dtype = tf.float32)

    # Return loaded image
    return image

# %% [markdown]
# ### This function loads and preprocesses an image, converts a given label string into a sequence of numeric values, pads the numeric sequence to a fixed length, and returns a dictionary containing the processed image tensor and the label tensor.

# %%
def encode_single_sample(image_path : str, label : str):

    '''
    The function takes an image path and label as input and returns a dictionary containing the processed image tensor and the label tensor.
    First, it loads the image using the load_image function, which decodes and resizes the image to a specific size. Then it converts the given
    label string into a sequence of Unicode characters using the unicode_split function. Next, it uses the char_to_num layer to convert each
    character in the label to a numerical representation. It pads the numerical representation with a special class (n_classes)
    to ensure that all labels have the same length (MAX_LABEL_LENGTH). Finally, it returns a dictionary containing the processed image tensor
    and the label tensor.

    Arguments :
        image_path : The location of the image file.
        label      : The text to present in the image.

    Returns:
        dict : A dictionary containing the processed image and label.
    '''

    # Get the image
    image = load_image(image_path)

    # Convert the label into characters
    chars = tf.strings.unicode_split(label, input_encoding='UTF-8')

    # Convert the characters into vectors
    vecs = char_to_num(chars)

    # Pad label
    pad_size = MAX_LABEL_LENGTH - tf.shape(vecs)[0]
    vecs = tf.pad(vecs, paddings = [[0, pad_size]], constant_values=n_classes+1)

    return {'image':image, 'label':vecs}

# %% [markdown]
# ### This code splits the combined dataset into training and validation subsets, shuffles the data, and then creates batched and prefetched TensorFlow datasets for efficient data loading during model training.

# %%
# Further split the training dataset into training and validation subsets
train_size = int(0.8*len(df))  # 80% of the training data for training
val_size = len(df) - train_size  # Remaining 20% for validation

# Splitting the training dataset
train_ds = tf.data.Dataset.from_tensor_slices(
    (np.array(df['FILENAME'].to_list()), np.array(df['IDENTITY'].to_list()))
).shuffle(train_size)

# Create training dataset
train_ds = train_ds.take(train_size).batch(BATCH_SIZE).prefetch(AUTOTUNE)

# Create validation dataset
valid_ds = train_ds.skip(train_size).batch(BATCH_SIZE).prefetch(AUTOTUNE)

# %% [markdown]
# ### This code creates TensorFlow datasets for training, validation, and testing by loading image paths and labels, shuffling the training data, applying the encode_single_sample function to preprocess the images and labels, batching the data, and using prefetching for optimized data loading.

# %%
# Training Data
train_ds = tf.data.Dataset.from_tensor_slices(
    (np.array(train_csv['FILENAME'].to_list()), np.array(train_csv['IDENTITY'].to_list()))
).shuffle(train_size).map(encode_single_sample, num_parallel_calls=AUTOTUNE).batch(BATCH_SIZE).prefetch(AUTOTUNE)

# # Validation data
valid_ds = tf.data.Dataset.from_tensor_slices(
    (np.array(valid_csv['FILENAME'].to_list()), np.array(valid_csv['IDENTITY'].to_list()))
).map(encode_single_sample, num_parallel_calls=AUTOTUNE).batch(BATCH_SIZE).prefetch(AUTOTUNE)

# # Testing data.
test_ds = tf.data.Dataset.from_tensor_slices(
    (np.array(test_csv['FILENAME'].to_list()), np.array(test_csv['IDENTITY'].to_list()))
).map(encode_single_sample, num_parallel_calls=AUTOTUNE).batch(BATCH_SIZE).prefetch(AUTOTUNE)

# %%
print(f"Training Data Size   : {tf.data.Dataset.cardinality(train_ds).numpy() * BATCH_SIZE}")
print(f"Validation Data Size : {tf.data.Dataset.cardinality(valid_ds).numpy() * BATCH_SIZE}")
print(f"Testing Data Size    : {tf.data.Dataset.cardinality(test_ds).numpy() * BATCH_SIZE}")
# Out:
# Training Data Size   : 21400
# Validation Data Size : 5400
# Testing Data Size    : 900

# %% [markdown]
# ### Resizes all images in the input folder to a specified size and saves them as PNG files in the output folder, ensuring the output directory exists.

# %%
# Set the new size in pixels (width, height) according to your choice
def resize_images_in_folder(input_folder, new_size=(200,50)):
    # Loop through all files in the input folder
    for filename in os.listdir(input_folder):
        # Open the image
        with Image.open(os.path.join(input_folder, filename)) as img:
            # Resize the image
            resized_img = img.resize(new_size)
            # Save the resized image to the output folder
            output_filename = os.path.splitext(filename)[0] + '.png'  # Ensure output format is PNG
            resized_img.save(os.path.join(input_folder, output_filename))

training_image_dir = "./training_data"
resize_images_in_folder(training_image_dir)

test_image_dir = "./testing_data1"
resize_images_in_folder(test_image_dir)

# %% [markdown]
# ### Displays a grid of images with their true labels, and optionally their predicted labels if a model is provided, using Matplotlib for visualization.

# %%
def show_images(data, GRID=[4,4], FIGSIZE=(25, 8), cmap='binary_r', model=None, decode_pred=None):

    # Plotting configurations
    plt.figure(figsize=FIGSIZE)
    n_rows, n_cols = GRID

    # Loading Data
    data = next(iter(data))
    images, labels = data['image'], data['label']

    # Iterate over the data
    for index, (image, label) in enumerate(zip(images, labels)):

        # Label processing
        text_label = num_to_char(label)
        text_label = tf.strings.reduce_join(text_label).numpy().decode('UTF-8')
        text_label = text_label.replace("[UNK]", " ").strip()

        # Create a sub plot
        plt.subplot(n_rows, n_cols, index+1)
        plt.imshow(tf.transpose(image, perm=[1,0,2]), cmap=cmap)
        plt.axis('off')

        if model is not None and decode_pred is not None:
            # Make prediction
            pred = model.predict(tf.expand_dims(image, axis=0))
            pred = decode_pred(pred)[0]
            title = f"True : {text_label}\nPred : {pred}"
            plt.title(title)
        else:
            # add title
            plt.title(text_label)

    # Show the final plot
    cls()
    plt.show()

# %%
show_images(data=train_ds, cmap='gray')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[130], line 1
# ----> 1 show_images(data=train_ds, cmap='gray')
#
# Cell In[129], line 20, in show_images(data, GRID, FIGSIZE, cmap, model, decode_pred)
#      17 text_label = text_label.replace("[UNK]", " ").strip()
#      19 # Create a sub plot
# ---> 20 plt.subplot(n_rows, n_cols, index+1)
#      21 plt.imshow(tf.transpose(image, perm=[1,0,2]), cmap=cmap)
#      22 plt.axis('off')
#
# File ~/anaconda3/envs/renaissance/lib/python3.9/site-packages/matplotlib/pyplot.py:1534, in subplot(*args, **kwargs)
#    1531 fig = gcf()
#    1533 # First, search for an existing subplot with a matching spec.
# -> 1534 key = SubplotSpec._from_subplot_args(fig, args)
#    1536 for ax in fig.axes:
#    1537     # If we found an Axes at the position, we can reuse it if the user passed no
#    1538     # kwargs or if the Axes class and kwargs are identical.
#    1539     if (ax.get_subplotspec() == key
#    1540         and (kwargs == {}
#    1541              or (ax._projection_init
#    1542                  == fig._process_projection_requirements(**kwargs)))):
#
# File ~/anaconda3/envs/renaissance/lib/python3.9/site-packages/matplotlib/gridspec.py:589, in SubplotSpec._from_subplot_args(figure, args)
#     587 else:
#     588     if not isinstance(num, Integral) or num < 1 or num > rows*cols:
# --> 589         raise ValueError(
#     590             f"num must be an integer with 1 <= num <= {rows*cols}, "
#     591             f"not {num!r}"
#     592         )
#     593     i = j = num
#     594 return gs[i-1:j]
#
# ValueError: num must be an integer with 1 <= num <= 16, not 17

# %%
show_images(data=test_ds, cmap='gray')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[103], line 1
# ----> 1 show_images(data=test_ds, cmap='gray')
#
# Cell In[101], line 20, in show_images(data, GRID, FIGSIZE, cmap, model, decode_pred)
#      17 text_label = text_label.replace("[UNK]", " ").strip()
#      19 # Create a sub plot
# ---> 20 plt.subplot(n_rows, n_cols, index+1)
#      21 plt.imshow(tf.transpose(image, perm=[1,0,2]), cmap=cmap)
#      22 plt.axis('off')
#
# File ~/anaconda3/envs/renaissance/lib/python3.9/site-packages/matplotlib/pyplot.py:1534, in subplot(*args, **kwargs)
#    1531 fig = gcf()
#    1533 # First, search for an existing subplot with a matching spec.
# -> 1534 key = SubplotSpec._from_subplot_args(fig, args)
#    1536 for ax in fig.axes:
#    1537     # If we found an Axes at the position, we can reuse it if the user passed no
#    1538     # kwargs or if the Axes class and kwargs are identical.
#    1539     if (ax.get_subplotspec() == key
#    1540         and (kwargs == {}
#    1541              or (ax._projection_init
#    1542                  == fig._process_projection_requirements(**kwargs)))):
#
# File ~/anaconda3/envs/renaissance/lib/python3.9/site-packages/matplotlib/gridspec.py:589, in SubplotSpec._from_subplot_args(figure, args)
#     587 else:
#     588     if not isinstance(num, Integral) or num < 1 or num > rows*cols:
# --> 589         raise ValueError(
#     590             f"num must be an integer with 1 <= num <= {rows*cols}, "
#     591             f"not {num!r}"
#     592         )
#     593     i = j = num
#     594 return gs[i-1:j]
#
# ValueError: num must be an integer with 1 <= num <= 16, not 17

# %% [markdown]
# # Model Definition

# %% [markdown]
# ### Defines a custom Keras layer that computes and adds the Connectionist Temporal Classification (CTC) loss to the model for training sequence-to-sequence prediction tasks.

# %%
class CTCLayer(layers.Layer):
    def __init__(self, **kwargs) -> None:
        super().__init__(**kwargs)
        self.loss_fn = keras.backend.ctc_batch_cost
    def call(self, y_true, y_pred):
        batch_len = tf.cast(tf.shape(y_true)[0], dtype='int64')
        input_len = tf.cast(tf.shape(y_pred)[1], dtype='int64') * tf.ones(shape=(batch_len, 1), dtype='int64')
        label_len = tf.cast(tf.shape(y_true)[1], dtype='int64') * tf.ones(shape=(batch_len, 1), dtype='int64')
        loss = self.loss_fn(y_true, y_pred, input_len, label_len)
        self.add_loss(loss)
        return y_pred

# %% [markdown]
# ### Decodes the predicted labels from the OCR model, converting numeric values back to characters and removing unknown tokens to produce the final text output.

# %%
def decode_pred(pred_label):

    '''
    The decode_pred function is used to decode the predicted labels generated by the OCR model.
    It takes a matrix of predicted labels as input, where each time step represents the probability
    for each character. The function uses CTC decoding to decode the numeric labels back into their
    character values. The function also removes any unknown tokens and returns the decoded texts as a
    list of strings. The function utilizes the num_to_char function to map numeric values back to their
    corresponding characters. Overall, the function is an essential step in the OCR process, as it allows
    us to obtain the final text output from the model's predictions.

    Argument :
        pred_label : These are the model predictions which are needed to be decoded.

    Return:
        filtered_text : This is the list of all the decoded and processed predictions.

    '''

    # Input length
    input_len = np.ones(shape=pred_label.shape[0]) * pred_label.shape[1]

    # CTC decode
    decode = keras.backend.ctc_decode(pred_label, input_length=input_len, greedy=True)[0][0][:,:MAX_LABEL_LENGTH]

    # Converting numerics back to their character values
    chars = num_to_char(decode)

    # Join all the characters
    texts = [tf.strings.reduce_join(inputs=char).numpy().decode('UTF-8') for char in chars]

    # Remove the unknown token
    filtered_texts = [text.replace('[UNK]', " ").strip() for text in texts]

    return filtered_texts

# %% [markdown]
# ### This code defines a deep learning model for optical character recognition (OCR) using a combination of convolutional neural networks (CNNs) for feature extraction and bidirectional long short-term memory (LSTM) networks for sequence learning, concluding with a custom CTC loss layer for training.

# %%
# Input Layer
input_images = layers.Input(shape=(IMG_WIDTH, IMG_HEIGHT, 1), name="image")

# Labels : These are added for the training purpose.
target_labels = layers.Input(shape=(None, ), name="label")

# CNN Network
x = layers.Conv2D(
    filters=32,
    kernel_size=3,
    strides=1,
    padding='same',
    activation='relu',
    kernel_initializer='he_normal'
)(input_images)
x = layers.BatchNormalization()(x)

x = layers.Conv2D(
    filters=32,
    kernel_size=3,
    strides=1,
    padding='same',
    activation='relu',
    kernel_initializer='he_normal'
)(x)
x = layers.BatchNormalization()(x)

x = layers.MaxPool2D(pool_size=(2,2), strides=(2,2))(x)

x = layers.Conv2D(
    filters=64,
    kernel_size=3,
    strides=1,
    padding='same',
    activation='relu',
    kernel_initializer='he_normal'
)(x)
x = layers.BatchNormalization()(x)

x = layers.Conv2D(
    filters=128,
    kernel_size=3,
    strides=1,
    padding='same',
    activation='relu',
    kernel_initializer='he_normal'
)(x)
x = layers.BatchNormalization()(x)

x = layers.MaxPool2D(pool_size=(2,2), strides=(2,2))(x)

# Encoding Space
encoding = layers.Reshape(target_shape=((IMG_WIDTH//4), (IMG_HEIGHT//4)*128))(x)
encoding = layers.Dense(128, activation='relu', kernel_initializer='he_normal')(encoding)
encoding = layers.Dropout(0.5)(encoding)

# RNN Network
x = layers.Bidirectional(layers.LSTM(256, return_sequences=True, dropout=0.5))(encoding)
x = layers.Bidirectional(layers.LSTM(128, return_sequences=True, dropout=0.5))(x)

# Output Layer
output = layers.Dense(len(char_to_num.get_vocabulary())+1, activation='softmax')(x)

# CTC Layer
ctc_layer = CTCLayer()(target_labels, output)

# Model
ocr_model = keras.Model(
    inputs=[input_images, target_labels],
    outputs=[ctc_layer]
)

# %%
plot_model(ocr_model, show_shapes=True, show_layer_names=True)

# %% [markdown]
# ### Compiles the OCR model with the Adam optimizer and trains it on the training dataset with validation, using early stopping and model checkpoint callbacks.

# %%
# Compile
ocr_model.compile(optimizer=keras.optimizers.Adam(learning_rate=1e-3))

# Learning Rate Scheduler
lr_scheduler = callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=3,
    verbose=1,
    min_lr=1e-6
)

# Train
history = ocr_model.fit(
    train_ds,
    validation_data=valid_ds,
    epochs=EPOCHS,
    callbacks=[
        callbacks.EarlyStopping(patience=5, restore_best_weights=True),
        lr_scheduler
    ]
)

# Learning Curve
pd.DataFrame(history.history).plot(figsize=(8,5))
plt.legend(fontsize=15)
plt.xlabel("Epochs")
plt.ylabel("CTC Loss Score")
plt.title("Learning Curve", fontsize=15)
plt.grid()
plt.show()
# Out:
# Epoch 1/100
#  24/214 ━━━━━━━━━━━━━━━━━━━━ 3:07 987ms/step - loss: 6559.3384

# %%
# Model Summary
ocr_model.summary()

# %% [markdown]
# ### Creates an inference model from the trained OCR model for making predictions and prints the model summary.

# %%
inference_model = keras.Model(
    inputs=ocr_model.input[0],  # Use only the first input if multiple
    outputs=ocr_model.get_layer(name="dense_1").output  # Adjust output layer name
)

# %%
print(decode_pred(inference_model.predict(test_ds))[:10])   #convert to test_ds

# %%
show_images(data=train_ds, model=inference_model, decode_pred=decode_pred, cmap='binary')

# %%
show_images(data=valid_ds, model=inference_model, decode_pred=decode_pred, cmap='binary')

# %%
show_images(data=test_ds, model=inference_model, decode_pred=decode_pred, cmap='binary')

# %% [markdown]
# # Saving the model

# %%
# Saving the model
ocr_model.save('ocr_model.keras')

# %% [markdown]
# ### Generates and decodes predictions from the inference model on the test dataset, printing the results as it is written in the book.

# %%
test_csv.head()

# %%
df_infer = test_csv

# Step 1: Sort the dataframe based on values before ';'
df_infer['before_semicolon'] = df_infer['IDENTITY'].apply(lambda x: int(x.split(';')[0]))
df_infer['after_semicolon'] = df_infer['IDENTITY'].apply(lambda x: int(x.split(';')[1]))
sorted_df = df_infer.sort_values(['before_semicolon']).reset_index(drop=True)
sorted_df.drop(columns=['before_semicolon', 'after_semicolon'], inplace=True)

# %%
sorted_df.shape

# %%
sorted_df.head()

# %%
sorted_df['IDENTITY'] = sorted_df['IDENTITY'].astype(str)

sorted_dfs = tf.data.Dataset.from_tensor_slices(
    (np.array(sorted_df['FILENAME'].to_list()), np.array(sorted_df['IDENTITY'].to_list()))
).map(encode_single_sample, num_parallel_calls=AUTOTUNE).batch(BATCH_SIZE).prefetch(AUTOTUNE)

decoded_predictions = decode_pred(inference_model.predict(sorted_dfs))

# %%
sorted_df.head()

# %%
pred = sorted_df['IDENTITY'].tolist()

# Print decoded predictions with a new line when there's a change in the number after ';'
current_group = None
i=0
for prediction in pred:
    before, after = map(int, prediction.split(';'))

    if current_group is None:
        current_group = after

    if after != current_group:
        print()  # Start a new line for the new group
        current_group = after

    print(decoded_predictions[i], end=' ')
    i+=1
print()

# %% [markdown]
# # Saving pedictions as .txt file

# %%
formatted_output = []

current_group = None
i = 0
for prediction in pred:
    before, after = map(int, prediction.split(';'))

    if current_group is None:
        current_group = after

    if after != current_group:
        formatted_output.append('\n')  # Start a new line for the new group
        current_group = after

    formatted_output.append(decoded_predictions[i] + ' ')
    i += 1

formatted_output.append('\n')  # Final new line

with open('formatted_predictions.txt', 'w') as file:
    file.writelines(formatted_output)

# %%
predictions = decode_pred(inference_model.predict(valid_ds))
true = df_valid['IDENTITY'].tolist()

# %%
import numpy as np
from difflib import SequenceMatcher

def calculate_cer(predicted, ground_truth):
    # Calculate the Levenshtein distance between the predicted and ground truth
    matcher = SequenceMatcher(None, ground_truth, predicted)
    num_edits = sum(triple[-1] for triple in matcher.get_opcodes() if triple[0] != 'equal')

    # CER is the number of edits divided by the total number of characters in the ground truth
    return num_edits / len(ground_truth) if len(ground_truth) > 0 else 1.0

def calculate_accuracy(true_list, predictions_list):
    correct_count = sum([pred == gt for pred, gt in zip(predictions_list, true_list)])
    return correct_count / len(true_list)

# Calculate CER for each word and the overall Accuracy
cer_list = [calculate_cer(pred, gt) for pred, gt in zip(predictions, true)]
cer = np.mean(cer_list)

accuracy = calculate_accuracy(true, predictions)

print(f"Character Error Rate (CER): {cer}")
print(f"Accuracy: {accuracy}")

# %%
sorted_df = tf.data.Dataset.from_tensor_slices(
    (np.array(sorted_df['FILENAME'].to_list()), np.array(sorted_df['IDENTITY'].to_list()))
).map(encode_single_sample, num_parallel_calls=AUTOTUNE).batch(BATCH_SIZE).prefetch(AUTOTUNE)
show_images(data=sorted_df, model=inference_model, decode_pred=decode_pred, cmap='binary')
